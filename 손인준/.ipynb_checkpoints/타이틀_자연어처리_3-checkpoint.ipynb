# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re
import time
import warnings
warnings.filterwarnings('ignore')
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline  
from scipy import stats

from collections import Counter
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words
import re
import nltk
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
data= pd.read_csv(r'C:\Users\injoo\광주 인공지능 사관학교\로테이션\자연어처리&추천시스템 김준태\미니프로젝트\Dataset\cleaned_USvidoes.csv', error_bad_lines=False)
data = data[['video_id', 'views', 'date']]

# %%
data2= pd.read_csv(r'C:\Users\injoo\광주 인공지능 사관학교\로테이션\자연어처리&추천시스템 김준태\미니프로젝트\Dataset\USvideos.csv', error_bad_lines=False)
data2 = data2['title']
# Out:
# b'Skipping line 2401: expected 11 fields, saw 21\nSkipping line 2800: expected 11 fields, saw 21\nSkipping line 5297: expected 11 fields, saw 12\nSkipping line 5299: expected 11 fields, saw 12\nSkipping line 5300: expected 11 fields, saw 12\nSkipping line 5301: expected 11 fields, saw 12\n'

# %%
df = pd.concat([ data2, data], axis = 1)

# %%
us_videos = df

# %%
result = us_videos.drop_duplicates('video_id', keep='last').values
df = pd.DataFrame(result, columns = us_videos.columns)

# %%
df
# Out:
#                                                   title     video_id   views  \
# 0     1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...  5ywKal6-anc  703750
# 1               iPhone X — Introducing iPhone X — Apple  GGm0FQ6i74U  244433
# 2                                           My Response  qJJHhVf3_ZM  220661
# 3                             Apple iPhone X first look  9CILSvf1snQ   27794
# 4                                     iPhone X (parody)  k9bYO7uSnrg   14577
# ...                                                 ...          ...     ...
# 2360  Wonderstruck Official Trailer [HD] | Amazon St...  qRoVlH1OcI4   55762
# 2361  Hidden NES Golf game on Nintendo Switch. A tri...  EoejGgUNmVU  142908
# 2362  WATCH: First Lady Melania Trump discusses chil...  MT1CMTI0EVw   24532
# 2363             First footage of wild sand cat kittens  AFxLA3RGjnc  144039
# 2364  First cosmic event seen in gravitational waves...          NaN     NaN
#
#             date
# 0     2017-09-13
# 1     2017-09-13
# 2     2017-09-13
# 3     2017-09-13
# 4     2017-09-13
# ...          ...
# 2360  2017-01-22
# 2361  2017-01-22
# 2362  2017-01-22
# 2363  2017-01-22
# 2364         NaN
#
# [2365 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# title       0
# video_id    1
# views       1
# date        1
# dtype: int64

# %%
df= df.dropna()

# %%
df = df.drop(columns = ['video_id', 'date'])

# %%
views = df['views']

# %%
views.quantile([0.25, 0.5, 0.75, 1])
# Out:
# 0.25        83536.5
# 0.50         287788
# 0.75         920616
# 1.00    4.15007e+07
# Name: views, dtype: object

# %%
df['views_label'] = df['views']

# %%
def label_func(x):
    if x>=12.57:
        return 1
    else:
        return 0

# %%
df['views_label'] = df['views_label'].apply(lambda x: label_func(x))

# %%
df
# Out:
#                                                   title views_log  views_label
# 0     1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...   13.4642            1
# 1               iPhone X — Introducing iPhone X — Apple   12.4067            0
# 2                                           My Response   12.3044            0
# 3                             Apple iPhone X first look   10.2326            0
# 4                                     iPhone X (parody)   9.58727            0
# ...                                                 ...       ...          ...
# 2359  OUR TEAM 10 AUDITION with TESSA BROOKS & NICK ...   12.9954            1
# 2360  Wonderstruck Official Trailer [HD] | Amazon St...   10.9289            0
# 2361  Hidden NES Golf game on Nintendo Switch. A tri...     11.87            0
# 2362  WATCH: First Lady Melania Trump discusses chil...   10.1078            0
# 2363             First footage of wild sand cat kittens   11.8778            0
#
# [2364 rows x 3 columns]

# %%
df.describe()
# Out:
#        views_label
# count  2364.000000
# mean      0.500000
# std       0.500106
# min       0.000000
# 25%       0.000000
# 50%       0.500000
# 75%       1.000000
# max       1.000000

# %%
df = df.drop(columns=['views_log'])
title_data = df

# %% [markdown]
# # 이제 자연어 처리 해주자 제목에 대해서

# %%
df
# Out:
#                                                   title  views_label
# 0     1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...            1
# 1               iPhone X — Introducing iPhone X — Apple            0
# 2                                           My Response            0
# 3                             Apple iPhone X first look            0
# 4                                     iPhone X (parody)            0
# ...                                                 ...          ...
# 2359  OUR TEAM 10 AUDITION with TESSA BROOKS & NICK ...            1
# 2360  Wonderstruck Official Trailer [HD] | Amazon St...            0
# 2361  Hidden NES Golf game on Nintendo Switch. A tri...            0
# 2362  WATCH: First Lady Melania Trump discusses chil...            0
# 2363             First footage of wild sand cat kittens            0
#
# [2364 rows x 2 columns]

# %%
df['title'] = df['title'].str.replace("[^\w]", " ")

# %%
df['title'] = df['title'].replace('', np.nan)

# %%
title_data = df['title']

# %%
titles_list = []
#숫자 제거가 덜 되었다. 하나하나 돌면서 숫자도 제거해주자. 단 단어랑 붙어 있는 숫자는 살려주자
for title in title_data:
    title = title.split(" ")
    word_without_number = []
    for word in title:
        output = re.sub(r'\d+', '', word)
        if output != '':
            word_without_number.append(output.lower())
    titles_list.append(word_without_number)

# %%
titles_list
# Out:
# [['year',
#   'of',
#   'vlogging',
#   'how',
#   'logan',
#   'paul',
#   'changed',
#   'youtube',
#   'forever'],
#  ['iphone', 'x', 'introducing', 'iphone', 'x', 'apple'],
#  ['my', 'response'],
#  ['apple', 'iphone', 'x', 'first', 'look'],
#  ['iphone', 'x', 'parody'],
#  ['the', 'disaster', 'artist', 'official', 'trailer', 'hd', 'a'],
#  ['the', 'check', 'in', 'hud', 'ben', 'carson', 'and', 'hurricanes'],
#  ['iphone', 'x', 'impressions', 'hands', 'on'],
#  ['attacked', 'by', 'a', 'police', 'dog'],
#  ['honest', 'trailers', 'the', 'mummy'],
#  ['honest', 'college', 'tour'],
#  ['best', 'floyd', 'mayweather', 'interview', 'awkward', 'puppets'],
#  ['jennifer',
#   'lawrence',
#   'challenges',
#   'jimmy',
#   'to',
#   'an',
#   'axe',
#   'throwing',
#   'contest'],
#  ['hand', 'in', 'hand', 'a', 'benefit', 'for', 'hurricane', 'relief', 'mtv'],
#  ['colin',
#   'cloud',
#   'mind',
#   'reader',
#   'predicts',
#   'your',
#   'tweets',
#   'america',
#   's',
#   'got',
#   'talent'],
#  ['iphone', 'x', 'hands', 'on', 'everything', 'you', 'need', 'to', 'know'],
#  ['what', 'do', 'you', 'want', 'to', 'eat'],
#  ['getting',
#   'into',
#   'a',
#   'conversation',
#   'in',
#   'a',
#   'language',
#   'you',
#   'don',
#   't',
#   'actually',
#   'speak',
#   'that',
#   'well'],
#  ['juicy', 'chicken', 'breast', 'you', 'suck', 'at', 'cooking', 'episode'],
#  ['downsizing', 'official', 'trailer', 'paramount', 'pictures'],
#  ['fergie', 'you', 'already', 'know', 'ft', 'nicki', 'minaj'],
#  ['hurricane', 'irma', 'death', 'toll', 'rises', 'to', 'in', 'cuba'],
#  ['gigi',
#   'hadid',
#   'loses',
#   'high',
#   'heel',
#   'during',
#   'fashion',
#   'week',
#   'walks',
#   'it',
#   'off',
#   'like',
#   'a',
#   'pro',
#   'tmz'],
#  ['superfruit', 'reacts', 'to', 'teens', 'react', 'to', 'superfruit'],
#  ['kid', 'rock', 'tennessee', 'mountain', 'top', 'lyrics'],
#  ['chargers', 'vs', 'broncos', 'nfl', 'week', 'game', 'highlights'],
#  ['nerf', 'bow', 'trick', 'shots', 'dude', 'perfect'],
#  ['action',
#   'bronson',
#   'and',
#   'sean',
#   'evans',
#   'have',
#   'a',
#   'sandwich',
#   'showdown',
#   'judged',
#   'by',
#   'mario',
#   'batali',
#   'sean',
#   'in',
#   'the',
#   'wild'],
#  ['joe', 'arpaio', 'last', 'week', 'tonight', 'with', 'john', 'oliver', 'hbo'],
#  ['what', 's', 'in', 'this', 's', 'mystery', 'caboodle'],
#  ['radiohead', 'lift'],
#  ['what', 's', 'actually', 'the', 'plane', 'of', 'the', 'future'],
#  ['blind', 'people', 'describe', 'beauty'],
#  ['what', 'hillary', 'clinton', 'really', 'thinks'],
#  ['drowning', 'for', 'power', 'rooster', 'teeth', 'animated', 'adventures'],
#  ['jumping', 'through', 'impossible', 'shapes'],
#  ['does',
#   'maggie',
#   'gyllenhaal',
#   'have',
#   'taylor',
#   'swift',
#   's',
#   'scarf',
#   'wwhl'],
#  ['from',
#   'the',
#   'air',
#   'irma',
#   's',
#   'catastrophic',
#   'wrath',
#   'is',
#   'undeniable'],
#  ['fall',
#   'makeup',
#   'tutorial',
#   'talk',
#   'through',
#   'tutorial',
#   'casey',
#   'holmes'],
#  ['the', 'commuter', 'teaser', 'trailer', 'movieclips', 'trailers'],
#  ['the', 'problem', 'with', 'our', 'phones'],
#  ['lany', 'super', 'far', 'official', 'video'],
#  ['gwyneth', 'paltrow', 'crashes', 'james', 'goop', 'magazine', 'rant'],
#  ['fail',
#   'new',
#   'estee',
#   'lauder',
#   'double',
#   'wear',
#   'nude',
#   'first',
#   'impression',
#   'review',
#   'demo',
#   'days',
#   'of',
#   'foundation'],
#  ['im', 'gonna', 'be', 'a', 'father', 'things', 'got', 'awkward'],
#  ['fenty',
#   'beauty',
#   'pro',
#   'filt',
#   'r',
#   'foundation',
#   'review',
#   'nyma',
#   'tang',
#   'thedarkestshade'],
#  ['jimmy',
#   'kimmel',
#   'talks',
#   'to',
#   'kristen',
#   'bell',
#   'in',
#   'orlando',
#   'after',
#   'hurricane',
#   'irma'],
#  ['hurricane', 'jose', 'a', 'm', 'advisory'],
#  ['this',
#   'made',
#   'my',
#   'dad',
#   'cry',
#   'story',
#   'of',
#   'my',
#   'comeback',
#   'competition'],
#  ['gold', 'diva', 'macarons', 'the', 'scran', 'line'],
#  ['chocolate', 'chip', 'cookie', 'cupcakes', 'nerdy', 'nummies'],
#  ['apple', 'watch', 'series', 'hands', 'on', 'live', 'from', 'apple', 'event'],
#  ['last', 'week', 'tonight', 'with', 'john', 'oliver', 'se', 'sep'],
#  ['harry',
#   'styles',
#   'the',
#   'chain',
#   'fleetwood',
#   'mac',
#   'cover',
#   'in',
#   'the',
#   'live',
#   'lounge'],
#  ['real', 'clowns', 'creepier', 'than', 'pennywise', 'from', 'it'],
#  ['here', 's', 'what', 'happens', 'when', 'two', 'hurricanes', 'collide'],
#  ['season', 'preview', 'white', 'people', 'renovating', 'houses'],
#  ['after', 'hours', 'movies', 'whose', 'timelines', 'don', 't', 'add', 'up'],
#  ['don',
#   'lemon',
#   'praises',
#   'chunky',
#   'cnn',
#   'reporter',
#   'facing',
#   'irma',
#   'wrath',
#   'nothing',
#   'wrong',
#   'with',
#   'a',
#   'little',
#   'curve'],
#  ['kirstin', 'bad', 'weather', 'official', 'video'],
#  ['jim',
#   'carrey',
#   's',
#   'bizarre',
#   'fashion',
#   'week',
#   'interview',
#   'daily',
#   'pop',
#   'e',
#   'news'],
#  ['blind', 'taste', 'test', 'grace', 'helbig'],
#  ['surveying',
#   'hurricane',
#   'irma',
#   's',
#   'damage',
#   'in',
#   'southwest',
#   'florida'],
#  ['day', 'at', 'the', 'beach', 'mayor', 'steve', 'fulop'],
#  ['seafood', 'vs', 'seafood', 'australia'],
#  ['fifty', 'shades', 'freed', 'teaser', 'hd'],
#  ['qb', 'turned', 'psychic', 'tony', 'romo', 'predicts', 'future'],
#  ['iphone',
#   'x',
#   'walkthrough',
#   'animoji',
#   'face',
#   'id',
#   'portrait',
#   'mode',
#   'lighting',
#   'effects',
#   'more'],
#  ['how', 'to', 'photograph', 'incredible', 'architecture'],
#  ['tommy',
#   'wiseau',
#   'on',
#   'why',
#   'james',
#   'franco',
#   'was',
#   'perfect',
#   'for',
#   'the',
#   'disaster',
#   'artist',
#   'los',
#   'angeles',
#   'times'],
#  ['how',
#   'kanye',
#   'west',
#   's',
#   'graduation',
#   'changed',
#   'music',
#   'genius',
#   'news'],
#  ['iphone', 'x', 'hands', 'on'],
#  ['tying', 'a', 'shoe'],
#  ['big', 'announcement', 'on', 'my', 'popscicle'],
#  ['things', 'you', 'need', 'to', 'know', 'about', 'pennywise'],
#  ['obsessed', 'with', 'netflix'],
#  ['game', 'revealed', 'season', 'episode', 'a', 'goodbye', 'kiss'],
#  ['jim',
#   'carrey',
#   'sounds',
#   'off',
#   'on',
#   'icons',
#   'and',
#   'more',
#   'at',
#   'nyfw',
#   'e',
#   'live',
#   'from',
#   'the',
#   'red',
#   'carpet'],
#  ['更なるフィット感を追求するねこ', 'maru', 'wishes', 'for', 'more', 'fitting', 'feeling'],
#  ['storm',
#   'chaser',
#   'battles',
#   'hurricane',
#   'irma',
#   's',
#   'powerful',
#   'winds',
#   'nbc',
#   'news'],
#  ['willow', 's', 'birthday'],
#  ['iphone', 'hands', 'on', 'don', 't', 'overlook', 'this', 'big', 'update'],
#  ['essential',
#   'phone',
#   'drop',
#   'test',
#   'titanium',
#   'and',
#   'ceramic',
#   'vs',
#   'gravity'],
#  ['drone',
#   'captures',
#   'aftermath',
#   'of',
#   'hurricane',
#   'irma',
#   'in',
#   'naples',
#   'florida'],
#  ['hurricane', 'size', 'comparison'],
#  ['can',
#   'you',
#   'assume',
#   'sexuality',
#   'based',
#   'on',
#   'a',
#   'first',
#   'impression',
#   'tell',
#   'my',
#   'story'],
#  ['live', 'tracking', 'of', 'hurricane', 'irma'],
#  ['how',
#   'computers',
#   'compress',
#   'text',
#   'huffman',
#   'coding',
#   'and',
#   'huffman',
#   'trees'],
#  ['the', 'constitution', 'of', 'the', 'spartans'],
#  ['hillary', 'clinton', 'speaks'],
#  ['wolf', 'alice', 'beautifully', 'unconventional'],
#  ['larry',
#   's',
#   'back',
#   'nothing',
#   'has',
#   'changed',
#   'curb',
#   'your',
#   'enthusiasm',
#   'season',
#   'trailer',
#   'hbo'],
#  ['casually',
#   'explained',
#   'is',
#   'she',
#   'into',
#   'you',
#   'ii',
#   'what',
#   's',
#   'the',
#   'worst',
#   'that',
#   'could',
#   'happen'],
#  ['easy', 'magic', 'tricks', 'anyone', 'can', 'do'],
#  ['i', 'bought', 'an', 'entire', 'outfit', 'blindfolded'],
#  ['japan',
#   's',
#   'ominous',
#   'dancing',
#   'cats',
#   'and',
#   'the',
#   'disaster',
#   'that',
#   'followed'],
#  ['rick',
#   'and',
#   'morty',
#   'character',
#   'studies',
#   'why',
#   'is',
#   'rick',
#   'such',
#   'a',
#   'rick'],
#  ['i', 'gave', 'myself', 'a', 'celebrity', 'hair', 'transformation'],
#  ['viral',
#   'instagram',
#   'makeup',
#   'trends',
#   'wavy',
#   'eyebrows',
#   'tested',
#   'alisha',
#   'marie'],
#  ['try',
#   'on',
#   'fall',
#   'haul',
#   'fashion',
#   'drugstore',
#   'makeup',
#   'ingrid',
#   'nilsen'],
#  ['minelli', 'empty', 'spaces', 'official', 'video', 'ultra', 'music'],
#  ['a',
#   'moment',
#   'of',
#   'silence',
#   'at',
#   'the',
#   'national',
#   'memorial',
#   'museum'],
#  ['tracking', 'hurricane', 'irma'],
#  ['life', 'of', 'kylie', 'recap', 'season', 'ep', 'e'],
#  ['what', 'is', 'derealisation', 'depersonalisation'],
#  ['hurricane',
#   'irma',
#   'makes',
#   'landfall',
#   'in',
#   'florida',
#   'keys',
#   'as',
#   'powerful',
#   'category',
#   'today'],
#  ['fenty', 'beauty', 'by', 'rihanna', 'full', 'review'],
#  ['hurricane',
#   'irma',
#   'now',
#   'a',
#   'category',
#   'could',
#   're',
#   'engergize',
#   'to',
#   'category',
#   'msnbc'],
#  ['irmagerd',
#   'hurricane',
#   'candy',
#   'and',
#   'why',
#   'it',
#   's',
#   'hard',
#   'to',
#   'make',
#   'candy',
#   'when',
#   'it',
#   'rains'],
#  ['bbc', 'anchor', 'gets', 'lost', 'on', 'camera', 'news', 'blooper'],
#  ['dried', 'up', 'beach', 'in', 'the', 'bahamas'],
#  ['hurricane', 'irma', 'news', 'bloopers'],
#  ['full',
#   'face',
#   'of',
#   'first',
#   'impressions',
#   'testing',
#   'new',
#   'makeup',
#   'beauty',
#   'with',
#   'mi'],
#  ['rudimental',
#   'sun',
#   'comes',
#   'up',
#   'feat',
#   'james',
#   'arthur',
#   'official',
#   'video'],
#  ['hilarious', 'thrift', 'store', 'items'],
#  ['hurricane',
#   'irma',
#   'roars',
#   'into',
#   'the',
#   'florida',
#   'keys',
#   'and',
#   'continues',
#   'up',
#   'the',
#   'coast'],
#  ['the',
#   'honda',
#   'civic',
#   'has',
#   'a',
#   'very',
#   'small',
#   'feature',
#   'that',
#   'i',
#   'never',
#   'noticed',
#   'until',
#   'now'],
#  ['testing', 'weird', 'puppy', 'toys', 'with', 'puppy', 'cute'],
#  ['served', 'like', 'a', 'girl', 'trailer'],
#  ['hurricane', 'irma', 'emergency', 'fake', 'interpreter'],
#  ['check', 'description', 'southern', 'most', 'point', 'live', 'webcam'],
#  ['cal', 'football', 'hc', 'justin', 'wilcox', 'september'],
#  ['salted',
#   'egg',
#   'crab',
#   'street',
#   'food',
#   'tour',
#   'of',
#   'old',
#   'airport',
#   'road',
#   'hawker',
#   'center'],
#  ['nothing', 'but', 'thieves', 'sorry', 'stripped', 'back'],
#  ['these', 'are', 'the', 'best', 'features', 'coming', 'to', 'iphones'],
#  ['galaxy', 'note', 'things', 'to', 'do', 'first'],
#  ['it', 'spoiler', 'talk'],
#  ['sloane',
#   'stephens',
#   'jokes',
#   'that',
#   'million',
#   'check',
#   'inspires',
#   'her',
#   'to',
#   'keep',
#   'playing',
#   'espn'],
#  ['killer', 'whales', 'attack', 'minke', 'frozen', 'planet', 'bbc', 'earth'],
#  ['garlic', 'knot', 'chicken', 'alfredo', 'ring'],
#  ['us', 'open', 'sloane', 'stephens', 'takes', 'the', 'title'],
#  ['first',
#   'tuned',
#   'run',
#   'of',
#   'terry',
#   'mayhugh',
#   's',
#   'quarter',
#   'scale',
#   'v',
#   'merlin'],
#  ['rainbow',
#   'connection',
#   'the',
#   'muppets',
#   'at',
#   'the',
#   'hollywood',
#   'bowl',
#   'september',
#   'hd'],
#  ['los',
#   'jugadores',
#   'de',
#   'sacachispas',
#   'entraron',
#   'vestidos',
#   'de',
#   'guerreros',
#   'vs',
#   'sarmiento',
#   'copa',
#   'argentina'],
#  ['days',
#   'timelapse',
#   'at',
#   'sea',
#   'k',
#   'through',
#   'thunderstorms',
#   'torrential',
#   'rain',
#   'busy',
#   'traffic'],
#  ['fenty', 'beauty', 'by', 'rihanna', 'hit', 'or', 'miss', 'jeffree', 'star'],
#  ['teardown',
#   'and',
#   'experiments',
#   'with',
#   'a',
#   'doppler',
#   'microwave',
#   'transceiver'],
#  ['stephen', 'king', 's', 'it', 'what', 's', 'the', 'difference'],
#  ['svu', 'opener', 'dedication', 'wmv'],
#  ['the', 'final', 'steps', 'of', 'making', 'pyrimethamine', 'daraprim'],
#  ['steve',
#   'bannon',
#   'trump',
#   's',
#   'access',
#   'hollywood',
#   'tape',
#   'was',
#   'a',
#   'litmus',
#   'test'],
#  ['roasting', 'youtubers', 'nails', 'nail', 'diss'],
#  ['dancing', 'in', 's', 'movies', 'supercut', 'vol'],
#  ['blake',
#   'shelton',
#   'i',
#   'll',
#   'name',
#   'the',
#   'dogs',
#   'official',
#   'music',
#   'video'],
#  ['dad', 'builds', 'palace', 'for', 'dogs'],
#  ['hurricane', 'irma', 'warning', 'with', 'sign', 'language'],
#  ['kmart', 'i', 'can'],
#  ['the', 'smartphone', 'challenge'],
#  ['fenty', 'beauty', 'full', 'face', 'beat', 'impressions', 'review'],
#  ['how', 'to', 'save', 'your', 'seat', 'in', 'japan'],
#  ['how',
#   'to',
#   'cook',
#   'with',
#   'no',
#   'power',
#   'during',
#   'a',
#   'hurricane',
#   'irma'],
#  ['how', 'to', 'win', 'australia'],
#  ['rihanna',
#   'fenty',
#   'beauty',
#   'my',
#   'first',
#   'impressions',
#   'full',
#   'face',
#   'review',
#   'for',
#   'dark',
#   'skin',
#   'msdebdeb'],
#  ['one', 'america', 'appeal', 'our', 'friends', 'in', 'texas'],
#  ['anvil', 'vs', 'watermelon', 'pyramid', 'crazy', 'm', 'drop', 'tests'],
#  ['genres',
#   'two',
#   'artists',
#   'one',
#   'song',
#   'all',
#   'voices',
#   'shape',
#   'of',
#   'you',
#   'ed',
#   'sheeran'],
#  ['welcome', 'to', 'jurassic', 'falls'],
#  ['buick', 'skyhawk', 'commercial'],
#  ['nicholls', 'postgame', 'kevin', 'sumlin'],
#  ['kane', 'brown', 'found', 'you', 'audio'],
#  ['game', 'of', 'thrones', 'sings', 'look', 'what', 'you', 'made', 'me', 'do'],
#  ['bernie',
#   'sanders',
#   'tries',
#   'to',
#   'say',
#   'something',
#   'nice',
#   'about',
#   'trump'],
#  ['sam', 'smith', 'too', 'good', 'at', 'goodbyes', 'official', 'audio'],
#  ['calvin',
#   'harris',
#   'hard',
#   'to',
#   'love',
#   'official',
#   'video',
#   'ft',
#   'jessie',
#   'reyez'],
#  ['update', 'problem', 'with', 'chemo', 'pills'],
#  ['if', 'kids', 'shows', 'were', 'honest', 'about', 'life'],
#  ['what', 'does', 'your', 'search', 'history', 'say', 'about', 'you'],
#  ['nerf',
#   'meets',
#   'call',
#   'of',
#   'duty',
#   'gun',
#   'game',
#   'first',
#   'person',
#   'in',
#   'k'],
#  ['g', 'eazy', 'no', 'limit', 'audio', 'ft', 'a', 'ap', 'rocky', 'cardi', 'b'],
#  ['rutgers', 'falls', 'to', 'eastern', 'michigan'],
#  ['florida',
#   'weather',
#   'cameras',
#   'hurricane',
#   'irma',
#   'cameras',
#   'across',
#   'florida'],
#  ['alias', 'grace', 'official', 'trailer', 'hd', 'netflix'],
#  ['the', 'only', 'dating', 'advice', 'you', 'll', 'ever', 'need'],
#  ['home', 'again', 'movie', 'review'],
#  ['fifth', 'harmony', 'deliver'],
#  ['janet',
#   'jackson',
#   'performs',
#   'dammn',
#   'baby',
#   'i',
#   'get',
#   'lonely',
#   'live',
#   'state',
#   'of',
#   'the',
#   'world',
#   'tour'],
#  ['jordan',
#   'peele',
#   'and',
#   'spike',
#   'lee',
#   'team',
#   'up',
#   'for',
#   'movie',
#   'about',
#   'black',
#   'cop',
#   'who',
#   'infiltrated',
#   'the',
#   'kkk'],
#  ['zayn', 'dusk', 'till', 'dawn', 'ft', 'sia'],
#  ['orlando', 'braces', 'for', 'hurricane', 'irma'],
#  ['it',
#   's',
#   'nicholas',
#   'hamilton',
#   'chosen',
#   'jacobs',
#   'play',
#   'raw',
#   's',
#   'whisper',
#   'challenge'],
#  ['green', 'day', 'too', 'dumb', 'to', 'die', 'official', 'lyric', 'video'],
#  ['hailee',
#   'steinfeld',
#   'alesso',
#   'ft',
#   'florida',
#   'georgia',
#   'line',
#   'watt',
#   'let',
#   'me',
#   'go',
#   'official',
#   'audio'],
#  ['kelly', 'clarkson', 'love', 'so', 'soft', 'official', 'video'],
#  ['harry', 'potter', 'theory', 'the', 'history', 'of', 'hagrid', 's', 'wand'],
#  ['hurricanes', 'irma', 'jose', 'and', 'katia', 'all', 'at', 'once', 'on'],
#  ['thomas', 'rhett', 'sweetheart', 'static', 'video'],
#  ['suburbicon', 'trailer'],
#  ['live',
#   'footage',
#   'as',
#   'hurricane',
#   'irma',
#   'destroys',
#   'maho',
#   'beach',
#   'cam',
#   'in',
#   'st',
#   'maarten'],
#  ['avenged', 'sevenfold', 'as', 'tears', 'go', 'by'],
#  ['acting', 'out', 'my', 'real', 'childhood', 'stories', 'part'],
#  ['taylor',
#   'swift',
#   'now',
#   'presents',
#   'see',
#   'what',
#   'taylor',
#   's',
#   'up',
#   'to',
#   'now',
#   'at',
#   't'],
#  ['american', 'horror', 'story', 'cult', 'bee', 'hive'],
#  ['lecrae', 'hammer', 'time', 'dance', 'visual', 'ft', 'k', 'phew'],
#  ['small', 'hands', 'samsung', 'galaxy', 'note', 'review'],
#  ['online', 'shopping', 'haul', 'with', 'me', 'a', 'shopaholic'],
#  ['liza',
#   'koshy',
#   's',
#   'dream',
#   'office',
#   'makeover',
#   'omg',
#   'we',
#   're',
#   'coming',
#   'over',
#   'mr',
#   'kate'],
#  ['rhab', 'quintino', 'i', 'just', 'can', 't', 'official', 'video'],
#  ['things',
#   'you',
#   'need',
#   'to',
#   'know',
#   'about',
#   'kittens',
#   'simon',
#   's',
#   'cat'],
#  ['watch',
#   'live',
#   'satellite',
#   'images',
#   'of',
#   'hurricane',
#   'irma',
#   'evacuation',
#   'orders',
#   'in',
#   'place',
#   'in',
#   'florida',
#   'time'],
#  ['gaga', 'five', 'foot', 'two', 'press', 'conference', 'festival'],
#  ['hello',
#   'world',
#   'meet',
#   'our',
#   'baby',
#   'girl',
#   'alexis',
#   'olympia',
#   'ohanian',
#   'jr'],
#  ['alexa', 'guess', 'my'],
#  ['bill', 'skarsgård', 's', 'demonic', 'it', 'smile', 'conan', 'on', 'tbs'],
#  ['iphone', 'x', 'introducing', 'iphone', 'x', 'apple'],
#  ['year',
#   'of',
#   'vlogging',
#   'how',
#   'logan',
#   'paul',
#   'changed',
#   'youtube',
#   'forever'],
#  ['apple', 'iphone', 'x', 'first', 'look'],
#  ['spiked', 'by', 'a', 'sea', 'urchin'],
#  ['lana', 'del', 'rey', 'white', 'mustang', 'official', 'video'],
#  ['official',
#   'us',
#   'find',
#   'your',
#   'voice',
#   'trailer',
#   'disney',
#   'pixar',
#   's',
#   'coco'],
#  ['iphone', 'x', 'and', 'iphone'],
#  ['my', 'response'],
#  ['soy',
#   'pablo',
#   'extended',
#   'trailer',
#   'a',
#   'bad',
#   'lip',
#   'reading',
#   'of',
#   'narcos',
#   'a',
#   'netflix',
#   'original',
#   'series'],
#  ['the',
#   'opposition',
#   'w',
#   'jordan',
#   'klepper',
#   'opposing',
#   'the',
#   'resistance',
#   'in',
#   'phoenix'],
#  ['iphone', 'x', 'parody'],
#  ['jennifer',
#   'lawrence',
#   'challenges',
#   'jimmy',
#   'to',
#   'an',
#   'axe',
#   'throwing',
#   'contest'],
#  ['the', 'check', 'in', 'hud', 'ben', 'carson', 'and', 'hurricanes'],
#  ['iphone', 'x', 'impressions', 'hands', 'on'],
#  ['the',
#   'real',
#   'reason',
#   'to',
#   'kill',
#   'a',
#   'mockingbird',
#   'became',
#   'so',
#   'famous'],
#  ['sarah', 'huckabee', 'sanders', 'on', 'jemele', 'hill'],
#  ['the', 'disaster', 'artist', 'official', 'trailer', 'hd', 'a'],
#  ['hand', 'in', 'hand', 'a', 'benefit', 'for', 'hurricane', 'relief', 'mtv'],
#  ['colin',
#   'cloud',
#   'mind',
#   'reader',
#   'predicts',
#   'your',
#   'tweets',
#   'america',
#   's',
#   'got',
#   'talent'],
#  ['riverdale', 'motive', 'trailer', 'the', 'cw'],
#  ['fergie', 'you', 'already', 'know', 'ft', 'nicki', 'minaj'],
#  ['best', 'floyd', 'mayweather', 'interview', 'awkward', 'puppets'],
#  ['weight', 'update', 'weeks', 'post', 'surgery', 'pounds'],
#  ['stephen',
#   'a',
#   'smith',
#   'calls',
#   'espn',
#   's',
#   'nbarank',
#   'garbage',
#   'for',
#   'carmelo',
#   'anthony',
#   'rating',
#   'first',
#   'take',
#   'espn'],
#  ['iphone', 'x', 'hands', 'on', 'everything', 'you', 'need', 'to', 'know'],
#  ['honest', 'trailers', 'the', 'mummy'],
#  ['what', 'do', 'you', 'want', 'to', 'eat'],
#  ['attacked', 'by', 'a', 'police', 'dog'],
#  ['does',
#   'maggie',
#   'gyllenhaal',
#   'have',
#   'taylor',
#   'swift',
#   's',
#   'scarf',
#   'wwhl'],
#  ['honest', 'college', 'tour'],
#  ['fifth', 'harmony', 'he', 'like', 'that'],
#  ['bell', 's', 'theorem', 'the', 'quantum', 'venn', 'diagram', 'paradox'],
#  ['bella',
#   'hadid',
#   'roughs',
#   'up',
#   'security',
#   'roughing',
#   'up',
#   'female',
#   'photog',
#   'tmz'],
#  ['iphone', 'x', 'face', 'id', 'unlock', 'fail'],
#  ['juicy', 'chicken', 'breast', 'you', 'suck', 'at', 'cooking', 'episode'],
#  ['downsizing', 'official', 'trailer', 'paramount', 'pictures'],
#  ['iphone',
#   'x',
#   'vs',
#   'iphone',
#   'hands',
#   'on',
#   'what',
#   's',
#   'the',
#   'difference'],
#  ['kid', 'rock', 'tennessee', 'mountain', 'top', 'lyrics'],
#  ['getting',
#   'into',
#   'a',
#   'conversation',
#   'in',
#   'a',
#   'language',
#   'you',
#   'don',
#   't',
#   'actually',
#   'speak',
#   'that',
#   'well'],
#  ['vlogtember', 'nyc', 'running', 'around', 'heyclaire'],
#  ['radiohead', 'lift'],
#  ['demi',
#   'lovato',
#   'performing',
#   'with',
#   'a',
#   'little',
#   'help',
#   'from',
#   'my',
#   'friends',
#   'at',
#   'hand',
#   'in',
#   'hand',
#   'september'],
#  ['hurricane', 'irma', 'death', 'toll', 'rises', 'to', 'in', 'cuba'],
#  ['tori',
#   'kelly',
#   'luis',
#   'fonsi',
#   'hallelujah',
#   'hand',
#   'in',
#   'hand',
#   'benefit'],
#  ['nerf', 'bow', 'trick', 'shots', 'dude', 'perfect'],
#  ['what', 's', 'actually', 'the', 'plane', 'of', 'the', 'future'],
#  ['superfruit', 'reacts', 'to', 'teens', 'react', 'to', 'superfruit'],
#  ['from',
#   'the',
#   'air',
#   'irma',
#   's',
#   'catastrophic',
#   'wrath',
#   'is',
#   'undeniable'],
#  ['mystery',
#   'van',
#   'helping',
#   'self',
#   'driving',
#   'cars',
#   'communicate',
#   'with',
#   'people',
#   'autonomy',
#   'ford'],
#  ['fenty', 'beauty', 'by', 'rihanna', 'review', 'wear', 'test'],
#  ['the', 'xx', 'on', 'hold', 'jamie', 'xx', 'remix'],
#  ['blind', 'people', 'describe', 'beauty'],
#  ['sarah',
#   'sanders',
#   'espn',
#   's',
#   'jemele',
#   'hill',
#   'committed',
#   'fireable',
#   'offense'],
#  ['imagine',
#   'dragons',
#   'whatever',
#   'it',
#   'takes',
#   'version',
#   'lyric',
#   'vide',
#   'o'],
#  ['selena', 'gomez', 'hand', 'in', 'hand'],
#  ['usher',
#   'and',
#   'blake',
#   'shelton',
#   'stand',
#   'by',
#   'me',
#   'hand',
#   'in',
#   'hand',
#   'a',
#   'benefit',
#   'for',
#   'hurricane',
#   'relief',
#   'mtv'],
#  ['action',
#   'bronson',
#   'and',
#   'sean',
#   'evans',
#   'have',
#   'a',
#   'sandwich',
#   'showdown',
#   'judged',
#   'by',
#   'mario',
#   'batali',
#   'sean',
#   'in',
#   'the',
#   'wild'],
#  ['apple', 'watch', 'series', 'hands', 'on', 'live', 'from', 'apple', 'event'],
#  ['chargers', 'vs', 'broncos', 'nfl', 'week', 'game', 'highlights'],
#  ['what', 's', 'in', 'this', 's', 'mystery', 'caboodle'],
#  ['stone',
#   'sour',
#   'rose',
#   'red',
#   'violent',
#   'blue',
#   'this',
#   'song',
#   'is',
#   'dumb',
#   'so',
#   'am',
#   'i',
#   'official',
#   'video'],
#  ['everything',
#   'wrong',
#   'with',
#   'alien',
#   'covenant',
#   'in',
#   'minutes',
#   'or',
#   'less'],
#  ['delicious',
#   'chocolate',
#   'cupcakes',
#   'in',
#   'minutes',
#   'the',
#   'scran',
#   'line'],
#  ['depeche', 'mode', 'cover', 'me'],
#  ['the', 'commuter', 'teaser', 'trailer', 'movieclips', 'trailers'],
#  ['joe', 'arpaio', 'last', 'week', 'tonight', 'with', 'john', 'oliver', 'hbo'],
#  ['world', 'of', 'walker', 'trailer'],
#  ['damage',
#   'from',
#   'hurricane',
#   'irma',
#   'at',
#   'the',
#   'magic',
#   'kingdom',
#   'walt',
#   'disney',
#   'world'],
#  ['the', 'problem', 'with', 'our', 'phones'],
#  ['here', 's', 'why', 'the', 'lexus', 'lc', 'costs'],
#  ['jumping', 'through', 'impossible', 'shapes'],
#  ['x',
#   'extreme',
#   'spicy',
#   'noodle',
#   'car',
#   'ride',
#   'i',
#   'cried',
#   'ranz',
#   'and',
#   'niana'],
#  ['更なるフィット感を追求するねこ', 'maru', 'wishes', 'for', 'more', 'fitting', 'feeling'],
#  ['what', 'i', 'wore', 'new', 'york', 'fashion', 'week'],
#  ['lany', 'super', 'far', 'official', 'video'],
#  ['last', 'week', 'tonight', 'with', 'john', 'oliver', 'se', 'sep'],
#  ['drowning', 'for', 'power', 'rooster', 'teeth', 'animated', 'adventures'],
#  ['don',
#   'lemon',
#   'praises',
#   'chunky',
#   'cnn',
#   'reporter',
#   'facing',
#   'irma',
#   'wrath',
#   'nothing',
#   'wrong',
#   'with',
#   'a',
#   'little',
#   'curve'],
#  ['im', 'gonna', 'be', 'a', 'father', 'things', 'got', 'awkward'],
#  ['season', 'preview', 'white', 'people', 'renovating', 'houses'],
#  ['jimmy',
#   'kimmel',
#   'talks',
#   'to',
#   'kristen',
#   'bell',
#   'in',
#   'orlando',
#   'after',
#   'hurricane',
#   'irma'],
#  ['this',
#   'made',
#   'my',
#   'dad',
#   'cry',
#   'story',
#   'of',
#   'my',
#   'comeback',
#   'competition'],
#  ['fenty',
#   'beauty',
#   'pro',
#   'filt',
#   'r',
#   'foundation',
#   'review',
#   'nyma',
#   'tang',
#   'thedarkestshade'],
#  ['iphone',
#   'x',
#   'walkthrough',
#   'animoji',
#   'face',
#   'id',
#   'portrait',
#   'mode',
#   'lighting',
#   'effects',
#   'more'],
#  ['how',
#   'to',
#   'make',
#   'lloyd',
#   'from',
#   'the',
#   'new',
#   'lego',
#   'ninjago',
#   'movie',
#   'out',
#   'of',
#   'cake',
#   'yolanda',
#   'gampp',
#   'how',
#   'to',
#   'cake',
#   'it'],
#  ['mustard', 'vs', 'cheese', 'answering', 'your', 'questions', 'qandgay'],
#  ['enter', 'shikari', 'rabble', 'rouser', 'official', 'promo', 'video'],
#  ['interview', 'with', 'a', 'runaway', 'toddler'],
#  ['hurricane', 'jose', 'a', 'm', 'advisory'],
#  ['chocolate', 'chip', 'cookie', 'cupcakes', 'nerdy', 'nummies'],
#  ['things', 'you', 'need', 'to', 'know', 'about', 'pennywise'],
#  ['crowder', 'prove', 'it', 'ft', 'kb'],
#  ['how', 'to', 'photograph', 'incredible', 'architecture'],
#  ['galen', 'hooks', 'wait', 'for', 'me', 'a', 'galen', 'hooks', 'film'],
#  ['obsessed', 'with', 'netflix'],
#  ['harry',
#   'styles',
#   'the',
#   'chain',
#   'fleetwood',
#   'mac',
#   'cover',
#   'in',
#   'the',
#   'live',
#   'lounge'],
#  ['willow', 's', 'birthday'],
#  ['jim',
#   'carrey',
#   's',
#   'bizarre',
#   'fashion',
#   'week',
#   'interview',
#   'daily',
#   'pop',
#   'e',
#   'news'],
#  ['blind', 'taste', 'test', 'grace', 'helbig'],
#  ['after', 'hours', 'movies', 'whose', 'timelines', 'don', 't', 'add', 'up'],
#  ['real', 'clowns', 'creepier', 'than', 'pennywise', 'from', 'it'],
#  ['tommy',
#   'wiseau',
#   'on',
#   'why',
#   'james',
#   'franco',
#   'was',
#   'perfect',
#   'for',
#   'the',
#   'disaster',
#   'artist',
#   'los',
#   'angeles',
#   'times'],
#  ['apple', 'watch', 'series', 'hands', 'on'],
#  ['rudimental',
#   'sun',
#   'comes',
#   'up',
#   'feat',
#   'james',
#   'arthur',
#   'official',
#   'video'],
#  ['big', 'announcement', 'on', 'my', 'popscicle'],
#  ['qb', 'turned', 'psychic', 'tony', 'romo', 'predicts', 'future'],
#  ['fall',
#   'makeup',
#   'tutorial',
#   'talk',
#   'through',
#   'tutorial',
#   'casey',
#   'holmes'],
#  ['fifty', 'shades', 'freed', 'teaser', 'hd'],
#  ['seafood', 'vs', 'seafood', 'australia'],
#  ['fail',
#   'new',
#   'estee',
#   'lauder',
#   'double',
#   'wear',
#   'nude',
#   'first',
#   'impression',
#   'review',
#   'demo',
#   'days',
#   'of',
#   'foundation'],
#  ['how',
#   'kanye',
#   'west',
#   's',
#   'graduation',
#   'changed',
#   'music',
#   'genius',
#   'news'],
#  ['storm',
#   'chaser',
#   'battles',
#   'hurricane',
#   'irma',
#   's',
#   'powerful',
#   'winds',
#   'nbc',
#   'news'],
#  ['kirstin', 'bad', 'weather', 'official', 'video'],
#  ['hillary', 'clinton', 'speaks'],
#  ['jim',
#   'carrey',
#   'sounds',
#   'off',
#   'on',
#   'icons',
#   'and',
#   'more',
#   'at',
#   'nyfw',
#   'e',
#   'live',
#   'from',
#   'the',
#   'red',
#   'carpet'],
#  ['surveying',
#   'hurricane',
#   'irma',
#   's',
#   'damage',
#   'in',
#   'southwest',
#   'florida'],
#  ['drone',
#   'captures',
#   'aftermath',
#   'of',
#   'hurricane',
#   'irma',
#   'in',
#   'naples',
#   'florida'],
#  ['here', 's', 'what', 'happens', 'when', 'two', 'hurricanes', 'collide'],
#  ['iphone', 'hands', 'on', 'don', 't', 'overlook', 'this', 'big', 'update'],
#  ['can',
#   'you',
#   'assume',
#   'sexuality',
#   'based',
#   'on',
#   'a',
#   'first',
#   'impression',
#   'tell',
#   'my',
#   'story'],
#  ['wet', 'book', 'rescue'],
#  ['hurricane', 'size', 'comparison'],
#  ['queen', 'live', 'aid', 'part', 'high', 'quality'],
#  ['how',
#   'computers',
#   'compress',
#   'text',
#   'huffman',
#   'coding',
#   'and',
#   'huffman',
#   'trees'],
#  ['live', 'tracking', 'of', 'hurricane', 'irma'],
#  ['the', 'constitution', 'of', 'the', 'spartans'],
#  ['tying', 'a', 'shoe'],
#  ['wolf', 'alice', 'beautifully', 'unconventional'],
#  ['casually',
#   'explained',
#   'is',
#   'she',
#   'into',
#   'you',
#   'ii',
#   'what',
#   's',
#   'the',
#   'worst',
#   'that',
#   'could',
#   'happen'],
#  ['minelli', 'empty', 'spaces', 'official', 'video', 'ultra', 'music'],
#  ['larry',
#   's',
#   'back',
#   'nothing',
#   'has',
#   'changed',
#   'curb',
#   'your',
#   'enthusiasm',
#   'season',
#   'trailer',
#   'hbo'],
#  ['easy', 'magic', 'tricks', 'anyone', 'can', 'do'],
#  ['game', 'revealed', 'season', 'episode', 'a', 'goodbye', 'kiss'],
#  ['japan',
#   's',
#   'ominous',
#   'dancing',
#   'cats',
#   'and',
#   'the',
#   'disaster',
#   'that',
#   'followed'],
#  ['i', 'bought', 'an', 'entire', 'outfit', 'blindfolded'],
#  ['essential',
#   'phone',
#   'drop',
#   'test',
#   'titanium',
#   'and',
#   'ceramic',
#   'vs',
#   'gravity'],
#  ['viral',
#   'instagram',
#   'makeup',
#   'trends',
#   'wavy',
#   'eyebrows',
#   'tested',
#   'alisha',
#   'marie'],
#  ['try',
#   'on',
#   'fall',
#   'haul',
#   'fashion',
#   'drugstore',
#   'makeup',
#   'ingrid',
#   'nilsen'],
#  ['rick',
#   'and',
#   'morty',
#   'character',
#   'studies',
#   'why',
#   'is',
#   'rick',
#   'such',
#   'a',
#   'rick'],
#  ['a',
#   'moment',
#   'of',
#   'silence',
#   'at',
#   'the',
#   'national',
#   'memorial',
#   'museum'],
#  ['tracking', 'hurricane', 'irma'],
#  ['what', 'is', 'derealisation', 'depersonalisation'],
#  ['hurricane',
#   'irma',
#   'makes',
#   'landfall',
#   'in',
#   'florida',
#   'keys',
#   'as',
#   'powerful',
#   'category',
#   'today'],
#  ['testing', 'weird', 'puppy', 'toys', 'with', 'puppy', 'cute'],
#  ['fenty', 'beauty', 'by', 'rihanna', 'full', 'review'],
#  ['hour',
#   'test',
#   'on',
#   'these',
#   'cult',
#   'beauty',
#   'buys',
#   'full',
#   'face',
#   'first',
#   'impressions',
#   'beauty',
#   'with',
#   'mi'],
#  ['dried', 'up', 'beach', 'in', 'the', 'bahamas'],
#  ['hurricane',
#   'irma',
#   'now',
#   'a',
#   'category',
#   'could',
#   're',
#   'engergize',
#   'to',
#   'category',
#   'msnbc'],
#  ['life', 'of', 'kylie', 'recap', 'season', 'ep', 'e'],
#  ['galaxy', 'note', 'things', 'to', 'do', 'first'],
#  ['irmagerd',
#   'hurricane',
#   'candy',
#   'and',
#   'why',
#   'it',
#   's',
#   'hard',
#   'to',
#   'make',
#   'candy',
#   'when',
#   'it',
#   'rains'],
#  ['hurricane', 'irma', 'news', 'bloopers'],
#  ['hilarious', 'thrift', 'store', 'items'],
#  ['bbc', 'anchor', 'gets', 'lost', 'on', 'camera', 'news', 'blooper'],
#  ['hurricane',
#   'irma',
#   'roars',
#   'into',
#   'the',
#   'florida',
#   'keys',
#   'and',
#   'continues',
#   'up',
#   'the',
#   'coast'],
#  ['the',
#   'honda',
#   'civic',
#   'has',
#   'a',
#   'very',
#   'small',
#   'feature',
#   'that',
#   'i',
#   'never',
#   'noticed',
#   'until',
#   'now'],
#  ['i',
#   'will',
#   'knock',
#   'out',
#   'anthony',
#   'joshua',
#   'kubrat',
#   'pulev',
#   'and',
#   'roughs',
#   'up',
#   'offers',
#   'to',
#   'fight',
#   'kugan',
#   'cassius'],
#  ['served', 'like', 'a', 'girl', 'trailer'],
#  ['i', 'gave', 'myself', 'a', 'celebrity', 'hair', 'transformation'],
#  ['hurricane', 'irma', 'emergency', 'fake', 'interpreter'],
#  ['check', 'description', 'southern', 'most', 'point', 'live', 'webcam'],
#  ['cal', 'football', 'hc', 'justin', 'wilcox', 'september'],
#  ['salted',
#   'egg',
#   'crab',
#   'street',
#   'food',
#   'tour',
#   'of',
#   'old',
#   'airport',
#   'road',
#   'hawker',
#   'center'],
#  ['nothing', 'but', 'thieves', 'sorry', 'stripped', 'back'],
#  ['us', 'open', 'sloane', 'stephens', 'takes', 'the', 'title'],
#  ['garlic', 'knot', 'chicken', 'alfredo', 'ring'],
#  ['days',
#   'timelapse',
#   'at',
#   'sea',
#   'k',
#   'through',
#   'thunderstorms',
#   'torrential',
#   'rain',
#   'busy',
#   'traffic'],
#  ['it', 'spoiler', 'talk'],
#  ['killer', 'whales', 'attack', 'minke', 'frozen', 'planet', 'bbc', 'earth'],
#  ['first',
#   'tuned',
#   'run',
#   'of',
#   'terry',
#   'mayhugh',
#   's',
#   'quarter',
#   'scale',
#   'v',
#   'merlin'],
#  ['rainbow',
#   'connection',
#   'the',
#   'muppets',
#   'at',
#   'the',
#   'hollywood',
#   'bowl',
#   'september',
#   'hd'],
#  ['los',
#   'jugadores',
#   'de',
#   'sacachispas',
#   'entraron',
#   'vestidos',
#   'de',
#   'guerreros',
#   'vs',
#   'sarmiento',
#   'copa',
#   'argentina'],
#  ['rami', 'malek', 'como', 'freddie', 'mercury', 'en', 'live', 'aid'],
#  ['teardown',
#   'and',
#   'experiments',
#   'with',
#   'a',
#   'doppler',
#   'microwave',
#   'transceiver'],
#  ['svu', 'opener', 'dedication', 'wmv'],
#  ['fenty', 'beauty', 'by', 'rihanna', 'hit', 'or', 'miss', 'jeffree', 'star'],
#  ['the', 'final', 'steps', 'of', 'making', 'pyrimethamine', 'daraprim'],
#  ['stephen', 'king', 's', 'it', 'what', 's', 'the', 'difference'],
#  ['roasting', 'youtubers', 'nails', 'nail', 'diss'],
#  ['blake',
#   'shelton',
#   'i',
#   'll',
#   'name',
#   'the',
#   'dogs',
#   'official',
#   'music',
#   'video'],
#  ['dancing', 'in', 's', 'movies', 'supercut', 'vol'],
#  ['dad', 'builds', 'palace', 'for', 'dogs'],
#  ['game', 'of', 'thrones', 'sings', 'look', 'what', 'you', 'made', 'me', 'do'],
#  ['hurricane', 'irma', 'warning', 'with', 'sign', 'language'],
#  ['the', 'smartphone', 'challenge'],
#  ['kmart', 'i', 'can'],
#  ['fenty', 'beauty', 'full', 'face', 'beat', 'impressions', 'review'],
#  ['how', 'to', 'save', 'your', 'seat', 'in', 'japan'],
#  ['how',
#   'to',
#   'cook',
#   'with',
#   'no',
#   'power',
#   'during',
#   'a',
#   'hurricane',
#   'irma'],
#  ['how', 'to', 'win', 'australia'],
#  ['rihanna',
#   'fenty',
#   'beauty',
#   'my',
#   'first',
#   'impressions',
#   'full',
#   'face',
#   'review',
#   'for',
#   'dark',
#   'skin',
#   'msdebdeb'],
#  ['steve',
#   'bannon',
#   'trump',
#   's',
#   'access',
#   'hollywood',
#   'tape',
#   'was',
#   'a',
#   'litmus',
#   'test'],
#  ['genres',
#   'two',
#   'artists',
#   'one',
#   'song',
#   'all',
#   'voices',
#   'shape',
#   'of',
#   'you',
#   'ed',
#   'sheeran'],
#  ['kane', 'brown', 'found', 'you', 'audio'],
#  ['buick', 'skyhawk', 'commercial'],
#  ['nicholls', 'postgame', 'kevin', 'sumlin'],
#  ['calvin',
#   'harris',
#   'hard',
#   'to',
#   'love',
#   'official',
#   'video',
#   'ft',
#   'jessie',
#   'reyez'],
#  ['the', 'shape', 'of', 'water', 'red', 'band', 'trailer'],
#  ['my', 'boyfriend', 'buys', 'my', 'outfits'],
#  ['funny', 'you', 'should', 'ask'],
#  ['how', 'not', 'to', 'land', 'an', 'orbital', 'rocket', 'booster'],
#  ['jimmy', 'kimmel', 's', 'full', 'interview', 'with', 'sean', 'spicer'],
#  ['hello',
#   'world',
#   'meet',
#   'our',
#   'baby',
#   'girl',
#   'alexis',
#   'olympia',
#   'ohanian',
#   'jr'],
#  ['life', 'after', 'hate', 'september', 'act', 'full', 'frontal', 'on', 'tbs'],
#  ['the', 'it', 'department'],
#  ['bts', '방탄소년단', 'dna', 'official', 'teaser'],
#  ['machine', 'gun', 'kelly', 'let', 'you', 'go'],
#  ['bill', 'skarsgård', 's', 'demonic', 'it', 'smile', 'conan', 'on', 'tbs'],
#  ['fall', 'out', 'boy', 'the', 'last', 'of', 'the', 'real', 'ones'],
#  ['iphone', 'plus', 'vs', 'iphone', 'plus', 'worth', 'upgrading'],
#  ['alexa', 'guess', 'my', 'number'],
#  ['official',
#   'us',
#   'find',
#   'your',
#   'voice',
#   'trailer',
#   'disney',
#   'pixar',
#   's',
#   'coco'],
#  ['aaron', 'carter', 's', 'hiv', 'test', 'results', 'revealed'],
#  ['lana', 'del', 'rey', 'white', 'mustang', 'official', 'video'],
#  ['the', 'impossible', 'big', 'mac', 'challenge', 'destroyed'],
#  ['soy',
#   'pablo',
#   'extended',
#   'trailer',
#   'a',
#   'bad',
#   'lip',
#   'reading',
#   'of',
#   'narcos',
#   'a',
#   'netflix',
#   'original',
#   'series'],
#  ['iphone', 'x', 'introducing', 'iphone', 'x', 'apple'],
#  ['year',
#   'of',
#   'vlogging',
#   'how',
#   'logan',
#   'paul',
#   'changed',
#   'youtube',
#   'forever'],
#  ['iphone', 'x', 'and', 'iphone'],
#  ['spiked', 'by', 'a', 'sea', 'urchin'],
#  ['sarah', 'huckabee', 'sanders', 'on', 'jemele', 'hill'],
#  ['apple', 'iphone', 'x', 'first', 'look'],
#  ['julien', 'baker', 'appointments', 'official', 'video'],
#  ['mother', 'movie', 'review'],
#  ['hell', 'yes'],
#  ['blindfold', 'gymnastics', 'challenge'],
#  ['dua', 'lipa', 'x', 'gallant', 'in', 'the', 'room', 'episode'],
#  ['chris', 'young', 'losing', 'sleep'],
#  ['bella',
#   'hadid',
#   'roughs',
#   'up',
#   'security',
#   'roughing',
#   'up',
#   'female',
#   'photog',
#   'tmz'],
#  ['teyana',
#   'taylor',
#   'tells',
#   'all',
#   'about',
#   'boob',
#   'surgery',
#   'and',
#   'says',
#   'kanye',
#   'is',
#   'back'],
#  ['red', 'velvet', 'cupcakes', 'as', 'made', 'by', 'kevin', 'durant'],
#  ['cream', 'cheese', 'stuffed', 'pumpkin', 'muffins', 'episode'],
#  ['full',
#   'face',
#   'of',
#   'first',
#   'impressions',
#   'fenty',
#   'beauty',
#   'too',
#   'faced',
#   'ysl',
#   'more'],
#  ['aly', 'aj', 'take', 'me'],
#  ['my', 'response'],
#  ['adam',
#   'ruins',
#   'everything',
#   'the',
#   'messed',
#   'up',
#   'story',
#   'of',
#   'how',
#   'hawaii',
#   'became',
#   'a',
#   'state',
#   'trutv'],
#  ['the',
#   'opposition',
#   'w',
#   'jordan',
#   'klepper',
#   'opposing',
#   'the',
#   'resistance',
#   'in',
#   'phoenix'],
#  ['jennifer',
#   'lawrence',
#   'challenges',
#   'jimmy',
#   'to',
#   'an',
#   'axe',
#   'throwing',
#   'contest'],
#  ['why', 'we', 'eat', 'too', 'much'],
#  ['iphone', 'x', 'parody'],
#  ['iphone', 'x', 'impressions', 'hands', 'on'],
#  ['nicki',
#   'minaj',
#   'surprises',
#   'nas',
#   'celebrating',
#   'his',
#   'rd',
#   'birthday',
#   'party',
#   'with',
#   'swizz',
#   'beatz'],
#  ['the', 'fast', 'and', 'the', 'furious', 'parody', 'goodbye', 'scene'],
#  ['the',
#   'real',
#   'reason',
#   'to',
#   'kill',
#   'a',
#   'mockingbird',
#   'became',
#   'so',
#   'famous'],
#  ['toni', 'braxton', 'deadwood', 'audio'],
#  ['livery', 'cab', 'hits', 'cyclist', 'in', 'east', 'flatbush'],
#  ['riverdale', 'motive', 'trailer', 'the', 'cw'],
#  ['husker', 'du', 'sorry', 'somehow'],
#  ['the', 'check', 'in', 'hud', 'ben', 'carson', 'and', 'hurricanes'],
#  ['lore', 'official', 'trailer', 'hd', 'amazon', 'video'],
#  ['why', 'we', 'need', 'to', 'be', 'talking', 'about', 'american', 'tail'],
#  ['we', 'need', 'to', 'talk'],
#  ['riverdale', 'between', 'the', 'scenes', 'madelaine', 'petsch'],
#  ['learn', 'to', 'stack', 'dice', 'learn', 'quick'],
#  ['optical', 'illusions'],
#  ['x', 'ambassadors', 'ahead', 'of', 'myself'],
#  ['dl', 'hughley', 'on', 'espn', 'jemele', 'hill', 'controversy'],
#  ['bell', 's', 'theorem', 'the', 'quantum', 'venn', 'diagram', 'paradox'],
#  ['the', 'disaster', 'artist', 'official', 'trailer', 'hd', 'a'],
#  ['does',
#   'maggie',
#   'gyllenhaal',
#   'have',
#   'taylor',
#   'swift',
#   's',
#   'scarf',
#   'wwhl'],
#  ['angelica',
#   'hale',
#   'year',
#   'old',
#   'singer',
#   'blows',
#   'the',
#   'audience',
#   'away',
#   'america',
#   's',
#   'got',
#   'talent'],
#  ['weight', 'update', 'weeks', 'post', 'surgery', 'pounds'],
#  ['best',
#   'mic',
#   'd',
#   'up',
#   'sounds',
#   'of',
#   'week',
#   'sound',
#   'fx',
#   'nfl',
#   'films'],
#  ['sarah',
#   'sanders',
#   'espn',
#   's',
#   'jemele',
#   'hill',
#   'committed',
#   'fireable',
#   'offense'],
#  ['fergie', 'you', 'already', 'know', 'ft', 'nicki', 'minaj'],
#  ['hand', 'in', 'hand', 'a', 'benefit', 'for', 'hurricane', 'relief', 'mtv'],
#  ['kelly', 'clarkson', 'talks', 'american', 'idol', 'dr', 'luke', 'interview'],
#  ['will', 'grace', 'journey', 'to', 'now', 'digital', 'exclusive'],
#  ['what', 'to', 'eat', 'in', 'melbourne'],
#  ['iphone', 'x', 'iphone', 'hands', 'on'],
#  ['stephen',
#   'a',
#   'smith',
#   'calls',
#   'espn',
#   's',
#   'nbarank',
#   'garbage',
#   'for',
#   'carmelo',
#   'anthony',
#   'rating',
#   'first',
#   'take',
#   'espn'],
#  ['the', 'xx', 'on', 'hold', 'jamie', 'xx', 'remix'],
#  ['tori',
#   'kelly',
#   'luis',
#   'fonsi',
#   'hallelujah',
#   'hand',
#   'in',
#   'hand',
#   'benefit'],
#  ['best', 'floyd', 'mayweather', 'interview', 'awkward', 'puppets'],
#  ['hudson',
#   'moore',
#   'just',
#   'wanna',
#   'love',
#   'you',
#   'official',
#   'music',
#   'video'],
#  ['boyfriend', 'buys', 'my', 'outfits'],
#  ['iphone', 'x', 'face', 'id', 'unlock', 'fail'],
#  ['stone',
#   'sour',
#   'rose',
#   'red',
#   'violent',
#   'blue',
#   'this',
#   'song',
#   'is',
#   'dumb',
#   'so',
#   'am',
#   'i',
#   'official',
#   'video'],
#  ['couple', 's', 'first', 'merch'],
#  ['what', 'do', 'you', 'want', 'to', 'eat'],
#  ['kph',
#   'water',
#   'rocket',
#   'trike',
#   'ǀ',
#   'kph',
#   'in',
#   'second',
#   'g',
#   'ǀ',
#   'rider',
#   'françois',
#   'gissy'],
#  ['honest', 'trailers', 'the', 'mummy'],
#  ['iphone',
#   'x',
#   'vs',
#   'iphone',
#   'hands',
#   'on',
#   'what',
#   's',
#   'the',
#   'difference'],
#  ['not', 'enough', 'milk', 'my', 'breastfeeding', 'story', 'momtember'],
#  ['attacked', 'by', 'a', 'police', 'dog'],
#  ['depeche', 'mode', 'cover', 'me'],
#  ['honest', 'college', 'tour'],
#  ['world', 'of', 'walker', 'trailer'],
#  ['the', 'internet', 'made', 'me', 'cry', 'again'],
#  ['selena', 'gomez', 'hand', 'in', 'hand'],
#  ['iphone', 'x', 'hands', 'on', 'live', 'from', 'apple', 'event'],
#  ['kid', 'rock', 'tennessee', 'mountain', 'top', 'lyrics'],
#  ['juicy', 'chicken', 'breast', 'you', 'suck', 'at', 'cooking', 'episode'],
#  ['downsizing', 'official', 'trailer', 'paramount', 'pictures'],
#  ['i',
#   'm',
#   'sorry',
#   'for',
#   'my',
#   'racial',
#   'slurs',
#   'about',
#   'the',
#   'finnish'],
#  ['usher',
#   'and',
#   'blake',
#   'shelton',
#   'stand',
#   'by',
#   'me',
#   'hand',
#   'in',
#   'hand',
#   'a',
#   'benefit',
#   'for',
#   'hurricane',
#   'relief',
#   'mtv'],
#  ['getting',
#   'into',
#   'a',
#   'conversation',
#   'in',
#   'a',
#   'language',
#   'you',
#   'don',
#   't',
#   'actually',
#   'speak',
#   'that',
#   'well'],
#  ['demi',
#   'lovato',
#   'performing',
#   'with',
#   'a',
#   'little',
#   'help',
#   'from',
#   'my',
#   'friends',
#   'at',
#   'hand',
#   'in',
#   'hand',
#   'september'],
#  ['radiohead', 'lift'],
#  ['weezer', 'beach', 'boys'],
#  ['doom', 'and', 'wolfenstein', 'for', 'switch', 'announcement', 'trailer'],
#  ['crowder', 'prove', 'it', 'ft', 'kb'],
#  ['what', 's', 'actually', 'the', 'plane', 'of', 'the', 'future'],
#  ['enter', 'shikari', 'rabble', 'rouser', 'official', 'promo', 'video'],
#  ['superfruit', 'reacts', 'to', 'teens', 'react', 'to', 'superfruit'],
#  ['nerf', 'bow', 'trick', 'shots', 'dude', 'perfect'],
#  ['damage',
#   'from',
#   'hurricane',
#   'irma',
#   'at',
#   'the',
#   'magic',
#   'kingdom',
#   'walt',
#   'disney',
#   'world'],
#  ['million', 'subscribers', 'struggling', 'still', 'smiling'],
#  ['blind', 'people', 'describe', 'beauty'],
#  ['imagine',
#   'dragons',
#   'whatever',
#   'it',
#   'takes',
#   'version',
#   'lyric',
#   'vide',
#   'o'],
#  ['x',
#   'extreme',
#   'spicy',
#   'noodle',
#   'car',
#   'ride',
#   'i',
#   'cried',
#   'ranz',
#   'and',
#   'niana'],
#  ['mystery',
#   'van',
#   'helping',
#   'self',
#   'driving',
#   'cars',
#   'communicate',
#   'with',
#   'people',
#   'autonomy',
#   'ford'],
#  ['action',
#   'bronson',
#   'and',
#   'sean',
#   'evans',
#   'have',
#   'a',
#   'sandwich',
#   'showdown',
#   'judged',
#   'by',
#   'mario',
#   'batali',
#   'sean',
#   'in',
#   'the',
#   'wild'],
#  ['everything',
#   'wrong',
#   'with',
#   'alien',
#   'covenant',
#   'in',
#   'minutes',
#   'or',
#   'less'],
#  ['更なるフィット感を追求するねこ', 'maru', 'wishes', 'for', 'more', 'fitting', 'feeling'],
#  ['what', 's', 'in', 'this', 's', 'mystery', 'caboodle'],
#  ['the', 'commuter', 'teaser', 'trailer', 'movieclips', 'trailers'],
#  ['here', 's', 'why', 'the', 'lexus', 'lc', 'costs'],
#  ['joe', 'arpaio', 'last', 'week', 'tonight', 'with', 'john', 'oliver', 'hbo'],
#  ['get', 'more', 'ellen', 'with', 'ellen', 's', 'show', 'me', 'more', 'show'],
#  ['jumping', 'through', 'impossible', 'shapes'],
#  ['genesis', 'ibex', 'and', 'cassini', 'scishow', 'talk', 'show'],
#  ['from',
#   'the',
#   'air',
#   'irma',
#   's',
#   'catastrophic',
#   'wrath',
#   'is',
#   'undeniable'],
#  ['what', 'i', 'wore', 'new', 'york', 'fashion', 'week'],
#  ['lany', 'super', 'far', 'official', 'video'],
#  ['houston',
#   'attorney',
#   'tony',
#   'buzbee',
#   'drops',
#   'a',
#   'tank',
#   'on',
#   'river',
#   'oaks',
#   'blvd'],
#  ['cassini',
#   'burns',
#   'into',
#   'saturn',
#   'after',
#   'grand',
#   'finale',
#   'out',
#   'there'],
#  ['jennifer',
#   'lawrence',
#   'tore',
#   'her',
#   'diaphragm',
#   'while',
#   'filming',
#   'mother'],
#  ['vlogtember', 'nyc', 'running', 'around', 'heyclaire'],
#  ['answering', 'your', 'questions', 'qandgay'],
#  ['drowning', 'for', 'power', 'rooster', 'teeth', 'animated', 'adventures'],
#  ['im', 'gonna', 'be', 'a', 'father', 'things', 'got', 'awkward'],
#  ['don',
#   'lemon',
#   'praises',
#   'chunky',
#   'cnn',
#   'reporter',
#   'facing',
#   'irma',
#   'wrath',
#   'nothing',
#   'wrong',
#   'with',
#   'a',
#   'little',
#   'curve'],
#  ['fenty',
#   'beauty',
#   'pro',
#   'filt',
#   'r',
#   'foundation',
#   'review',
#   'nyma',
#   'tang',
#   'thedarkestshade'],
#  ['season', 'preview', 'white', 'people', 'renovating', 'houses'],
#  ['how',
#   'to',
#   'make',
#   'lloyd',
#   'from',
#   'the',
#   'new',
#   'lego',
#   'ninjago',
#   'movie',
#   'out',
#   'of',
#   'cake',
#   'yolanda',
#   'gampp',
#   'how',
#   'to',
#   'cake',
#   'it'],
#  ['delicious',
#   'chocolate',
#   'cupcakes',
#   'in',
#   'minutes',
#   'the',
#   'scran',
#   'line'],
#  ['galen', 'hooks', 'wait', 'for', 'me', 'a', 'galen', 'hooks', 'film'],
#  ['blueborne', 'android', 'take', 'over', 'demo'],
#  ['queen', 'live', 'aid', 'part', 'high', 'quality'],
#  ['fenty', 'beauty', 'by', 'rihanna', 'review', 'wear', 'test'],
#  ['hurricane', 'jose', 'a', 'm', 'advisory'],
#  ['rudimental',
#   'sun',
#   'comes',
#   'up',
#   'feat',
#   'james',
#   'arthur',
#   'official',
#   'video'],
#  ['how', 'to', 'photograph', 'incredible', 'architecture'],
#  ['chocolate', 'chip', 'cookie', 'cupcakes', 'nerdy', 'nummies'],
#  ['apple', 'watch', 'series', 'hands', 'on'],
#  ['harry',
#   'styles',
#   'the',
#   'chain',
#   'fleetwood',
#   'mac',
#   'cover',
#   'in',
#   'the',
#   'live',
#   'lounge'],
#  ['james', 'tw', 'please', 'keep', 'loving', 'me'],
#  ['obsessed', 'with', 'netflix'],
#  ['willow', 's', 'birthday'],
#  ['tommy',
#   'wiseau',
#   'on',
#   'why',
#   'james',
#   'franco',
#   'was',
#   'perfect',
#   'for',
#   'the',
#   'disaster',
#   'artist',
#   'los',
#   'angeles',
#   'times'],
#  ['real', 'clowns', 'creepier', 'than', 'pennywise', 'from', 'it'],
#  ['things', 'you', 'need', 'to', 'know', 'about', 'pennywise'],
#  ['blind', 'taste', 'test', 'grace', 'helbig'],
#  ['iphone',
#   'x',
#   'walkthrough',
#   'animoji',
#   'face',
#   'id',
#   'portrait',
#   'mode',
#   'lighting',
#   'effects',
#   'more'],
#  ['last', 'week', 'tonight', 'with', 'john', 'oliver', 'se', 'sep'],
#  ['big', 'announcement', 'on', 'my', 'popscicle'],
#  ['fall',
#   'makeup',
#   'tutorial',
#   'talk',
#   'through',
#   'tutorial',
#   'casey',
#   'holmes'],
#  ['fifty', 'shades', 'freed', 'teaser', 'hd'],
#  ['qb', 'turned', 'psychic', 'tony', 'romo', 'predicts', 'future'],
#  ['tying', 'a', 'shoe'],
#  ['how',
#   'kanye',
#   'west',
#   's',
#   'graduation',
#   'changed',
#   'music',
#   'genius',
#   'news'],
#  ['seafood', 'vs', 'seafood', 'australia'],
#  ['interview', 'with', 'a', 'runaway', 'toddler'],
#  ['fail',
#   'new',
#   'estee',
#   'lauder',
#   'double',
#   'wear',
#   'nude',
#   'first',
#   'impression',
#   'review',
#   'demo',
#   'days',
#   'of',
#   'foundation'],
#  ['storm',
#   'chaser',
#   'battles',
#   'hurricane',
#   'irma',
#   's',
#   'powerful',
#   'winds',
#   'nbc',
#   'news'],
#  ['jim',
#   'carrey',
#   'sounds',
#   'off',
#   'on',
#   'icons',
#   'and',
#   'more',
#   'at',
#   'nyfw',
#   'e',
#   'live',
#   'from',
#   'the',
#   'red',
#   'carpet'],
#  ['jim',
#   'carrey',
#   's',
#   'bizarre',
#   'fashion',
#   'week',
#   'interview',
#   'daily',
#   'pop',
#   'e',
#   'news'],
#  ['here', 's', 'what', 'happens', 'when', 'two', 'hurricanes', 'collide'],
#  ['hillary', 'clinton', 'speaks'],
#  ['kirstin', 'bad', 'weather', 'official', 'video'],
#  ['creativity', 'gets', 'you', 'noticed', 'feat', 'tango', 'squad', 'adidas'],
#  ['game', 'revealed', 'season', 'episode', 'a', 'goodbye', 'kiss'],
#  ['can',
#   'you',
#   'assume',
#   'sexuality',
#   'based',
#   'on',
#   'a',
#   'first',
#   'impression',
#   'tell',
#   'my',
#   'story'],
#  ['drone',
#   'captures',
#   'aftermath',
#   'of',
#   'hurricane',
#   'irma',
#   'in',
#   'naples',
#   'florida'],
#  ['iphone', 'hands', 'on', 'don', 't', 'overlook', 'this', 'big', 'update'],
#  ['how',
#   'computers',
#   'compress',
#   'text',
#   'huffman',
#   'coding',
#   'and',
#   'huffman',
#   'trees'],
#  ['the', 'constitution', 'of', 'the', 'spartans'],
#  ['minelli', 'empty', 'spaces', 'official', 'video', 'ultra', 'music'],
#  ['larry',
#   's',
#   'back',
#   'nothing',
#   'has',
#   'changed',
#   'curb',
#   'your',
#   'enthusiasm',
#   'season',
#   'trailer',
#   'hbo'],
#  ['casually',
#   'explained',
#   'is',
#   'she',
#   'into',
#   'you',
#   'ii',
#   'what',
#   's',
#   'the',
#   'worst',
#   'that',
#   'could',
#   'happen'],
#  ['wolf', 'alice', 'beautifully', 'unconventional'],
#  ['hurricane', 'size', 'comparison'],
#  ['i', 'bought', 'an', 'entire', 'outfit', 'blindfolded'],
#  ['internet',
#   'trending',
#   'dance',
#   'challenge',
#   'with',
#   'megan',
#   'batoon',
#   'youtube',
#   'challenges',
#   'refinery'],
#  ['it', 'scores', 'biggest', 'horror', 'opening', 'ever', 'movie', 'talk'],
#  ['easy', 'magic', 'tricks', 'anyone', 'can', 'do'],
#  ['winch', 'bot', 'scanlime'],
#  ['essential',
#   'phone',
#   'drop',
#   'test',
#   'titanium',
#   'and',
#   'ceramic',
#   'vs',
#   'gravity'],
#  ['bts', 'singing', 'closer', 'with', 'the', 'chainsmokers'],
#  ['if', 'bioshock', 'was', 'made', 'in'],
#  ['parcour', 'part', 'road', 'to', 'olympics', 'andri', 'ragettli'],
#  ['a',
#   'moment',
#   'of',
#   'silence',
#   'at',
#   'the',
#   'national',
#   'memorial',
#   'museum'],
#  ['try',
#   'on',
#   'fall',
#   'haul',
#   'fashion',
#   'drugstore',
#   'makeup',
#   'ingrid',
#   'nilsen'],
#  ['san', 'cisco', 'the', 'distance', 'official', 'music', 'video'],
#  ['wet', 'book', 'rescue'],
#  ['viral',
#   'instagram',
#   'makeup',
#   'trends',
#   'wavy',
#   'eyebrows',
#   'tested',
#   'alisha',
#   'marie'],
#  ['injured',
#   'in',
#   'explosion',
#   'on',
#   'london',
#   'subway',
#   'train',
#   'at',
#   'parsons',
#   'green',
#   'underground',
#   'station',
#   'time'],
#  ['shakira', 'perro', 'fiel', 'official', 'video', 'ft', 'nicky', 'jam'],
#  ['the', 'insane', 'full', 'house', 'theory', 'that', 'might', 'be', 'true'],
#  ['fuller', 'house', 'season', 'official', 'trailer', 'hd', 'netflix'],
#  ['burning',
#   'device',
#   'filmed',
#   'on',
#   'tube',
#   'carriage',
#   'at',
#   'parsons',
#   'green',
#   'station'],
#  ['reasons', 'not', 'to', 'buy', 'iphone', 'x'],
#  ['funny', 'you', 'should', 'ask'],
#  ['jennifer',
#   'lawrence',
#   'got',
#   'into',
#   'a',
#   'bar',
#   'fight',
#   'in',
#   'budapest'],
#  ['the', 'shape', 'of', 'water', 'red', 'band', 'trailer'],
#  ['colbert', 'reveals', 'what', 'letterman', 'taught', 'him'],
#  ['facing', 'my', 'anxiety'],
#  ['all', 'the', 'money', 'in', 'the', 'world', 'official', 'trailer', 'hd'],
#  ['nf', 'let', 'you', 'down', 'audio'],
#  ['my', 'butt', 'has', 'some', 'complaints', 'about', 'australia'],
#  ['mother', 'movie', 'review'],
#  ['how', 'the', 'triplet', 'flow', 'took', 'over', 'rap'],
#  ['fall',
#   'essentials',
#   'you',
# ...
#  ['apple', 'watch', 'series', 'hands', 'on'],
#  ['fenty',
#   'beauty',
#   'pro',
#   'filt',
#   'r',
#   'foundation',
#   'review',
#   'nyma',
#   'tang',
#   'thedarkestshade'],
#  ['bonnie', 'mckee', 'thorns'],
#  ['blueborne', 'android', 'take', 'over', 'demo'],
#  ['make', 'it', 'real', 'kingsman', 'umbrella', 'gun'],
#  ['how',
#   'to',
#   'make',
#   'lloyd',
#   'from',
#   'the',
#   'new',
#   'lego',
#   'ninjago',
#   'movie',
#   'out',
#   'of',
#   'cake',
#   'yolanda',
#   'gampp',
#   'how',
#   'to',
#   'cake',
#   'it'],
#  ['fenty', 'beauty', 'by', 'rihanna', 'review', 'wear', 'test'],
#  ['don',
#   'lemon',
#   'praises',
#   'chunky',
#   'cnn',
#   'reporter',
#   'facing',
#   'irma',
#   'wrath',
#   'nothing',
#   'wrong',
#   'with',
#   'a',
#   'little',
#   'curve'],
#  ['day', 'at', 'the', 'beach', 'mayor', 'steve', 'fulop'],
#  ['delicious',
#   'chocolate',
#   'cupcakes',
#   'in',
#   'minutes',
#   'the',
#   'scran',
#   'line'],
#  ['mondeo',
#   'driver',
#   'desperate',
#   'to',
#   'overtake',
#   'just',
#   'to',
#   'get',
#   'stuck',
#   'in',
#   'traffic'],
#  ['the', 'try', 'guys', 'get', 'makeovers', 'from', 'high', 'school', 'girls'],
#  ['the', 'jake', 'paulers', 'song', 'official', 'music', 'video'],
#  ['the', 'insane', 'full', 'house', 'theory', 'that', 'might', 'be', 'true'],
#  ['shakira', 'perro', 'fiel', 'official', 'video', 'ft', 'nicky', 'jam'],
#  ['pure', 'uncut', 'holo', 'not', 'drugz', 'for', 'nails'],
#  ['injured',
#   'in',
#   'explosion',
#   'on',
#   'london',
#   'subway',
#   'train',
#   'at',
#   'parsons',
#   'green',
#   'underground',
#   'station',
#   'time'],
#  ['rick', 'and', 'morty', 'has', 'rick', 'changed'],
#  ['why', 'does', 'the', 'mac', 'mini', 'exist', 'in'],
#  ['bf', 'gf', 'prank', 'wars', 'have', 'begun'],
#  ['vampy', 'fall', 'look', 'new', 'makeup', 'nicole', 'guerriero'],
#  ['fuller', 'house', 'season', 'official', 'trailer', 'hd', 'netflix'],
#  ['how', 'the', 'cast', 'of', 'it', 'should', 'really', 'look'],
#  ['the', 'perfect', 'proposal', 'lele', 'pons', 'anwar', 'jibawi'],
#  ['we', 'need', 'to', 'talk'],
#  ['live',
#   'stream',
#   'canelo',
#   'vs',
#   'golovkin',
#   'official',
#   'weigh',
#   'in',
#   'friday',
#   'sept',
#   'at',
#   'pm',
#   'et',
#   'pm',
#   'pt'],
#  ['reasons', 'not', 'to', 'buy', 'iphone', 'x'],
#  ['match', 'highlights', 'watford', 'v', 'man', 'city'],
#  ['new',
#   'burts',
#   'bees',
#   'goodness',
#   'glows',
#   'foundation',
#   'first',
#   'impression',
#   'demo',
#   'days',
#   'of',
#   'foundation'],
#  ['diy', 'fruit', 'flavored', 'cupcakes'],
#  ['full',
#   'canelo',
#   'alvarez',
#   'vs',
#   'gennady',
#   'golovkin',
#   'weigh',
#   'in',
#   'espn'],
#  ['burning',
#   'device',
#   'filmed',
#   'on',
#   'tube',
#   'carriage',
#   'at',
#   'parsons',
#   'green',
#   'station'],
#  ['miley', 'cyrus', 'see', 'you', 'again', 'in', 'the', 'live', 'lounge'],
#  ['playing', 'with', 'magic', 'makeup', 'nikkietutorials'],
#  ['conanisrael', 'sneak', 'peak', 'gal', 'gadot', 'conan', 'on', 'tbs'],
#  ['jennifer',
#   'lawrence',
#   'got',
#   'into',
#   'a',
#   'bar',
#   'fight',
#   'in',
#   'budapest'],
#  ['is', 'it', 'a', 'scam', 'shein', 'try', 'on', 'haul'],
#  ['funny', 'you', 'should', 'ask'],
#  ['colbert', 'reveals', 'what', 'letterman', 'taught', 'him'],
#  ['the', 'shape', 'of', 'water', 'red', 'band', 'trailer'],
#  ['nf', 'let', 'you', 'down', 'audio'],
#  ['my', 'butt', 'has', 'some', 'complaints', 'about', 'australia'],
#  ['how', 'the', 'triplet', 'flow', 'took', 'over', 'rap'],
#  ['mother', 'movie', 'review'],
#  ['all', 'the', 'money', 'in', 'the', 'world', 'official', 'trailer', 'hd'],
#  ['watermelon', 'freakshake', 'cupcakes', 'the', 'scran', 'line'],
#  ['facing', 'my', 'anxiety'],
#  ['a', 'few', 'words', 'on', 'chile', 'joanna', 'rants'],
#  ['yo', 'gotti', 'ft', 'nicki', 'minaj', 'rake', 'it', 'up'],
#  ['kingsman',
#   'the',
#   'golden',
#   'circle',
#   'that',
#   'dog',
#   'don',
#   't',
#   'hunt',
#   'clip',
#   'th',
#   'century',
#   'fox'],
#  ['my', 'boyfriend', 'buys', 'my', 'outfits'],
#  ['drawing',
#   'weird',
#   'australian',
#   'phrases',
#   'feat',
#   'draw',
#   'with',
#   'jazza',
#   'mate'],
#  ['harry',
#   'potter',
#   'theory',
#   'voldemort',
#   's',
#   'full',
#   'tri',
#   'wizard',
#   'cup',
#   'plan'],
#  ['cassini', 's', 'last', 'looks', 'at', 'saturn'],
#  ['will',
#   'john',
#   'wick',
#   'be',
#   'able',
#   'to',
#   'hold',
#   'off',
#   'the',
#   'avengers',
#   'sju'],
#  ['parsons', 'green', 'there', 'was', 'a', 'human', 'stampede', 'bbc', 'news'],
#  ['niall', 'horan', 'too', 'much', 'to', 'ask', 'audio'],
#  ['i', 'ordered', 'the', 'first', 'free', 'things', 'from', 'wish'],
#  ['my', 'day', 'at', 'apple', 'with', 'the', 'new', 'iphone', 'x'],
#  ['people', 'are', 'awesome', 'girls', 'edition'],
#  ['the', 'it', 'department'],
#  ['aaron', 'carter', 's', 'hiv', 'test', 'results', 'revealed'],
#  ['london', 'police', 'investigate', 'explosion', 'on', 'train'],
#  ['lego',
#   'ultimate',
#   'collectors',
#   'series',
#   'millennium',
#   'falcon',
#   'review'],
#  ['how', 'not', 'to', 'land', 'an', 'orbital', 'rocket', 'booster'],
#  ['back', 'to', 'school', 'outfit', 'ideas', 'grace', 'helbig'],
#  ['carly', 'rae', 'jepsen', 'cut', 'to', 'the', 'feeling'],
#  ['chris', 'young', 'losing', 'sleep'],
#  ['life', 'after', 'hate', 'september', 'act', 'full', 'frontal', 'on', 'tbs'],
#  ['how',
#   'jay',
#   'z',
#   'pays',
#   'homage',
#   'to',
#   'hispanic',
#   'culture',
#   'in',
#   'his',
#   'lyrics',
#   'genius',
#   'news'],
#  ['grace', 'vanderwaal', 'just', 'the', 'beginning'],
#  ['the', 'road', 'to', 'live'],
#  ['machine', 'gun', 'kelly', 'let', 'you', 'go'],
#  ['thomas',
#   'rhett',
#   'bobby',
#   'bones',
#   'surprise',
#   'fans',
#   'with',
#   'life',
#   'changes'],
#  ['game',
#   'of',
#   'thrones',
#   'conquest',
#   'rebellion',
#   'an',
#   'animated',
#   'history',
#   'of',
#   'the',
#   'seven',
#   'kingdoms',
#   'clip'],
#  ['miley',
#   'cyrus',
#   'talks',
#   'vmas',
#   'music',
#   'and',
#   'america',
#   'in',
#   'at',
#   'rainbowland'],
#  ['fenty', 'beauty', 'hot', 'or', 'hmmm', 'jackie', 'aina'],
#  ['dillon',
#   'francis',
#   'hurts',
#   'his',
#   'body',
#   'with',
#   'spicy',
#   'wings',
#   'hot',
#   'ones'],
#  ['hello',
#   'world',
#   'meet',
#   'our',
#   'baby',
#   'girl',
#   'alexis',
#   'olympia',
#   'ohanian',
#   'jr'],
#  ['bts', '방탄소년단', 'dna', 'official', 'teaser'],
#  ['fall', 'out', 'boy', 'the', 'last', 'of', 'the', 'real', 'ones'],
#  ['trapped', 'in', 'a', 'snake', 'tank', 'pt', 'ft', 'boa', 'constrictor'],
#  ['alexa', 'guess', 'my', 'number'],
#  ['did',
#   'i',
#   'really',
#   'buy',
#   'shoes',
#   'on',
#   'ebay',
#   'yeezys',
#   'valentino',
#   'and',
#   'straight',
#   'up',
#   'copies'],
#  ['everytime',
#   'the',
#   'beat',
#   'drops',
#   'with',
#   'the',
#   'chainsmokers',
#   'ranz',
#   'and',
#   'niana'],
#  ['adelaine',
#   'morin',
#   's',
#   'hello',
#   'yellow',
#   'bedroom',
#   'makeover',
#   'omg',
#   'we',
#   're',
#   'coming',
#   'over',
#   'mr',
#   'kate'],
#  ['it', 'pennywise', 'glam', 'halloween', 'makeup', 'tutorial'],
#  ['nyfw', 'limo', 'rides', 'a', 'big', 'unboxing', 'carli', 'bybel'],
#  ['fall',
#   'essentials',
#   'you',
#   'need',
#   'beauty',
#   'lifestyle',
#   'casey',
#   'holmes'],
#  ['norm', 'macdonald', 'is', 'a', 'comic', 'genius'],
#  ['julien', 'baker', 'appointments', 'official', 'video'],
#  ['lethal', 'bizzle', 'teaches', 'dame', 'judi', 'dench', 'how', 'to', 'rap'],
#  ['blindfold', 'gymnastics', 'challenge'],
#  ['jiggly',
#   'cheese',
#   'cake',
#   'redo',
#   'reading',
#   'mean',
#   'inspiring',
#   'comments'],
#  ['behind',
#   'the',
#   'scenes',
#   'subaru',
#   'wrx',
#   'sti',
#   'type',
#   'ra',
#   'nbr',
#   'special',
#   'nurburgring'],
#  ['dua', 'lipa', 'x', 'gallant', 'in', 'the', 'room', 'episode'],
#  ['welcome', 'baby', 'taika'],
#  ['what',
#   'will',
#   'you',
#   'be',
#   'turned',
#   'into',
#   'in',
#   'space',
#   'in',
#   'seconds',
#   'without',
#   'a',
#   'spacesuit'],
#  ['official',
#   'us',
#   'find',
#   'your',
#   'voice',
#   'trailer',
#   'disney',
#   'pixar',
#   's',
#   'coco'],
#  ['optical', 'illusions'],
#  ['close', 'look', 'at', 'victoria', 'beckham', 'make', 'up', 'products'],
#  ['the',
#   'strangest',
#   'sights',
#   'cassini',
#   'saw',
#   'postcards',
#   'from',
#   'saturn',
#   'npr',
#   's',
#   'skunk',
#   'bear'],
#  ['kph',
#   'water',
#   'rocket',
#   'trike',
#   'ǀ',
#   'kph',
#   'in',
#   'second',
#   'g',
#   'ǀ',
#   'rider',
#   'françois',
#   'gissy'],
#  ['why', 'we', 'eat', 'too', 'much'],
#  ['lana', 'del', 'rey', 'white', 'mustang', 'official', 'video'],
#  ['x', 'ambassadors', 'ahead', 'of', 'myself'],
#  ['bella',
#   'hadid',
#   'roughs',
#   'up',
#   'security',
#   'roughing',
#   'up',
#   'female',
#   'photog',
#   'tmz'],
#  ['the', 'impossible', 'big', 'mac', 'challenge', 'destroyed'],
#  ['gregg', 'sulkin', 'for', 'raw', 's', 'word', 'play'],
#  ['jennifer',
#   'lawrence',
#   'my',
#   'new',
#   'horror',
#   'film',
#   'mother',
#   'is',
#   'an',
#   'assault',
#   'today'],
#  ['soy',
#   'pablo',
#   'extended',
#   'trailer',
#   'a',
#   'bad',
#   'lip',
#   'reading',
#   'of',
#   'narcos',
#   'a',
#   'netflix',
#   'original',
#   'series'],
#  ['toni', 'braxton', 'deadwood', 'audio'],
#  ['automatica', 'k', 'robots', 'vs', 'music', 'nigel', 'stanford'],
#  ['hell', 'yes'],
#  ['the', 'fast', 'and', 'the', 'furious', 'parody', 'goodbye', 'scene'],
#  ['get', 'ready', 'with', 'me', 'ft', 'old', 'friend'],
#  ['iphone', 'x', 'introducing', 'iphone', 'x', 'apple'],
#  ['year',
#   'old',
#   'bodybuilder',
#   'william',
#   'reed',
#   'sees',
#   'color',
#   'for',
#   'first',
#   'time'],
#  ['teyana',
#   'taylor',
#   'tells',
#   'all',
#   'about',
#   'boob',
#   'surgery',
#   'and',
#   'says',
#   'kanye',
#   'is',
#   'back'],
#  ['victoria', 'beckham', 'collection', 'hot', 'or', 'not'],
#  ['aly', 'aj', 'take', 'me'],
#  ['kelly', 'clarkson', 'talks', 'american', 'idol', 'dr', 'luke', 'interview'],
#  ['viral',
#   'video',
#   'uk',
#   'geese',
#   'bodyguards',
#   'help',
#   'a',
#   'hedgehog',
#   'cross',
#   'road'],
#  ['spiked', 'by', 'a', 'sea', 'urchin'],
#  ['car', 'hits', 'cyclist', 'in', 'east', 'flatbush'],
#  ['year',
#   'of',
#   'vlogging',
#   'how',
#   'logan',
#   'paul',
#   'changed',
#   'youtube',
#   'forever'],
#  ['adam',
#   'ruins',
#   'everything',
#   'the',
#   'messed',
#   'up',
#   'story',
#   'of',
#   'how',
#   'hawaii',
#   'became',
#   'a',
#   'state',
#   'trutv'],
#  ['apple', 'iphone', 'x', 'first', 'look'],
#  ['inside', 'the', 'world', 's', 'smelliest', 'factory'],
#  ['weezer', 'beach', 'boys'],
#  ['nicki',
#   'minaj',
#   'surprises',
#   'nas',
#   'celebrating',
#   'his',
#   'rd',
#   'birthday',
#   'party',
#   'with',
#   'swizz',
#   'beatz'],
#  ['cream', 'cheese', 'stuffed', 'pumpkin', 'muffins', 'episode'],
#  ['riverdale', 'motive', 'trailer', 'the', 'cw'],
#  ['red', 'velvet', 'cupcakes', 'as', 'made', 'by', 'kevin', 'durant'],
#  ['lore', 'official', 'trailer', 'hd', 'amazon', 'video'],
#  ['learn', 'to', 'stack', 'dice', 'learn', 'quick'],
#  ['jacob', 'banks', 'unknown', 'to', 'you', 'audio'],
#  ['the', 'day', 'longest', 'flight', 'in', 'history'],
#  ['the',
#   'opposition',
#   'w',
#   'jordan',
#   'klepper',
#   'opposing',
#   'the',
#   'resistance',
#   'in',
#   'phoenix'],
#  ['hand', 'in', 'hand', 'a', 'benefit', 'for', 'hurricane', 'relief', 'mtv'],
#  ['dl', 'hughley', 'on', 'espn', 'jemele', 'hill', 'controversy'],
#  ['my', 'response'],
#  ['iphone', 'x', 'parody'],
#  ['alex',
#   'aiono',
#   'trinidad',
#   'cardona',
#   'does',
#   'it',
#   'feel',
#   'like',
#   'falling',
#   'audio'],
#  ['the', 'xx', 'on', 'hold', 'jamie', 'xx', 'remix'],
#  ['not',
#   'enough',
#   'milk',
#   'my',
#   'breastfeeding',
#   'journey',
#   'tips',
#   'momtember'],
#  ['craig', 'david', 'heartline', 'audio'],
#  ['hudson',
#   'moore',
#   'just',
#   'wanna',
#   'love',
#   'you',
#   'official',
#   'music',
#   'video'],
#  ['we', 'need', 'to', 'talk'],
#  ['bell', 's', 'theorem', 'the', 'quantum', 'venn', 'diagram', 'paradox'],
#  ['r', 'hurts', 'good', 'audio', 'only'],
#  ['tori',
#   'kelly',
#   'luis',
#   'fonsi',
#   'hallelujah',
#   'hand',
#   'in',
#   'hand',
#   'benefit'],
#  ['will', 'grace', 'journey', 'to', 'now', 'digital', 'exclusive'],
#  ['angelica',
#   'hale',
#   'year',
#   'old',
#   'singer',
#   'blows',
#   'the',
#   'audience',
#   'away',
#   'america',
#   's',
#   'got',
#   'talent'],
#  ['depeche', 'mode', 'cover', 'me'],
#  ['weight', 'update', 'weeks', 'post', 'surgery', 'pounds'],
#  ['fergie', 'you', 'already', 'know', 'ft', 'nicki', 'minaj'],
#  ['the', 'disaster', 'artist', 'official', 'trailer', 'hd', 'a'],
#  ['what', 'to', 'eat', 'in', 'melbourne'],
#  ['does',
#   'maggie',
#   'gyllenhaal',
#   'have',
#   'taylor',
#   'swift',
#   's',
#   'scarf',
#   'wwhl'],
#  ['best',
#   'mic',
#   'd',
#   'up',
#   'sounds',
#   'of',
#   'week',
#   'sound',
#   'fx',
#   'nfl',
#   'films'],
#  ['the', 'internet', 'made', 'me', 'cry', 'again'],
#  ['emmalyn', 'self', 'care', 'official', 'music', 'video'],
#  ['iphone', 'x', 'iphone', 'hands', 'on'],
#  ['full',
#   'face',
#   'of',
#   'first',
#   'impressions',
#   'fenty',
#   'beauty',
#   'too',
#   'faced',
#   'ysl',
#   'more'],
#  ['king', 'krule', 'dum', 'surfer'],
#  ['couple', 's', 'first', 'merch'],
#  ['james', 'tw', 'please', 'keep', 'loving', 'me'],
#  ['best', 'floyd', 'mayweather', 'interview', 'awkward', 'puppets'],
#  ['iphone', 'x', 'face', 'id', 'unlock', 'fail'],
#  ['s',
#   'mores',
#   'alaska',
#   'with',
#   'italian',
#   'meringue',
#   'plus',
#   'a',
#   'special',
#   'announcement',
#   'cupcake',
#   'jemma'],
#  ['boyfriend', 'buys', 'my', 'outfits'],
#  ['what', 'do', 'you', 'want', 'to', 'eat'],
#  ['film',
#   'theory',
#   'ariel',
#   'is',
#   'related',
#   'to',
#   'hercules',
#   'disney',
#   's',
#   'connected',
#   'universe'],
#  ['million', 'subscribers', 'struggling', 'still', 'smiling'],
#  ['husker', 'du', 'sorry', 'somehow'],
#  ['honest', 'college', 'tour'],
#  ['iphone',
#   'x',
#   'vs',
#   'iphone',
#   'hands',
#   'on',
#   'what',
#   's',
#   'the',
#   'difference'],
#  ['stone',
#   'sour',
#   'rose',
#   'red',
#   'violent',
#   'blue',
#   'this',
#   'song',
#   'is',
#   'dumb',
#   'so',
#   'am',
#   'i',
#   'official',
#   'video'],
#  ['honest', 'trailers', 'the', 'mummy'],
#  ['enter', 'shikari', 'rabble', 'rouser', 'official', 'promo', 'video'],
#  ['léon', 'i', 'believe', 'in', 'us', 'audio'],
#  ['kid', 'rock', 'tennessee', 'mountain', 'top', 'lyrics'],
#  ['mystery',
#   'van',
#   'helping',
#   'self',
#   'driving',
#   'cars',
#   'communicate',
#   'with',
#   'people',
#   'autonomy',
#   'ford'],
#  ['world', 'of', 'walker', 'trailer'],
#  ['crowder', 'prove', 'it', 'ft', 'kb'],
#  ['iphone', 'x', 'hands', 'on', 'live', 'from', 'apple', 'event'],
#  ['get', 'more', 'ellen', 'with', 'ellen', 's', 'show', 'me', 'more', 'show'],
#  ['riverdale', 'between', 'the', 'scenes', 'madelaine', 'petsch'],
#  ['sarah',
#   'sanders',
#   'espn',
#   's',
#   'jemele',
#   'hill',
#   'committed',
#   'fireable',
#   'offense'],
#  ['radiohead', 'lift'],
#  ['replay', 'day', 'hot', 'rod', 'drag', 'week', 'from', 'byron', 'dragway'],
#  ['nerf', 'bow', 'trick', 'shots', 'dude', 'perfect'],
#  ['grant', 'hart', 'e', 'p', 'version'],
#  ['juicy', 'chicken', 'breast', 'you', 'suck', 'at', 'cooking', 'episode'],
#  ['imagine',
#   'dragons',
#   'whatever',
#   'it',
#   'takes',
#   'version',
#   'lyric',
#   'vide',
#   'o'],
#  ['x',
#   'extreme',
#   'spicy',
#   'noodle',
#   'car',
#   'ride',
#   'i',
#   'cried',
#   'ranz',
#   'and',
#   'niana'],
#  ['cassini',
#   'burns',
#   'into',
#   'saturn',
#   'after',
#   'grand',
#   'finale',
#   'out',
#   'there'],
#  ['downsizing', 'official', 'trailer', 'paramount', 'pictures'],
#  ['superfruit', 'reacts', 'to', 'teens', 'react', 'to', 'superfruit'],
#  ['demi',
#   'lovato',
#   'performing',
#   'with',
#   'a',
#   'little',
#   'help',
#   'from',
#   'my',
#   'friends',
#   'at',
#   'hand',
#   'in',
#   'hand',
#   'september'],
#  ['everything',
#   'wrong',
#   'with',
#   'alien',
#   'covenant',
#   'in',
#   'minutes',
#   'or',
#   'less'],
#  ['getting',
#   'into',
#   'a',
#   'conversation',
#   'in',
#   'a',
#   'language',
#   'you',
#   'don',
#   't',
#   'actually',
#   'speak',
#   'that',
#   'well'],
#  ['blind', 'people', 'describe', 'beauty'],
#  ['building',
#   'a',
#   'high',
#   'capacity',
#   'battery',
#   'bank',
#   'using',
#   'my',
#   'diy',
#   'tab',
#   'welder'],
#  ['what', 's', 'actually', 'the', 'plane', 'of', 'the', 'future'],
#  ['lany', 'super', 'far', 'official', 'video'],
#  ['from',
#   'the',
#   'air',
#   'irma',
#   's',
#   'catastrophic',
#   'wrath',
#   'is',
#   'undeniable'],
#  ['big',
#   'jb',
#   'weld',
#   'diamond',
#   'coring',
#   'bit',
#   'workshop',
#   'fabricobblin',
#   'fun'],
#  ['i',
#   'm',
#   'sorry',
#   'for',
#   'my',
#   'racial',
#   'slurs',
#   'about',
#   'the',
#   'finnish'],
#  ['vlogtember', 'nyc', 'running', 'around', 'heyclaire'],
#  ...]

# %%
only_title = df['title']
title_data = only_title

title_data = title_data.str.replace("[^\w]", " ")
#혹시나 공백이 있으면
title_data= title_data.replace('', np.nan)

#결측치 있으면 모두 제거
title_data = title_data.dropna(how='any')

# %% [markdown]
# ### Stopwords 제거 (NLTK corpus stopwords 이용)

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

stop_words = set(stopwords.words('english')) 
cleaned_titles = []
words_list = []
for title in titles_list:
    tmp_list = []
    for word in title:
        if word not in stop_words:
            tmp_list.append(word)
            words_list.append(word)
    cleaned_titles.append(tmp_list)

# %%
x = pd.Series(cleaned_titles)

# %%
df['title'] = x

# %%
print(type(df['title'][0]))
# Out:
# <class 'list'>

# %%
df
# Out:
#                                                   title  views_label
# 0     [year, vlogging, logan, paul, changed, youtube...            1
# 1            [iphone, x, introducing, iphone, x, apple]            0
# 2                                            [response]            0
# 3                       [apple, iphone, x, first, look]            0
# 4                                   [iphone, x, parody]            0
# ...                                                 ...          ...
# 2359    [team, audition, tessa, brooks, nick, crompton]            1
# 2360  [wonderstruck, official, trailer, hd, amazon, ...            0
# 2361  [hidden, nes, golf, game, nintendo, switch, tr...            0
# 2362  [watch, first, lady, melania, trump, discusses...            0
# 2363         [first, footage, wild, sand, cat, kittens]            0
#
# [2364 rows x 2 columns]

# %%
def strip_func(x):
    return ' '.join(x)

# %%
df['title'] = df['title'].apply(lambda x: strip_func(x))

# %%
df
# Out:
#                                                   title  views_label
# 0      year vlogging logan paul changed youtube forever            1
# 1                   iphone x introducing iphone x apple            0
# 2                                              response            0
# 3                             apple iphone x first look            0
# 4                                       iphone x parody            0
# ...                                                 ...          ...
# 2359           team audition tessa brooks nick crompton            1
# 2360    wonderstruck official trailer hd amazon studios            0
# 2361  hidden nes golf game nintendo switch tribute s...            0
# 2362  watch first lady melania trump discusses child...            0
# 2363                first footage wild sand cat kittens            0
#
# [2364 rows x 2 columns]

# %% [markdown]
# # LSTM3에서 가져온 코드다

# %%
#test/train 스플릿
# X_train , X_test, y_train, y_test = train_test_split(df['title'], df['views'], test_size=0.2, shuffle=False)

title_train, title_test, y_train, y_test = train_test_split(df['title'], df['views_label'], test_size=0.2, shuffle=False)

print("# split done")
stopwords = []
#토근화 진행
X_train = []
for stc in title_train:
  token = []
  words = stc.split()
  for word in words:
    if word not in stopwords:
      token.append(word)
  X_train.append(token)

X_test =  []

for stc in title_test:
  token = []
  words = stc.split()
  for word in words:
    if word not in stopwords:
      token.append(word)
  X_test.append(token)

print("# tokenization done")
# Out:
# # split done
# # tokenization done

# %%
X_train
# Out:
# [['year', 'vlogging', 'logan', 'paul', 'changed', 'youtube', 'forever'],
#  ['iphone', 'x', 'introducing', 'iphone', 'x', 'apple'],
#  ['response'],
#  ['apple', 'iphone', 'x', 'first', 'look'],
#  ['iphone', 'x', 'parody'],
#  ['disaster', 'artist', 'official', 'trailer', 'hd'],
#  ['check', 'hud', 'ben', 'carson', 'hurricanes'],
#  ['iphone', 'x', 'impressions', 'hands'],
#  ['attacked', 'police', 'dog'],
#  ['honest', 'trailers', 'mummy'],
#  ['honest', 'college', 'tour'],
#  ['best', 'floyd', 'mayweather', 'interview', 'awkward', 'puppets'],
#  ['jennifer', 'lawrence', 'challenges', 'jimmy', 'axe', 'throwing', 'contest'],
#  ['hand', 'hand', 'benefit', 'hurricane', 'relief', 'mtv'],
#  ['colin',
#   'cloud',
#   'mind',
#   'reader',
#   'predicts',
#   'tweets',
#   'america',
#   'got',
#   'talent'],
#  ['iphone', 'x', 'hands', 'everything', 'need', 'know'],
#  ['want', 'eat'],
#  ['getting', 'conversation', 'language', 'actually', 'speak', 'well'],
#  ['juicy', 'chicken', 'breast', 'suck', 'cooking', 'episode'],
#  ['downsizing', 'official', 'trailer', 'paramount', 'pictures'],
#  ['fergie', 'already', 'know', 'ft', 'nicki', 'minaj'],
#  ['hurricane', 'irma', 'death', 'toll', 'rises', 'cuba'],
#  ['gigi',
#   'hadid',
#   'loses',
#   'high',
#   'heel',
#   'fashion',
#   'week',
#   'walks',
#   'like',
#   'pro',
#   'tmz'],
#  ['superfruit', 'reacts', 'teens', 'react', 'superfruit'],
#  ['kid', 'rock', 'tennessee', 'mountain', 'top', 'lyrics'],
#  ['chargers', 'vs', 'broncos', 'nfl', 'week', 'game', 'highlights'],
#  ['nerf', 'bow', 'trick', 'shots', 'dude', 'perfect'],
#  ['action',
#   'bronson',
#   'sean',
#   'evans',
#   'sandwich',
#   'showdown',
#   'judged',
#   'mario',
#   'batali',
#   'sean',
#   'wild'],
#  ['joe', 'arpaio', 'last', 'week', 'tonight', 'john', 'oliver', 'hbo'],
#  ['mystery', 'caboodle'],
#  ['radiohead', 'lift'],
#  ['actually', 'plane', 'future'],
#  ['blind', 'people', 'describe', 'beauty'],
#  ['hillary', 'clinton', 'really', 'thinks'],
#  ['drowning', 'power', 'rooster', 'teeth', 'animated', 'adventures'],
#  ['jumping', 'impossible', 'shapes'],
#  ['maggie', 'gyllenhaal', 'taylor', 'swift', 'scarf', 'wwhl'],
#  ['air', 'irma', 'catastrophic', 'wrath', 'undeniable'],
#  ['fall', 'makeup', 'tutorial', 'talk', 'tutorial', 'casey', 'holmes'],
#  ['commuter', 'teaser', 'trailer', 'movieclips', 'trailers'],
#  ['problem', 'phones'],
#  ['lany', 'super', 'far', 'official', 'video'],
#  ['gwyneth', 'paltrow', 'crashes', 'james', 'goop', 'magazine', 'rant'],
#  ['fail',
#   'new',
#   'estee',
#   'lauder',
#   'double',
#   'wear',
#   'nude',
#   'first',
#   'impression',
#   'review',
#   'demo',
#   'days',
#   'foundation'],
#  ['im', 'gonna', 'father', 'things', 'got', 'awkward'],
#  ['fenty',
#   'beauty',
#   'pro',
#   'filt',
#   'r',
#   'foundation',
#   'review',
#   'nyma',
#   'tang',
#   'thedarkestshade'],
#  ['jimmy',
#   'kimmel',
#   'talks',
#   'kristen',
#   'bell',
#   'orlando',
#   'hurricane',
#   'irma'],
#  ['hurricane', 'jose', 'advisory'],
#  ['made', 'dad', 'cry', 'story', 'comeback', 'competition'],
#  ['gold', 'diva', 'macarons', 'scran', 'line'],
#  ['chocolate', 'chip', 'cookie', 'cupcakes', 'nerdy', 'nummies'],
#  ['apple', 'watch', 'series', 'hands', 'live', 'apple', 'event'],
#  ['last', 'week', 'tonight', 'john', 'oliver', 'se', 'sep'],
#  ['harry', 'styles', 'chain', 'fleetwood', 'mac', 'cover', 'live', 'lounge'],
#  ['real', 'clowns', 'creepier', 'pennywise'],
#  ['happens', 'two', 'hurricanes', 'collide'],
#  ['season', 'preview', 'white', 'people', 'renovating', 'houses'],
#  ['hours', 'movies', 'whose', 'timelines', 'add'],
#  ['lemon',
#   'praises',
#   'chunky',
#   'cnn',
#   'reporter',
#   'facing',
#   'irma',
#   'wrath',
#   'nothing',
#   'wrong',
#   'little',
#   'curve'],
#  ['kirstin', 'bad', 'weather', 'official', 'video'],
#  ['jim',
#   'carrey',
#   'bizarre',
#   'fashion',
#   'week',
#   'interview',
#   'daily',
#   'pop',
#   'e',
#   'news'],
#  ['blind', 'taste', 'test', 'grace', 'helbig'],
#  ['surveying', 'hurricane', 'irma', 'damage', 'southwest', 'florida'],
#  ['day', 'beach', 'mayor', 'steve', 'fulop'],
#  ['seafood', 'vs', 'seafood', 'australia'],
#  ['fifty', 'shades', 'freed', 'teaser', 'hd'],
#  ['qb', 'turned', 'psychic', 'tony', 'romo', 'predicts', 'future'],
#  ['iphone',
#   'x',
#   'walkthrough',
#   'animoji',
#   'face',
#   'id',
#   'portrait',
#   'mode',
#   'lighting',
#   'effects'],
#  ['photograph', 'incredible', 'architecture'],
#  ['tommy',
#   'wiseau',
#   'james',
#   'franco',
#   'perfect',
#   'disaster',
#   'artist',
#   'los',
#   'angeles',
#   'times'],
#  ['kanye', 'west', 'graduation', 'changed', 'music', 'genius', 'news'],
#  ['iphone', 'x', 'hands'],
#  ['tying', 'shoe'],
#  ['big', 'announcement', 'popscicle'],
#  ['things', 'need', 'know', 'pennywise'],
#  ['obsessed', 'netflix'],
#  ['game', 'revealed', 'season', 'episode', 'goodbye', 'kiss'],
#  ['jim', 'carrey', 'sounds', 'icons', 'nyfw', 'e', 'live', 'red', 'carpet'],
#  ['更なるフィット感を追求するねこ', 'maru', 'wishes', 'fitting', 'feeling'],
#  ['storm',
#   'chaser',
#   'battles',
#   'hurricane',
#   'irma',
#   'powerful',
#   'winds',
#   'nbc',
#   'news'],
#  ['willow', 'birthday'],
#  ['iphone', 'hands', 'overlook', 'big', 'update'],
#  ['essential',
#   'phone',
#   'drop',
#   'test',
#   'titanium',
#   'ceramic',
#   'vs',
#   'gravity'],
#  ['drone', 'captures', 'aftermath', 'hurricane', 'irma', 'naples', 'florida'],
#  ['hurricane', 'size', 'comparison'],
#  ['assume', 'sexuality', 'based', 'first', 'impression', 'tell', 'story'],
#  ['live', 'tracking', 'hurricane', 'irma'],
#  ['computers', 'compress', 'text', 'huffman', 'coding', 'huffman', 'trees'],
#  ['constitution', 'spartans'],
#  ['hillary', 'clinton', 'speaks'],
#  ['wolf', 'alice', 'beautifully', 'unconventional'],
#  ['larry',
#   'back',
#   'nothing',
#   'changed',
#   'curb',
#   'enthusiasm',
#   'season',
#   'trailer',
#   'hbo'],
#  ['casually', 'explained', 'ii', 'worst', 'could', 'happen'],
#  ['easy', 'magic', 'tricks', 'anyone'],
#  ['bought', 'entire', 'outfit', 'blindfolded'],
#  ['japan', 'ominous', 'dancing', 'cats', 'disaster', 'followed'],
#  ['rick', 'morty', 'character', 'studies', 'rick', 'rick'],
#  ['gave', 'celebrity', 'hair', 'transformation'],
#  ['viral',
#   'instagram',
#   'makeup',
#   'trends',
#   'wavy',
#   'eyebrows',
#   'tested',
#   'alisha',
#   'marie'],
#  ['try', 'fall', 'haul', 'fashion', 'drugstore', 'makeup', 'ingrid', 'nilsen'],
#  ['minelli', 'empty', 'spaces', 'official', 'video', 'ultra', 'music'],
#  ['moment', 'silence', 'national', 'memorial', 'museum'],
#  ['tracking', 'hurricane', 'irma'],
#  ['life', 'kylie', 'recap', 'season', 'ep', 'e'],
#  ['derealisation', 'depersonalisation'],
#  ['hurricane',
#   'irma',
#   'makes',
#   'landfall',
#   'florida',
#   'keys',
#   'powerful',
#   'category',
#   'today'],
#  ['fenty', 'beauty', 'rihanna', 'full', 'review'],
#  ['hurricane', 'irma', 'category', 'could', 'engergize', 'category', 'msnbc'],
#  ['irmagerd', 'hurricane', 'candy', 'hard', 'make', 'candy', 'rains'],
#  ['bbc', 'anchor', 'gets', 'lost', 'camera', 'news', 'blooper'],
#  ['dried', 'beach', 'bahamas'],
#  ['hurricane', 'irma', 'news', 'bloopers'],
#  ['full',
#   'face',
#   'first',
#   'impressions',
#   'testing',
#   'new',
#   'makeup',
#   'beauty',
#   'mi'],
#  ['rudimental',
#   'sun',
#   'comes',
#   'feat',
#   'james',
#   'arthur',
#   'official',
#   'video'],
#  ['hilarious', 'thrift', 'store', 'items'],
#  ['hurricane', 'irma', 'roars', 'florida', 'keys', 'continues', 'coast'],
#  ['honda', 'civic', 'small', 'feature', 'never', 'noticed'],
#  ['testing', 'weird', 'puppy', 'toys', 'puppy', 'cute'],
#  ['served', 'like', 'girl', 'trailer'],
#  ['hurricane', 'irma', 'emergency', 'fake', 'interpreter'],
#  ['check', 'description', 'southern', 'point', 'live', 'webcam'],
#  ['cal', 'football', 'hc', 'justin', 'wilcox', 'september'],
#  ['salted',
#   'egg',
#   'crab',
#   'street',
#   'food',
#   'tour',
#   'old',
#   'airport',
#   'road',
#   'hawker',
#   'center'],
#  ['nothing', 'thieves', 'sorry', 'stripped', 'back'],
#  ['best', 'features', 'coming', 'iphones'],
#  ['galaxy', 'note', 'things', 'first'],
#  ['spoiler', 'talk'],
#  ['sloane',
#   'stephens',
#   'jokes',
#   'million',
#   'check',
#   'inspires',
#   'keep',
#   'playing',
#   'espn'],
#  ['killer', 'whales', 'attack', 'minke', 'frozen', 'planet', 'bbc', 'earth'],
#  ['garlic', 'knot', 'chicken', 'alfredo', 'ring'],
#  ['us', 'open', 'sloane', 'stephens', 'takes', 'title'],
#  ['first',
#   'tuned',
#   'run',
#   'terry',
#   'mayhugh',
#   'quarter',
#   'scale',
#   'v',
#   'merlin'],
#  ['rainbow', 'connection', 'muppets', 'hollywood', 'bowl', 'september', 'hd'],
#  ['los',
#   'jugadores',
#   'de',
#   'sacachispas',
#   'entraron',
#   'vestidos',
#   'de',
#   'guerreros',
#   'vs',
#   'sarmiento',
#   'copa',
#   'argentina'],
#  ['days',
#   'timelapse',
#   'sea',
#   'k',
#   'thunderstorms',
#   'torrential',
#   'rain',
#   'busy',
#   'traffic'],
#  ['fenty', 'beauty', 'rihanna', 'hit', 'miss', 'jeffree', 'star'],
#  ['teardown', 'experiments', 'doppler', 'microwave', 'transceiver'],
#  ['stephen', 'king', 'difference'],
#  ['svu', 'opener', 'dedication', 'wmv'],
#  ['final', 'steps', 'making', 'pyrimethamine', 'daraprim'],
#  ['steve', 'bannon', 'trump', 'access', 'hollywood', 'tape', 'litmus', 'test'],
#  ['roasting', 'youtubers', 'nails', 'nail', 'diss'],
#  ['dancing', 'movies', 'supercut', 'vol'],
#  ['blake', 'shelton', 'name', 'dogs', 'official', 'music', 'video'],
#  ['dad', 'builds', 'palace', 'dogs'],
#  ['hurricane', 'irma', 'warning', 'sign', 'language'],
#  ['kmart'],
#  ['smartphone', 'challenge'],
#  ['fenty', 'beauty', 'full', 'face', 'beat', 'impressions', 'review'],
#  ['save', 'seat', 'japan'],
#  ['cook', 'power', 'hurricane', 'irma'],
#  ['win', 'australia'],
#  ['rihanna',
#   'fenty',
#   'beauty',
#   'first',
#   'impressions',
#   'full',
#   'face',
#   'review',
#   'dark',
#   'skin',
#   'msdebdeb'],
#  ['one', 'america', 'appeal', 'friends', 'texas'],
#  ['anvil', 'vs', 'watermelon', 'pyramid', 'crazy', 'drop', 'tests'],
#  ['genres',
#   'two',
#   'artists',
#   'one',
#   'song',
#   'voices',
#   'shape',
#   'ed',
#   'sheeran'],
#  ['welcome', 'jurassic', 'falls'],
#  ['buick', 'skyhawk', 'commercial'],
#  ['nicholls', 'postgame', 'kevin', 'sumlin'],
#  ['kane', 'brown', 'found', 'audio'],
#  ['game', 'thrones', 'sings', 'look', 'made'],
#  ['bernie', 'sanders', 'tries', 'say', 'something', 'nice', 'trump'],
#  ['sam', 'smith', 'good', 'goodbyes', 'official', 'audio'],
#  ['calvin',
#   'harris',
#   'hard',
#   'love',
#   'official',
#   'video',
#   'ft',
#   'jessie',
#   'reyez'],
#  ['update', 'problem', 'chemo', 'pills'],
#  ['kids', 'shows', 'honest', 'life'],
#  ['search', 'history', 'say'],
#  ['nerf', 'meets', 'call', 'duty', 'gun', 'game', 'first', 'person', 'k'],
#  ['g', 'eazy', 'limit', 'audio', 'ft', 'ap', 'rocky', 'cardi', 'b'],
#  ['rutgers', 'falls', 'eastern', 'michigan'],
#  ['florida',
#   'weather',
#   'cameras',
#   'hurricane',
#   'irma',
#   'cameras',
#   'across',
#   'florida'],
#  ['alias', 'grace', 'official', 'trailer', 'hd', 'netflix'],
#  ['dating', 'advice', 'ever', 'need'],
#  ['home', 'movie', 'review'],
#  ['fifth', 'harmony', 'deliver'],
#  ['janet',
#   'jackson',
#   'performs',
#   'dammn',
#   'baby',
#   'get',
#   'lonely',
#   'live',
#   'state',
#   'world',
#   'tour'],
#  ['jordan',
#   'peele',
#   'spike',
#   'lee',
#   'team',
#   'movie',
#   'black',
#   'cop',
#   'infiltrated',
#   'kkk'],
#  ['zayn', 'dusk', 'till', 'dawn', 'ft', 'sia'],
#  ['orlando', 'braces', 'hurricane', 'irma'],
#  ['nicholas',
#   'hamilton',
#   'chosen',
#   'jacobs',
#   'play',
#   'raw',
#   'whisper',
#   'challenge'],
#  ['green', 'day', 'dumb', 'die', 'official', 'lyric', 'video'],
#  ['hailee',
#   'steinfeld',
#   'alesso',
#   'ft',
#   'florida',
#   'georgia',
#   'line',
#   'watt',
#   'let',
#   'go',
#   'official',
#   'audio'],
#  ['kelly', 'clarkson', 'love', 'soft', 'official', 'video'],
#  ['harry', 'potter', 'theory', 'history', 'hagrid', 'wand'],
#  ['hurricanes', 'irma', 'jose', 'katia'],
#  ['thomas', 'rhett', 'sweetheart', 'static', 'video'],
#  ['suburbicon', 'trailer'],
#  ['live',
#   'footage',
#   'hurricane',
#   'irma',
#   'destroys',
#   'maho',
#   'beach',
#   'cam',
#   'st',
#   'maarten'],
#  ['avenged', 'sevenfold', 'tears', 'go'],
#  ['acting', 'real', 'childhood', 'stories', 'part'],
#  ['taylor', 'swift', 'presents', 'see', 'taylor'],
#  ['american', 'horror', 'story', 'cult', 'bee', 'hive'],
#  ['lecrae', 'hammer', 'time', 'dance', 'visual', 'ft', 'k', 'phew'],
#  ['small', 'hands', 'samsung', 'galaxy', 'note', 'review'],
#  ['online', 'shopping', 'haul', 'shopaholic'],
#  ['liza',
#   'koshy',
#   'dream',
#   'office',
#   'makeover',
#   'omg',
#   'coming',
#   'mr',
#   'kate'],
#  ['rhab', 'quintino', 'official', 'video'],
#  ['things', 'need', 'know', 'kittens', 'simon', 'cat'],
#  ['watch',
#   'live',
#   'satellite',
#   'images',
#   'hurricane',
#   'irma',
#   'evacuation',
#   'orders',
#   'place',
#   'florida',
#   'time'],
#  ['gaga', 'five', 'foot', 'two', 'press', 'conference', 'festival'],
#  ['hello',
#   'world',
#   'meet',
#   'baby',
#   'girl',
#   'alexis',
#   'olympia',
#   'ohanian',
#   'jr'],
#  ['alexa', 'guess'],
#  ['bill', 'skarsgård', 'demonic', 'smile', 'conan', 'tbs'],
#  ['iphone', 'x', 'introducing', 'iphone', 'x', 'apple'],
#  ['year', 'vlogging', 'logan', 'paul', 'changed', 'youtube', 'forever'],
#  ['apple', 'iphone', 'x', 'first', 'look'],
#  ['spiked', 'sea', 'urchin'],
#  ['lana', 'del', 'rey', 'white', 'mustang', 'official', 'video'],
#  ['official', 'us', 'find', 'voice', 'trailer', 'disney', 'pixar', 'coco'],
#  ['iphone', 'x', 'iphone'],
#  ['response'],
#  ['soy',
#   'pablo',
#   'extended',
#   'trailer',
#   'bad',
#   'lip',
#   'reading',
#   'narcos',
#   'netflix',
#   'original',
#   'series'],
#  ['opposition', 'w', 'jordan', 'klepper', 'opposing', 'resistance', 'phoenix'],
#  ['iphone', 'x', 'parody'],
#  ['jennifer', 'lawrence', 'challenges', 'jimmy', 'axe', 'throwing', 'contest'],
#  ['check', 'hud', 'ben', 'carson', 'hurricanes'],
#  ['iphone', 'x', 'impressions', 'hands'],
#  ['real', 'reason', 'kill', 'mockingbird', 'became', 'famous'],
#  ['sarah', 'huckabee', 'sanders', 'jemele', 'hill'],
#  ['disaster', 'artist', 'official', 'trailer', 'hd'],
#  ['hand', 'hand', 'benefit', 'hurricane', 'relief', 'mtv'],
#  ['colin',
#   'cloud',
#   'mind',
#   'reader',
#   'predicts',
#   'tweets',
#   'america',
#   'got',
#   'talent'],
#  ['riverdale', 'motive', 'trailer', 'cw'],
#  ['fergie', 'already', 'know', 'ft', 'nicki', 'minaj'],
#  ['best', 'floyd', 'mayweather', 'interview', 'awkward', 'puppets'],
#  ['weight', 'update', 'weeks', 'post', 'surgery', 'pounds'],
#  ['stephen',
#   'smith',
#   'calls',
#   'espn',
#   'nbarank',
#   'garbage',
#   'carmelo',
#   'anthony',
#   'rating',
#   'first',
#   'take',
#   'espn'],
#  ['iphone', 'x', 'hands', 'everything', 'need', 'know'],
#  ['honest', 'trailers', 'mummy'],
#  ['want', 'eat'],
#  ['attacked', 'police', 'dog'],
#  ['maggie', 'gyllenhaal', 'taylor', 'swift', 'scarf', 'wwhl'],
#  ['honest', 'college', 'tour'],
#  ['fifth', 'harmony', 'like'],
#  ['bell', 'theorem', 'quantum', 'venn', 'diagram', 'paradox'],
#  ['bella',
#   'hadid',
#   'roughs',
#   'security',
#   'roughing',
#   'female',
#   'photog',
#   'tmz'],
#  ['iphone', 'x', 'face', 'id', 'unlock', 'fail'],
#  ['juicy', 'chicken', 'breast', 'suck', 'cooking', 'episode'],
#  ['downsizing', 'official', 'trailer', 'paramount', 'pictures'],
#  ['iphone', 'x', 'vs', 'iphone', 'hands', 'difference'],
#  ['kid', 'rock', 'tennessee', 'mountain', 'top', 'lyrics'],
#  ['getting', 'conversation', 'language', 'actually', 'speak', 'well'],
#  ['vlogtember', 'nyc', 'running', 'around', 'heyclaire'],
#  ['radiohead', 'lift'],
#  ['demi',
#   'lovato',
#   'performing',
#   'little',
#   'help',
#   'friends',
#   'hand',
#   'hand',
#   'september'],
#  ['hurricane', 'irma', 'death', 'toll', 'rises', 'cuba'],
#  ['tori', 'kelly', 'luis', 'fonsi', 'hallelujah', 'hand', 'hand', 'benefit'],
#  ['nerf', 'bow', 'trick', 'shots', 'dude', 'perfect'],
#  ['actually', 'plane', 'future'],
#  ['superfruit', 'reacts', 'teens', 'react', 'superfruit'],
#  ['air', 'irma', 'catastrophic', 'wrath', 'undeniable'],
#  ['mystery',
#   'van',
#   'helping',
#   'self',
#   'driving',
#   'cars',
#   'communicate',
#   'people',
#   'autonomy',
#   'ford'],
#  ['fenty', 'beauty', 'rihanna', 'review', 'wear', 'test'],
#  ['xx', 'hold', 'jamie', 'xx', 'remix'],
#  ['blind', 'people', 'describe', 'beauty'],
#  ['sarah',
#   'sanders',
#   'espn',
#   'jemele',
#   'hill',
#   'committed',
#   'fireable',
#   'offense'],
#  ['imagine', 'dragons', 'whatever', 'takes', 'version', 'lyric', 'vide'],
#  ['selena', 'gomez', 'hand', 'hand'],
#  ['usher',
#   'blake',
#   'shelton',
#   'stand',
#   'hand',
#   'hand',
#   'benefit',
#   'hurricane',
#   'relief',
#   'mtv'],
#  ['action',
#   'bronson',
#   'sean',
#   'evans',
#   'sandwich',
#   'showdown',
#   'judged',
#   'mario',
#   'batali',
#   'sean',
#   'wild'],
#  ['apple', 'watch', 'series', 'hands', 'live', 'apple', 'event'],
#  ['chargers', 'vs', 'broncos', 'nfl', 'week', 'game', 'highlights'],
#  ['mystery', 'caboodle'],
#  ['stone',
#   'sour',
#   'rose',
#   'red',
#   'violent',
#   'blue',
#   'song',
#   'dumb',
#   'official',
#   'video'],
#  ['everything', 'wrong', 'alien', 'covenant', 'minutes', 'less'],
#  ['delicious', 'chocolate', 'cupcakes', 'minutes', 'scran', 'line'],
#  ['depeche', 'mode', 'cover'],
#  ['commuter', 'teaser', 'trailer', 'movieclips', 'trailers'],
#  ['joe', 'arpaio', 'last', 'week', 'tonight', 'john', 'oliver', 'hbo'],
#  ['world', 'walker', 'trailer'],
#  ['damage',
#   'hurricane',
#   'irma',
#   'magic',
#   'kingdom',
#   'walt',
#   'disney',
#   'world'],
#  ['problem', 'phones'],
#  ['lexus', 'lc', 'costs'],
#  ['jumping', 'impossible', 'shapes'],
#  ['x', 'extreme', 'spicy', 'noodle', 'car', 'ride', 'cried', 'ranz', 'niana'],
#  ['更なるフィット感を追求するねこ', 'maru', 'wishes', 'fitting', 'feeling'],
#  ['wore', 'new', 'york', 'fashion', 'week'],
#  ['lany', 'super', 'far', 'official', 'video'],
#  ['last', 'week', 'tonight', 'john', 'oliver', 'se', 'sep'],
#  ['drowning', 'power', 'rooster', 'teeth', 'animated', 'adventures'],
#  ['lemon',
#   'praises',
#   'chunky',
#   'cnn',
#   'reporter',
#   'facing',
#   'irma',
#   'wrath',
#   'nothing',
#   'wrong',
#   'little',
#   'curve'],
#  ['im', 'gonna', 'father', 'things', 'got', 'awkward'],
#  ['season', 'preview', 'white', 'people', 'renovating', 'houses'],
#  ['jimmy',
#   'kimmel',
#   'talks',
#   'kristen',
#   'bell',
#   'orlando',
#   'hurricane',
#   'irma'],
#  ['made', 'dad', 'cry', 'story', 'comeback', 'competition'],
#  ['fenty',
#   'beauty',
#   'pro',
#   'filt',
#   'r',
#   'foundation',
#   'review',
#   'nyma',
#   'tang',
#   'thedarkestshade'],
#  ['iphone',
#   'x',
#   'walkthrough',
#   'animoji',
#   'face',
#   'id',
#   'portrait',
#   'mode',
#   'lighting',
#   'effects'],
#  ['make',
#   'lloyd',
#   'new',
#   'lego',
#   'ninjago',
#   'movie',
#   'cake',
#   'yolanda',
#   'gampp',
#   'cake'],
#  ['mustard', 'vs', 'cheese', 'answering', 'questions', 'qandgay'],
#  ['enter', 'shikari', 'rabble', 'rouser', 'official', 'promo', 'video'],
#  ['interview', 'runaway', 'toddler'],
#  ['hurricane', 'jose', 'advisory'],
#  ['chocolate', 'chip', 'cookie', 'cupcakes', 'nerdy', 'nummies'],
#  ['things', 'need', 'know', 'pennywise'],
#  ['crowder', 'prove', 'ft', 'kb'],
#  ['photograph', 'incredible', 'architecture'],
#  ['galen', 'hooks', 'wait', 'galen', 'hooks', 'film'],
#  ['obsessed', 'netflix'],
#  ['harry', 'styles', 'chain', 'fleetwood', 'mac', 'cover', 'live', 'lounge'],
#  ['willow', 'birthday'],
#  ['jim',
#   'carrey',
#   'bizarre',
#   'fashion',
#   'week',
#   'interview',
#   'daily',
#   'pop',
#   'e',
#   'news'],
#  ['blind', 'taste', 'test', 'grace', 'helbig'],
#  ['hours', 'movies', 'whose', 'timelines', 'add'],
#  ['real', 'clowns', 'creepier', 'pennywise'],
#  ['tommy',
#   'wiseau',
#   'james',
#   'franco',
#   'perfect',
#   'disaster',
#   'artist',
#   'los',
#   'angeles',
#   'times'],
#  ['apple', 'watch', 'series', 'hands'],
#  ['rudimental',
#   'sun',
#   'comes',
#   'feat',
#   'james',
#   'arthur',
#   'official',
#   'video'],
#  ['big', 'announcement', 'popscicle'],
#  ['qb', 'turned', 'psychic', 'tony', 'romo', 'predicts', 'future'],
#  ['fall', 'makeup', 'tutorial', 'talk', 'tutorial', 'casey', 'holmes'],
#  ['fifty', 'shades', 'freed', 'teaser', 'hd'],
#  ['seafood', 'vs', 'seafood', 'australia'],
#  ['fail',
#   'new',
#   'estee',
#   'lauder',
#   'double',
#   'wear',
#   'nude',
#   'first',
#   'impression',
#   'review',
#   'demo',
#   'days',
#   'foundation'],
#  ['kanye', 'west', 'graduation', 'changed', 'music', 'genius', 'news'],
#  ['storm',
#   'chaser',
#   'battles',
#   'hurricane',
#   'irma',
#   'powerful',
#   'winds',
#   'nbc',
#   'news'],
#  ['kirstin', 'bad', 'weather', 'official', 'video'],
#  ['hillary', 'clinton', 'speaks'],
#  ['jim', 'carrey', 'sounds', 'icons', 'nyfw', 'e', 'live', 'red', 'carpet'],
#  ['surveying', 'hurricane', 'irma', 'damage', 'southwest', 'florida'],
#  ['drone', 'captures', 'aftermath', 'hurricane', 'irma', 'naples', 'florida'],
#  ['happens', 'two', 'hurricanes', 'collide'],
#  ['iphone', 'hands', 'overlook', 'big', 'update'],
#  ['assume', 'sexuality', 'based', 'first', 'impression', 'tell', 'story'],
#  ['wet', 'book', 'rescue'],
#  ['hurricane', 'size', 'comparison'],
#  ['queen', 'live', 'aid', 'part', 'high', 'quality'],
#  ['computers', 'compress', 'text', 'huffman', 'coding', 'huffman', 'trees'],
#  ['live', 'tracking', 'hurricane', 'irma'],
#  ['constitution', 'spartans'],
#  ['tying', 'shoe'],
#  ['wolf', 'alice', 'beautifully', 'unconventional'],
#  ['casually', 'explained', 'ii', 'worst', 'could', 'happen'],
#  ['minelli', 'empty', 'spaces', 'official', 'video', 'ultra', 'music'],
#  ['larry',
#   'back',
#   'nothing',
#   'changed',
#   'curb',
#   'enthusiasm',
#   'season',
#   'trailer',
#   'hbo'],
#  ['easy', 'magic', 'tricks', 'anyone'],
#  ['game', 'revealed', 'season', 'episode', 'goodbye', 'kiss'],
#  ['japan', 'ominous', 'dancing', 'cats', 'disaster', 'followed'],
#  ['bought', 'entire', 'outfit', 'blindfolded'],
#  ['essential',
#   'phone',
#   'drop',
#   'test',
#   'titanium',
#   'ceramic',
#   'vs',
#   'gravity'],
#  ['viral',
#   'instagram',
#   'makeup',
#   'trends',
#   'wavy',
#   'eyebrows',
#   'tested',
#   'alisha',
#   'marie'],
#  ['try', 'fall', 'haul', 'fashion', 'drugstore', 'makeup', 'ingrid', 'nilsen'],
#  ['rick', 'morty', 'character', 'studies', 'rick', 'rick'],
#  ['moment', 'silence', 'national', 'memorial', 'museum'],
#  ['tracking', 'hurricane', 'irma'],
#  ['derealisation', 'depersonalisation'],
#  ['hurricane',
#   'irma',
#   'makes',
#   'landfall',
#   'florida',
#   'keys',
#   'powerful',
#   'category',
#   'today'],
#  ['testing', 'weird', 'puppy', 'toys', 'puppy', 'cute'],
#  ['fenty', 'beauty', 'rihanna', 'full', 'review'],
#  ['hour',
#   'test',
#   'cult',
#   'beauty',
#   'buys',
#   'full',
#   'face',
#   'first',
#   'impressions',
#   'beauty',
#   'mi'],
#  ['dried', 'beach', 'bahamas'],
#  ['hurricane', 'irma', 'category', 'could', 'engergize', 'category', 'msnbc'],
#  ['life', 'kylie', 'recap', 'season', 'ep', 'e'],
#  ['galaxy', 'note', 'things', 'first'],
#  ['irmagerd', 'hurricane', 'candy', 'hard', 'make', 'candy', 'rains'],
#  ['hurricane', 'irma', 'news', 'bloopers'],
#  ['hilarious', 'thrift', 'store', 'items'],
#  ['bbc', 'anchor', 'gets', 'lost', 'camera', 'news', 'blooper'],
#  ['hurricane', 'irma', 'roars', 'florida', 'keys', 'continues', 'coast'],
#  ['honda', 'civic', 'small', 'feature', 'never', 'noticed'],
#  ['knock',
#   'anthony',
#   'joshua',
#   'kubrat',
#   'pulev',
#   'roughs',
#   'offers',
#   'fight',
#   'kugan',
#   'cassius'],
#  ['served', 'like', 'girl', 'trailer'],
#  ['gave', 'celebrity', 'hair', 'transformation'],
#  ['hurricane', 'irma', 'emergency', 'fake', 'interpreter'],
#  ['check', 'description', 'southern', 'point', 'live', 'webcam'],
#  ['cal', 'football', 'hc', 'justin', 'wilcox', 'september'],
#  ['salted',
#   'egg',
#   'crab',
#   'street',
#   'food',
#   'tour',
#   'old',
#   'airport',
#   'road',
#   'hawker',
#   'center'],
#  ['nothing', 'thieves', 'sorry', 'stripped', 'back'],
#  ['us', 'open', 'sloane', 'stephens', 'takes', 'title'],
#  ['garlic', 'knot', 'chicken', 'alfredo', 'ring'],
#  ['days',
#   'timelapse',
#   'sea',
#   'k',
#   'thunderstorms',
#   'torrential',
#   'rain',
#   'busy',
#   'traffic'],
#  ['spoiler', 'talk'],
#  ['killer', 'whales', 'attack', 'minke', 'frozen', 'planet', 'bbc', 'earth'],
#  ['first',
#   'tuned',
#   'run',
#   'terry',
#   'mayhugh',
#   'quarter',
#   'scale',
#   'v',
#   'merlin'],
#  ['rainbow', 'connection', 'muppets', 'hollywood', 'bowl', 'september', 'hd'],
#  ['los',
#   'jugadores',
#   'de',
#   'sacachispas',
#   'entraron',
#   'vestidos',
#   'de',
#   'guerreros',
#   'vs',
#   'sarmiento',
#   'copa',
#   'argentina'],
#  ['rami', 'malek', 'como', 'freddie', 'mercury', 'en', 'live', 'aid'],
#  ['teardown', 'experiments', 'doppler', 'microwave', 'transceiver'],
#  ['svu', 'opener', 'dedication', 'wmv'],
#  ['fenty', 'beauty', 'rihanna', 'hit', 'miss', 'jeffree', 'star'],
#  ['final', 'steps', 'making', 'pyrimethamine', 'daraprim'],
#  ['stephen', 'king', 'difference'],
#  ['roasting', 'youtubers', 'nails', 'nail', 'diss'],
#  ['blake', 'shelton', 'name', 'dogs', 'official', 'music', 'video'],
#  ['dancing', 'movies', 'supercut', 'vol'],
#  ['dad', 'builds', 'palace', 'dogs'],
#  ['game', 'thrones', 'sings', 'look', 'made'],
#  ['hurricane', 'irma', 'warning', 'sign', 'language'],
#  ['smartphone', 'challenge'],
#  ['kmart'],
#  ['fenty', 'beauty', 'full', 'face', 'beat', 'impressions', 'review'],
#  ['save', 'seat', 'japan'],
#  ['cook', 'power', 'hurricane', 'irma'],
#  ['win', 'australia'],
#  ['rihanna',
#   'fenty',
#   'beauty',
#   'first',
#   'impressions',
#   'full',
#   'face',
#   'review',
#   'dark',
#   'skin',
#   'msdebdeb'],
#  ['steve', 'bannon', 'trump', 'access', 'hollywood', 'tape', 'litmus', 'test'],
#  ['genres',
#   'two',
#   'artists',
#   'one',
#   'song',
#   'voices',
#   'shape',
#   'ed',
#   'sheeran'],
#  ['kane', 'brown', 'found', 'audio'],
#  ['buick', 'skyhawk', 'commercial'],
#  ['nicholls', 'postgame', 'kevin', 'sumlin'],
#  ['calvin',
#   'harris',
#   'hard',
#   'love',
#   'official',
#   'video',
#   'ft',
#   'jessie',
#   'reyez'],
#  ['shape', 'water', 'red', 'band', 'trailer'],
#  ['boyfriend', 'buys', 'outfits'],
#  ['funny', 'ask'],
#  ['land', 'orbital', 'rocket', 'booster'],
#  ['jimmy', 'kimmel', 'full', 'interview', 'sean', 'spicer'],
#  ['hello',
#   'world',
#   'meet',
#   'baby',
#   'girl',
#   'alexis',
#   'olympia',
#   'ohanian',
#   'jr'],
#  ['life', 'hate', 'september', 'act', 'full', 'frontal', 'tbs'],
#  ['department'],
#  ['bts', '방탄소년단', 'dna', 'official', 'teaser'],
#  ['machine', 'gun', 'kelly', 'let', 'go'],
#  ['bill', 'skarsgård', 'demonic', 'smile', 'conan', 'tbs'],
#  ['fall', 'boy', 'last', 'real', 'ones'],
#  ['iphone', 'plus', 'vs', 'iphone', 'plus', 'worth', 'upgrading'],
#  ['alexa', 'guess', 'number'],
#  ['official', 'us', 'find', 'voice', 'trailer', 'disney', 'pixar', 'coco'],
#  ['aaron', 'carter', 'hiv', 'test', 'results', 'revealed'],
#  ['lana', 'del', 'rey', 'white', 'mustang', 'official', 'video'],
#  ['impossible', 'big', 'mac', 'challenge', 'destroyed'],
#  ['soy',
#   'pablo',
#   'extended',
#   'trailer',
#   'bad',
#   'lip',
#   'reading',
#   'narcos',
#   'netflix',
#   'original',
#   'series'],
#  ['iphone', 'x', 'introducing', 'iphone', 'x', 'apple'],
#  ['year', 'vlogging', 'logan', 'paul', 'changed', 'youtube', 'forever'],
#  ['iphone', 'x', 'iphone'],
#  ['spiked', 'sea', 'urchin'],
#  ['sarah', 'huckabee', 'sanders', 'jemele', 'hill'],
#  ['apple', 'iphone', 'x', 'first', 'look'],
#  ['julien', 'baker', 'appointments', 'official', 'video'],
#  ['mother', 'movie', 'review'],
#  ['hell', 'yes'],
#  ['blindfold', 'gymnastics', 'challenge'],
#  ['dua', 'lipa', 'x', 'gallant', 'room', 'episode'],
#  ['chris', 'young', 'losing', 'sleep'],
#  ['bella',
#   'hadid',
#   'roughs',
#   'security',
#   'roughing',
#   'female',
#   'photog',
#   'tmz'],
#  ['teyana', 'taylor', 'tells', 'boob', 'surgery', 'says', 'kanye', 'back'],
#  ['red', 'velvet', 'cupcakes', 'made', 'kevin', 'durant'],
#  ['cream', 'cheese', 'stuffed', 'pumpkin', 'muffins', 'episode'],
#  ['full', 'face', 'first', 'impressions', 'fenty', 'beauty', 'faced', 'ysl'],
#  ['aly', 'aj', 'take'],
#  ['response'],
#  ['adam',
#   'ruins',
#   'everything',
#   'messed',
#   'story',
#   'hawaii',
#   'became',
#   'state',
#   'trutv'],
#  ['opposition', 'w', 'jordan', 'klepper', 'opposing', 'resistance', 'phoenix'],
#  ['jennifer', 'lawrence', 'challenges', 'jimmy', 'axe', 'throwing', 'contest'],
#  ['eat', 'much'],
#  ['iphone', 'x', 'parody'],
#  ['iphone', 'x', 'impressions', 'hands'],
#  ['nicki',
#   'minaj',
#   'surprises',
#   'nas',
#   'celebrating',
#   'rd',
#   'birthday',
#   'party',
#   'swizz',
#   'beatz'],
#  ['fast', 'furious', 'parody', 'goodbye', 'scene'],
#  ['real', 'reason', 'kill', 'mockingbird', 'became', 'famous'],
#  ['toni', 'braxton', 'deadwood', 'audio'],
#  ['livery', 'cab', 'hits', 'cyclist', 'east', 'flatbush'],
#  ['riverdale', 'motive', 'trailer', 'cw'],
#  ['husker', 'du', 'sorry', 'somehow'],
#  ['check', 'hud', 'ben', 'carson', 'hurricanes'],
#  ['lore', 'official', 'trailer', 'hd', 'amazon', 'video'],
#  ['need', 'talking', 'american', 'tail'],
#  ['need', 'talk'],
#  ['riverdale', 'scenes', 'madelaine', 'petsch'],
#  ['learn', 'stack', 'dice', 'learn', 'quick'],
#  ['optical', 'illusions'],
#  ['x', 'ambassadors', 'ahead'],
#  ['dl', 'hughley', 'espn', 'jemele', 'hill', 'controversy'],
#  ['bell', 'theorem', 'quantum', 'venn', 'diagram', 'paradox'],
#  ['disaster', 'artist', 'official', 'trailer', 'hd'],
#  ['maggie', 'gyllenhaal', 'taylor', 'swift', 'scarf', 'wwhl'],
#  ['angelica',
#   'hale',
#   'year',
#   'old',
#   'singer',
#   'blows',
#   'audience',
#   'away',
#   'america',
#   'got',
#   'talent'],
#  ['weight', 'update', 'weeks', 'post', 'surgery', 'pounds'],
#  ['best', 'mic', 'sounds', 'week', 'sound', 'fx', 'nfl', 'films'],
#  ['sarah',
#   'sanders',
#   'espn',
#   'jemele',
#   'hill',
#   'committed',
#   'fireable',
#   'offense'],
#  ['fergie', 'already', 'know', 'ft', 'nicki', 'minaj'],
#  ['hand', 'hand', 'benefit', 'hurricane', 'relief', 'mtv'],
#  ['kelly', 'clarkson', 'talks', 'american', 'idol', 'dr', 'luke', 'interview'],
#  ['grace', 'journey', 'digital', 'exclusive'],
#  ['eat', 'melbourne'],
#  ['iphone', 'x', 'iphone', 'hands'],
#  ['stephen',
#   'smith',
#   'calls',
#   'espn',
#   'nbarank',
#   'garbage',
#   'carmelo',
#   'anthony',
#   'rating',
#   'first',
#   'take',
#   'espn'],
#  ['xx', 'hold', 'jamie', 'xx', 'remix'],
#  ['tori', 'kelly', 'luis', 'fonsi', 'hallelujah', 'hand', 'hand', 'benefit'],
#  ['best', 'floyd', 'mayweather', 'interview', 'awkward', 'puppets'],
#  ['hudson', 'moore', 'wanna', 'love', 'official', 'music', 'video'],
#  ['boyfriend', 'buys', 'outfits'],
#  ['iphone', 'x', 'face', 'id', 'unlock', 'fail'],
#  ['stone',
#   'sour',
#   'rose',
#   'red',
#   'violent',
#   'blue',
#   'song',
#   'dumb',
#   'official',
#   'video'],
#  ['couple', 'first', 'merch'],
#  ['want', 'eat'],
#  ['kph',
#   'water',
#   'rocket',
#   'trike',
#   'ǀ',
#   'kph',
#   'second',
#   'g',
#   'ǀ',
#   'rider',
#   'françois',
#   'gissy'],
#  ['honest', 'trailers', 'mummy'],
#  ['iphone', 'x', 'vs', 'iphone', 'hands', 'difference'],
#  ['enough', 'milk', 'breastfeeding', 'story', 'momtember'],
#  ['attacked', 'police', 'dog'],
#  ['depeche', 'mode', 'cover'],
#  ['honest', 'college', 'tour'],
#  ['world', 'walker', 'trailer'],
#  ['internet', 'made', 'cry'],
#  ['selena', 'gomez', 'hand', 'hand'],
#  ['iphone', 'x', 'hands', 'live', 'apple', 'event'],
#  ['kid', 'rock', 'tennessee', 'mountain', 'top', 'lyrics'],
#  ['juicy', 'chicken', 'breast', 'suck', 'cooking', 'episode'],
#  ['downsizing', 'official', 'trailer', 'paramount', 'pictures'],
#  ['sorry', 'racial', 'slurs', 'finnish'],
#  ['usher',
#   'blake',
#   'shelton',
#   'stand',
#   'hand',
#   'hand',
#   'benefit',
#   'hurricane',
#   'relief',
#   'mtv'],
#  ['getting', 'conversation', 'language', 'actually', 'speak', 'well'],
#  ['demi',
#   'lovato',
#   'performing',
#   'little',
#   'help',
#   'friends',
#   'hand',
#   'hand',
#   'september'],
#  ['radiohead', 'lift'],
#  ['weezer', 'beach', 'boys'],
#  ['doom', 'wolfenstein', 'switch', 'announcement', 'trailer'],
#  ['crowder', 'prove', 'ft', 'kb'],
#  ['actually', 'plane', 'future'],
#  ['enter', 'shikari', 'rabble', 'rouser', 'official', 'promo', 'video'],
#  ['superfruit', 'reacts', 'teens', 'react', 'superfruit'],
#  ['nerf', 'bow', 'trick', 'shots', 'dude', 'perfect'],
#  ['damage',
#   'hurricane',
#   'irma',
#   'magic',
#   'kingdom',
#   'walt',
#   'disney',
#   'world'],
#  ['million', 'subscribers', 'struggling', 'still', 'smiling'],
#  ['blind', 'people', 'describe', 'beauty'],
#  ['imagine', 'dragons', 'whatever', 'takes', 'version', 'lyric', 'vide'],
#  ['x', 'extreme', 'spicy', 'noodle', 'car', 'ride', 'cried', 'ranz', 'niana'],
#  ['mystery',
#   'van',
#   'helping',
#   'self',
#   'driving',
#   'cars',
#   'communicate',
#   'people',
#   'autonomy',
#   'ford'],
#  ['action',
#   'bronson',
#   'sean',
#   'evans',
#   'sandwich',
#   'showdown',
#   'judged',
#   'mario',
#   'batali',
#   'sean',
#   'wild'],
#  ['everything', 'wrong', 'alien', 'covenant', 'minutes', 'less'],
#  ['更なるフィット感を追求するねこ', 'maru', 'wishes', 'fitting', 'feeling'],
#  ['mystery', 'caboodle'],
#  ['commuter', 'teaser', 'trailer', 'movieclips', 'trailers'],
#  ['lexus', 'lc', 'costs'],
#  ['joe', 'arpaio', 'last', 'week', 'tonight', 'john', 'oliver', 'hbo'],
#  ['get', 'ellen', 'ellen', 'show', 'show'],
#  ['jumping', 'impossible', 'shapes'],
#  ['genesis', 'ibex', 'cassini', 'scishow', 'talk', 'show'],
#  ['air', 'irma', 'catastrophic', 'wrath', 'undeniable'],
#  ['wore', 'new', 'york', 'fashion', 'week'],
#  ['lany', 'super', 'far', 'official', 'video'],
#  ['houston',
#   'attorney',
#   'tony',
#   'buzbee',
#   'drops',
#   'tank',
#   'river',
#   'oaks',
#   'blvd'],
#  ['cassini', 'burns', 'saturn', 'grand', 'finale'],
#  ['jennifer', 'lawrence', 'tore', 'diaphragm', 'filming', 'mother'],
#  ['vlogtember', 'nyc', 'running', 'around', 'heyclaire'],
#  ['answering', 'questions', 'qandgay'],
#  ['drowning', 'power', 'rooster', 'teeth', 'animated', 'adventures'],
#  ['im', 'gonna', 'father', 'things', 'got', 'awkward'],
#  ['lemon',
#   'praises',
#   'chunky',
#   'cnn',
#   'reporter',
#   'facing',
#   'irma',
#   'wrath',
#   'nothing',
#   'wrong',
#   'little',
#   'curve'],
#  ['fenty',
#   'beauty',
#   'pro',
#   'filt',
#   'r',
#   'foundation',
#   'review',
#   'nyma',
#   'tang',
#   'thedarkestshade'],
#  ['season', 'preview', 'white', 'people', 'renovating', 'houses'],
#  ['make',
#   'lloyd',
#   'new',
#   'lego',
#   'ninjago',
#   'movie',
#   'cake',
#   'yolanda',
#   'gampp',
#   'cake'],
#  ['delicious', 'chocolate', 'cupcakes', 'minutes', 'scran', 'line'],
#  ['galen', 'hooks', 'wait', 'galen', 'hooks', 'film'],
#  ['blueborne', 'android', 'take', 'demo'],
#  ['queen', 'live', 'aid', 'part', 'high', 'quality'],
#  ['fenty', 'beauty', 'rihanna', 'review', 'wear', 'test'],
#  ['hurricane', 'jose', 'advisory'],
#  ['rudimental',
#   'sun',
#   'comes',
#   'feat',
#   'james',
#   'arthur',
#   'official',
#   'video'],
#  ['photograph', 'incredible', 'architecture'],
#  ['chocolate', 'chip', 'cookie', 'cupcakes', 'nerdy', 'nummies'],
#  ['apple', 'watch', 'series', 'hands'],
#  ['harry', 'styles', 'chain', 'fleetwood', 'mac', 'cover', 'live', 'lounge'],
#  ['james', 'tw', 'please', 'keep', 'loving'],
#  ['obsessed', 'netflix'],
#  ['willow', 'birthday'],
#  ['tommy',
#   'wiseau',
#   'james',
#   'franco',
#   'perfect',
#   'disaster',
#   'artist',
#   'los',
#   'angeles',
#   'times'],
#  ['real', 'clowns', 'creepier', 'pennywise'],
#  ['things', 'need', 'know', 'pennywise'],
#  ['blind', 'taste', 'test', 'grace', 'helbig'],
#  ['iphone',
#   'x',
#   'walkthrough',
#   'animoji',
#   'face',
#   'id',
#   'portrait',
#   'mode',
#   'lighting',
#   'effects'],
#  ['last', 'week', 'tonight', 'john', 'oliver', 'se', 'sep'],
#  ['big', 'announcement', 'popscicle'],
#  ['fall', 'makeup', 'tutorial', 'talk', 'tutorial', 'casey', 'holmes'],
#  ['fifty', 'shades', 'freed', 'teaser', 'hd'],
#  ['qb', 'turned', 'psychic', 'tony', 'romo', 'predicts', 'future'],
#  ['tying', 'shoe'],
#  ['kanye', 'west', 'graduation', 'changed', 'music', 'genius', 'news'],
#  ['seafood', 'vs', 'seafood', 'australia'],
#  ['interview', 'runaway', 'toddler'],
#  ['fail',
#   'new',
#   'estee',
#   'lauder',
#   'double',
#   'wear',
#   'nude',
#   'first',
#   'impression',
#   'review',
#   'demo',
#   'days',
#   'foundation'],
#  ['storm',
#   'chaser',
#   'battles',
#   'hurricane',
#   'irma',
#   'powerful',
#   'winds',
#   'nbc',
#   'news'],
#  ['jim', 'carrey', 'sounds', 'icons', 'nyfw', 'e', 'live', 'red', 'carpet'],
#  ['jim',
#   'carrey',
#   'bizarre',
#   'fashion',
#   'week',
#   'interview',
#   'daily',
#   'pop',
#   'e',
#   'news'],
#  ['happens', 'two', 'hurricanes', 'collide'],
#  ['hillary', 'clinton', 'speaks'],
#  ['kirstin', 'bad', 'weather', 'official', 'video'],
#  ['creativity', 'gets', 'noticed', 'feat', 'tango', 'squad', 'adidas'],
#  ['game', 'revealed', 'season', 'episode', 'goodbye', 'kiss'],
#  ['assume', 'sexuality', 'based', 'first', 'impression', 'tell', 'story'],
#  ['drone', 'captures', 'aftermath', 'hurricane', 'irma', 'naples', 'florida'],
#  ['iphone', 'hands', 'overlook', 'big', 'update'],
#  ['computers', 'compress', 'text', 'huffman', 'coding', 'huffman', 'trees'],
#  ['constitution', 'spartans'],
#  ['minelli', 'empty', 'spaces', 'official', 'video', 'ultra', 'music'],
#  ['larry',
#   'back',
#   'nothing',
#   'changed',
#   'curb',
#   'enthusiasm',
#   'season',
#   'trailer',
#   'hbo'],
#  ['casually', 'explained', 'ii', 'worst', 'could', 'happen'],
#  ['wolf', 'alice', 'beautifully', 'unconventional'],
#  ['hurricane', 'size', 'comparison'],
#  ['bought', 'entire', 'outfit', 'blindfolded'],
#  ['internet',
#   'trending',
#   'dance',
#   'challenge',
#   'megan',
#   'batoon',
#   'youtube',
#   'challenges',
#   'refinery'],
#  ['scores', 'biggest', 'horror', 'opening', 'ever', 'movie', 'talk'],
#  ['easy', 'magic', 'tricks', 'anyone'],
#  ['winch', 'bot', 'scanlime'],
#  ['essential',
#   'phone',
#   'drop',
#   'test',
#   'titanium',
#   'ceramic',
#   'vs',
#   'gravity'],
#  ['bts', 'singing', 'closer', 'chainsmokers'],
#  ['bioshock', 'made'],
#  ['parcour', 'part', 'road', 'olympics', 'andri', 'ragettli'],
#  ['moment', 'silence', 'national', 'memorial', 'museum'],
#  ['try', 'fall', 'haul', 'fashion', 'drugstore', 'makeup', 'ingrid', 'nilsen'],
#  ['san', 'cisco', 'distance', 'official', 'music', 'video'],
#  ['wet', 'book', 'rescue'],
#  ['viral',
#   'instagram',
#   'makeup',
#   'trends',
#   'wavy',
#   'eyebrows',
#   'tested',
#   'alisha',
#   'marie'],
#  ['injured',
#   'explosion',
#   'london',
#   'subway',
#   'train',
#   'parsons',
#   'green',
#   'underground',
#   'station',
#   'time'],
#  ['shakira', 'perro', 'fiel', 'official', 'video', 'ft', 'nicky', 'jam'],
#  ['insane', 'full', 'house', 'theory', 'might', 'true'],
#  ['fuller', 'house', 'season', 'official', 'trailer', 'hd', 'netflix'],
#  ['burning',
#   'device',
#   'filmed',
#   'tube',
#   'carriage',
#   'parsons',
#   'green',
#   'station'],
#  ['reasons', 'buy', 'iphone', 'x'],
#  ['funny', 'ask'],
#  ['jennifer', 'lawrence', 'got', 'bar', 'fight', 'budapest'],
#  ['shape', 'water', 'red', 'band', 'trailer'],
#  ['colbert', 'reveals', 'letterman', 'taught'],
#  ['facing', 'anxiety'],
#  ['money', 'world', 'official', 'trailer', 'hd'],
#  ['nf', 'let', 'audio'],
#  ['butt', 'complaints', 'australia'],
#  ['mother', 'movie', 'review'],
#  ['triplet', 'flow', 'took', 'rap'],
#  ['fall', 'essentials', 'need', 'beauty', 'lifestyle', 'casey', 'holmes'],
#  ['boyfriend', 'buys', 'outfits'],
#  ['drawing',
#   'weird',
#   'australian',
#   'phrases',
#   'feat',
#   'draw',
#   'jazza',
#   'mate'],
#  ['ordered', 'first', 'free', 'things', 'wish'],
#  ['harry',
#   'potter',
#   'theory',
#   'voldemort',
#   'full',
#   'tri',
#   'wizard',
#   'cup',
#   'plan'],
#  ['yo', 'gotti', 'ft', 'nicki', 'minaj', 'rake'],
#  ['department'],
#  ['land', 'orbital', 'rocket', 'booster'],
#  ['miley', 'cyrus', 'see', 'live', 'lounge'],
#  ['day', 'apple', 'new', 'iphone', 'x'],
#  ['life', 'hate', 'september', 'act', 'full', 'frontal', 'tbs'],
#  ['aaron', 'carter', 'hiv', 'test', 'results', 'revealed'],
#  ['parsons', 'green', 'human', 'stampede', 'bbc', 'news'],
#  ['machine', 'gun', 'kelly', 'let', 'go'],
#  ['chris', 'young', 'losing', 'sleep'],
#  ['dillon', 'francis', 'hurts', 'body', 'spicy', 'wings', 'hot', 'ones'],
#  ['hello',
#   'world',
#   'meet',
#   'baby',
#   'girl',
#   'alexis',
#   'olympia',
#   'ohanian',
#   'jr'],
#  ['niall', 'horan', 'much', 'ask', 'audio'],
#  ['trapped', 'snake', 'tank', 'pt', 'ft', 'boa', 'constrictor'],
#  ['fenty', 'beauty', 'hot', 'hmmm', 'jackie', 'aina'],
#  ['back', 'school', 'outfit', 'ideas', 'grace', 'helbig'],
#  ['bts', '방탄소년단', 'dna', 'official', 'teaser'],
#  ['game',
#   'thrones',
#   'conquest',
#   'rebellion',
#   'animated',
#   'history',
#   'seven',
#   'kingdoms',
#   'clip'],
#  ['lego',
#   'ultimate',
#   'collectors',
#   'series',
#   'millennium',
#   'falcon',
#   'review'],
#  ['fall', 'boy', 'last', 'real', 'ones'],
#  ['really',
#   'buy',
#   'shoes',
#   'ebay',
#   'yeezys',
#   'valentino',
#   'straight',
#   'copies'],
#  ['turned', 'space', 'seconds', 'without', 'spacesuit'],
#  ['carly', 'rae', 'jepsen', 'cut', 'feeling'],
#  ['adelaine',
#   'morin',
#   'hello',
#   'yellow',
#   'bedroom',
#   'makeover',
#   'omg',
#   'coming',
#   'mr',
#   'kate'],
#  ['road', 'live'],
#  ['pennywise', 'glam', 'halloween', 'makeup', 'tutorial'],
#  ['nyfw', 'limo', 'rides', 'big', 'unboxing', 'carli', 'bybel'],
#  ['cassini', 'last', 'looks', 'saturn'],
#  ['blindfold', 'gymnastics', 'challenge'],
#  ['car', 'hits', 'cyclist', 'east', 'flatbush'],
#  ['jiggly',
#   'cheese',
#   'cake',
#   'redo',
#   'reading',
#   'mean',
#   'inspiring',
#   'comments'],
#  ['thomas', 'rhett', 'bobby', 'bones', 'surprise', 'fans', 'life', 'changes'],
#  ['london', 'police', 'investigate', 'explosion', 'train'],
#  ['bill', 'skarsgård', 'demonic', 'smile', 'conan', 'tbs'],
#  ['julien', 'baker', 'appointments', 'official', 'video'],
#  ['norm', 'macdonald', 'comic', 'genius'],
#  ['welcome', 'baby', 'taika'],
#  ['bella',
#   'hadid',
#   'roughs',
#   'security',
#   'roughing',
#   'female',
#   'photog',
#   'tmz'],
#  ['official', 'us', 'find', 'voice', 'trailer', 'disney', 'pixar', 'coco'],
#  ['alexa', 'guess', 'number'],
#  ['eat', 'much'],
#  ['lana', 'del', 'rey', 'white', 'mustang', 'official', 'video'],
#  ['sarah', 'huckabee', 'sanders', 'jemele', 'hill'],
#  ['impossible', 'big', 'mac', 'challenge', 'destroyed'],
#  ['close', 'look', 'victoria', 'beckham', 'make', 'products'],
#  ['people', 'awesome', 'girls', 'edition'],
#  ['dua', 'lipa', 'x', 'gallant', 'room', 'episode'],
#  ['nicki',
#   'minaj',
#   'surprises',
#   'nas',
#   'celebrating',
#   'rd',
#   'birthday',
#   'party',
#   'swizz',
#   'beatz'],
#  ['aly', 'aj', 'take'],
#  ['soy',
#   'pablo',
#   'extended',
#   'trailer',
#   'bad',
#   'lip',
#   'reading',
#   'narcos',
#   'netflix',
#   'original',
#   'series'],
#  ['x', 'ambassadors', 'ahead'],
#  ['hell', 'yes'],
#  ['miley', 'cyrus', 'talks', 'vmas', 'music', 'america', 'rainbowland'],
#  ['iphone', 'x', 'introducing', 'iphone', 'x', 'apple'],
#  ['grace', 'vanderwaal', 'beginning'],
#  ['victoria', 'beckham', 'collection', 'hot'],
#  ['optical', 'illusions'],
#  ['toni', 'braxton', 'deadwood', 'audio'],
#  ['teyana', 'taylor', 'tells', 'boob', 'surgery', 'says', 'kanye', 'back'],
#  ['get', 'ready', 'ft', 'old', 'friend'],
#  ['spiked', 'sea', 'urchin'],
#  ['year', 'vlogging', 'logan', 'paul', 'changed', 'youtube', 'forever'],
#  ['lore', 'official', 'trailer', 'hd', 'amazon', 'video'],
#  ['apple', 'iphone', 'x', 'first', 'look'],
#  ['adam',
#   'ruins',
#   'everything',
#   'messed',
#   'story',
#   'hawaii',
#   'became',
#   'state',
#   'trutv'],
#  ['dl', 'hughley', 'espn', 'jemele', 'hill', 'controversy'],
#  ['kelly', 'clarkson', 'talks', 'american', 'idol', 'dr', 'luke', 'interview'],
#  ['kph',
#   'water',
#   'rocket',
#   'trike',
#   'ǀ',
#   'kph',
#   'second',
#   'g',
#   'ǀ',
#   'rider',
#   'françois',
#   'gissy'],
#  ['grace', 'journey', 'digital', 'exclusive'],
#  ['behind',
#   'scenes',
#   'subaru',
#   'wrx',
#   'sti',
#   'type',
#   'ra',
#   'nbr',
#   'special',
#   'nurburgring'],
#  ['year',
#   'old',
#   'bodybuilder',
#   'william',
#   'reed',
#   'sees',
#   'color',
#   'first',
#   'time'],
#  ['maggie', 'gyllenhaal', 'taylor', 'swift', 'scarf', 'wwhl'],
#  ['red', 'velvet', 'cupcakes', 'made', 'kevin', 'durant'],
#  ['fast', 'furious', 'parody', 'goodbye', 'scene'],
#  ['day', 'longest', 'flight', 'history'],
#  ['inside', 'world', 'smelliest', 'factory'],
#  ['riverdale', 'motive', 'trailer', 'cw'],
#  ['iphone', 'x', 'parody'],
#  ['cream', 'cheese', 'stuffed', 'pumpkin', 'muffins', 'episode'],
#  ['response'],
#  ['opposition', 'w', 'jordan', 'klepper', 'opposing', 'resistance', 'phoenix'],
#  ['learn', 'stack', 'dice', 'learn', 'quick'],
#  ['hand', 'hand', 'benefit', 'hurricane', 'relief', 'mtv'],
#  ['enough', 'milk', 'breastfeeding', 'journey', 'tips', 'momtember'],
#  ['need', 'talk'],
#  ['weezer', 'beach', 'boys'],
#  ['bell', 'theorem', 'quantum', 'venn', 'diagram', 'paradox'],
#  ['hudson', 'moore', 'wanna', 'love', 'official', 'music', 'video'],
#  ['angelica',
#   'hale',
#   'year',
#   'old',
#   'singer',
#   'blows',
#   'audience',
#   'away',
#   'america',
#   'got',
#   'talent'],
#  ['fergie', 'already', 'know', 'ft', 'nicki', 'minaj'],
#  ['xx', 'hold', 'jamie', 'xx', 'remix'],
#  ['best', 'mic', 'sounds', 'week', 'sound', 'fx', 'nfl', 'films'],
#  ['disaster', 'artist', 'official', 'trailer', 'hd'],
#  ['tori', 'kelly', 'luis', 'fonsi', 'hallelujah', 'hand', 'hand', 'benefit'],
#  ['weight', 'update', 'weeks', 'post', 'surgery', 'pounds'],
#  ['world', 'walker', 'trailer'],
#  ['mores',
#   'alaska',
#   'italian',
#   'meringue',
#   'plus',
#   'special',
#   'announcement',
#   'cupcake',
#   'jemma'],
#  ['r', 'hurts', 'good', 'audio'],
#  ['eat', 'melbourne'],
#  ['husker', 'du', 'sorry', 'somehow'],
#  ['iphone', 'x', 'iphone', 'hands'],
#  ['mystery',
#   'van',
#   'helping',
#   'self',
#   'driving',
#   'cars',
#   'communicate',
#   'people',
#   'autonomy',
#   'ford'],
#  ['internet', 'made', 'cry'],
#  ['stephen',
#   'smith',
#   'calls',
#   'espn',
#   'nbarank',
#   'garbage',
#   'carmelo',
#   'anthony',
#   'rating',
#   'first',
#   'take',
#   'espn'],
#  ['best', 'floyd', 'mayweather', 'interview', 'awkward', 'puppets'],
#  ['depeche', 'mode', 'cover'],
#  ['full', 'face', 'first', 'impressions', 'fenty', 'beauty', 'faced', 'ysl'],
#  ['couple', 'first', 'merch'],
#  ['iphone', 'x', 'face', 'id', 'unlock', 'fail'],
#  ['boyfriend', 'buys', 'outfits'],
#  ['want', 'eat'],
#  ['king', 'krule', 'dum', 'surfer'],
#  ['honest', 'trailers', 'mummy'],
#  ['attacked', 'police', 'dog'],
#  ['iphone', 'x', 'vs', 'iphone', 'hands', 'difference'],
#  ['honest', 'college', 'tour'],
#  ['iphone', 'x', 'hands', 'live', 'apple', 'event'],
#  ['kid', 'rock', 'tennessee', 'mountain', 'top', 'lyrics'],
#  ['stone',
#   'sour',
#   'rose',
#   'red',
#   'violent',
#   'blue',
#   'song',
#   'dumb',
#   'official',
#   'video'],
#  ['million', 'subscribers', 'struggling', 'still', 'smiling'],
#  ['sarah',
#   'sanders',
#   'espn',
#   'jemele',
#   'hill',
#   'committed',
#   'fireable',
#   'offense'],
#  ['riverdale', 'scenes', 'madelaine', 'petsch'],
#  ['houston',
#   'attorney',
#   'tony',
#   'buzbee',
#   'drops',
#   'tank',
#   'river',
#   'oaks',
#   'blvd'],
#  ['downsizing', 'official', 'trailer', 'paramount', 'pictures'],
#  ['replay', 'day', 'hot', 'rod', 'drag', 'week', 'byron', 'dragway'],
#  ['nerf', 'bow', 'trick', 'shots', 'dude', 'perfect'],
#  ['juicy', 'chicken', 'breast', 'suck', 'cooking', 'episode'],
#  ['enter', 'shikari', 'rabble', 'rouser', 'official', 'promo', 'video'],
#  ['crowder', 'prove', 'ft', 'kb'],
#  ['radiohead', 'lift'],
#  ['getting', 'conversation', 'language', 'actually', 'speak', 'well'],
#  ['imagine', 'dragons', 'whatever', 'takes', 'version', 'lyric', 'vide'],
#  ['tyrese', 'slamsthe', 'rock', 'fast', 'furious', 'spinoff', 'sju'],
#  ['james', 'tw', 'please', 'keep', 'loving'],
#  ['demi',
#   'lovato',
#   'performing',
#   'little',
#   'help',
#   'friends',
#   'hand',
#   'hand',
#   'september'],
#  ['superfruit', 'reacts', 'teens', 'react', 'superfruit'],
#  ['actually', 'plane', 'future'],
#  ['answering', 'questions', 'qandgay'],
#  ['damage',
#   'hurricane',
#   'irma',
#   'magic',
#   'kingdom',
#   'walt',
#   'disney',
#   'world'],
#  ['x', 'extreme', 'spicy', 'noodle', 'car', 'ride', 'cried', 'ranz', 'niana'],
#  ['blind', 'people', 'describe', 'beauty'],
#  ['get', 'ellen', 'ellen', 'show', 'show'],
#  ['sorry', 'racial', 'slurs', 'finnish'],
#  ['selena', 'gomez', 'hand', 'hand'],
#  ['big',
#   'jb',
#   'weld',
#   'diamond',
#   'coring',
#   'bit',
#   'workshop',
#   'fabricobblin',
#   'fun'],
#  ['doom', 'wolfenstein', 'switch', 'announcement', 'trailer'],
#  ['cassini', 'burns', 'saturn', 'grand', 'finale'],
#  ['hurricane', 'irma', 'death', 'toll', 'rises', 'cuba'],
#  ['commuter', 'teaser', 'trailer', 'movieclips', 'trailers'],
#  ['queen', 'live', 'aid', 'part', 'high', 'quality'],
#  ['更なるフィット感を追求するねこ', 'maru', 'wishes', 'fitting', 'feeling'],
#  ['everything', 'wrong', 'alien', 'covenant', 'minutes', 'less'],
#  ['vlogtember', 'nyc', 'running', 'around', 'heyclaire'],
#  ['mystery', 'caboodle'],
#  ['alex', 'aiono', 'trinidad', 'cardona', 'feel', 'like', 'falling', 'audio'],
#  ['usher',
#   'blake',
#   'shelton',
#   'stand',
#   'hand',
#   'hand',
#   'benefit',
#   'hurricane',
#   'relief',
#   'mtv'],
#  ['san', 'cisco', 'distance', 'official', 'music', 'video'],
#  ['wore', 'new', 'york', 'fashion', 'week'],
#  ['genesis', 'ibex', 'cassini', 'scishow', 'talk', 'show'],
#  ['lexus', 'lc', 'costs'],
#  ['jennifer', 'lawrence', 'tore', 'diaphragm', 'filming', 'mother'],
#  ['jumping', 'impossible', 'shapes'],
#  ['lany', 'super', 'far', 'official', 'video'],
#  ['joe', 'arpaio', 'last', 'week', 'tonight', 'john', 'oliver', 'hbo'],
#  ['air', 'irma', 'catastrophic', 'wrath', 'undeniable'],
#  ['season', 'preview', 'white', 'people', 'renovating', 'houses'],
#  ['im', 'gonna', 'father', 'things', 'got', 'awkward'],
#  ['drowning', 'power', 'rooster', 'teeth', 'animated', 'adventures'],
#  ['apple', 'watch', 'series', 'hands'],
#  ['fenty',
#   'beauty',
#   'pro',
#   'filt',
#   'r',
#   'foundation',
#   'review',
#   'nyma',
#   'tang',
#   'thedarkestshade'],
#  ['bonnie', 'mckee', 'thorns'],
#  ['blueborne', 'android', 'take', 'demo'],
#  ['make', 'real', 'kingsman', 'umbrella', 'gun'],
#  ['make',
#   'lloyd',
#   'new',
#   'lego',
#   'ninjago',
#   'movie',
#   'cake',
#   'yolanda',
#   'gampp',
#   'cake'],
#  ['fenty', 'beauty', 'rihanna', 'review', 'wear', 'test'],
#  ['lemon',
#   'praises',
#   'chunky',
#   'cnn',
#   'reporter',
#   'facing',
#   'irma',
#   'wrath',
#   'nothing',
#   'wrong',
#   'little',
#   'curve'],
#  ['day', 'beach', 'mayor', 'steve', 'fulop'],
#  ['delicious', 'chocolate', 'cupcakes', 'minutes', 'scran', 'line'],
#  ['mondeo', 'driver', 'desperate', 'overtake', 'get', 'stuck', 'traffic'],
#  ['try', 'guys', 'get', 'makeovers', 'high', 'school', 'girls'],
#  ['jake', 'paulers', 'song', 'official', 'music', 'video'],
#  ['insane', 'full', 'house', 'theory', 'might', 'true'],
#  ['shakira', 'perro', 'fiel', 'official', 'video', 'ft', 'nicky', 'jam'],
#  ['pure', 'uncut', 'holo', 'drugz', 'nails'],
#  ['injured',
#   'explosion',
#   'london',
#   'subway',
#   'train',
#   'parsons',
#   'green',
#   'underground',
#   'station',
#   'time'],
#  ['rick', 'morty', 'rick', 'changed'],
#  ['mac', 'mini', 'exist'],
#  ['bf', 'gf', 'prank', 'wars', 'begun'],
#  ['vampy', 'fall', 'look', 'new', 'makeup', 'nicole', 'guerriero'],
#  ['fuller', 'house', 'season', 'official', 'trailer', 'hd', 'netflix'],
#  ['cast', 'really', 'look'],
#  ['perfect', 'proposal', 'lele', 'pons', 'anwar', 'jibawi'],
#  ['need', 'talk'],
#  ['live',
#   'stream',
#   'canelo',
#   'vs',
#   'golovkin',
#   'official',
#   'weigh',
#   'friday',
#   'sept',
#   'pm',
#   'et',
#   'pm',
#   'pt'],
#  ['reasons', 'buy', 'iphone', 'x'],
#  ['match', 'highlights', 'watford', 'v', 'man', 'city'],
#  ['new',
#   'burts',
#   'bees',
#   'goodness',
#   'glows',
#   'foundation',
#   'first',
#   'impression',
#   'demo',
#   'days',
#   'foundation'],
#  ['diy', 'fruit', 'flavored', 'cupcakes'],
#  ['full', 'canelo', 'alvarez', 'vs', 'gennady', 'golovkin', 'weigh', 'espn'],
#  ['burning',
#   'device',
#   'filmed',
#   'tube',
#   'carriage',
#   'parsons',
#   'green',
#   'station'],
#  ['miley', 'cyrus', 'see', 'live', 'lounge'],
#  ['playing', 'magic', 'makeup', 'nikkietutorials'],
#  ['conanisrael', 'sneak', 'peak', 'gal', 'gadot', 'conan', 'tbs'],
#  ['jennifer', 'lawrence', 'got', 'bar', 'fight', 'budapest'],
#  ['scam', 'shein', 'try', 'haul'],
#  ['funny', 'ask'],
#  ['colbert', 'reveals', 'letterman', 'taught'],
#  ['shape', 'water', 'red', 'band', 'trailer'],
#  ['nf', 'let', 'audio'],
#  ['butt', 'complaints', 'australia'],
#  ['triplet', 'flow', 'took', 'rap'],
#  ['mother', 'movie', 'review'],
#  ['money', 'world', 'official', 'trailer', 'hd'],
#  ['watermelon', 'freakshake', 'cupcakes', 'scran', 'line'],
#  ['facing', 'anxiety'],
#  ['words', 'chile', 'joanna', 'rants'],
#  ['yo', 'gotti', 'ft', 'nicki', 'minaj', 'rake'],
#  ['kingsman',
#   'golden',
#   'circle',
#   'dog',
#   'hunt',
#   'clip',
#   'th',
#   'century',
#   'fox'],
#  ['boyfriend', 'buys', 'outfits'],
#  ['drawing',
#   'weird',
#   'australian',
#   'phrases',
#   'feat',
#   'draw',
#   'jazza',
#   'mate'],
#  ['harry',
#   'potter',
#   'theory',
#   'voldemort',
#   'full',
#   'tri',
#   'wizard',
#   'cup',
#   'plan'],
#  ['cassini', 'last', 'looks', 'saturn'],
#  ['john', 'wick', 'able', 'hold', 'avengers', 'sju'],
#  ['parsons', 'green', 'human', 'stampede', 'bbc', 'news'],
#  ['niall', 'horan', 'much', 'ask', 'audio'],
#  ['ordered', 'first', 'free', 'things', 'wish'],
#  ['day', 'apple', 'new', 'iphone', 'x'],
#  ['people', 'awesome', 'girls', 'edition'],
#  ['department'],
#  ['aaron', 'carter', 'hiv', 'test', 'results', 'revealed'],
#  ['london', 'police', 'investigate', 'explosion', 'train'],
#  ['lego',
#   'ultimate',
#   'collectors',
#   'series',
#   'millennium',
#   'falcon',
#   'review'],
#  ['land', 'orbital', 'rocket', 'booster'],
#  ['back', 'school', 'outfit', 'ideas', 'grace', 'helbig'],
#  ['carly', 'rae', 'jepsen', 'cut', 'feeling'],
#  ['chris', 'young', 'losing', 'sleep'],
#  ['life', 'hate', 'september', 'act', 'full', 'frontal', 'tbs'],
#  ['jay',
#   'z',
#   'pays',
#   'homage',
#   'hispanic',
#   'culture',
#   'lyrics',
#   'genius',
#   'news'],
#  ['grace', 'vanderwaal', 'beginning'],
#  ['road', 'live'],
#  ['machine', 'gun', 'kelly', 'let', 'go'],
#  ['thomas', 'rhett', 'bobby', 'bones', 'surprise', 'fans', 'life', 'changes'],
#  ['game',
#   'thrones',
#   'conquest',
#   'rebellion',
#   'animated',
#   'history',
#   'seven',
#   'kingdoms',
#   'clip'],
#  ['miley', 'cyrus', 'talks', 'vmas', 'music', 'america', 'rainbowland'],
#  ['fenty', 'beauty', 'hot', 'hmmm', 'jackie', 'aina'],
#  ['dillon', 'francis', 'hurts', 'body', 'spicy', 'wings', 'hot', 'ones'],
#  ['hello',
#   'world',
#   'meet',
#   'baby',
#   'girl',
#   'alexis',
#   'olympia',
#   'ohanian',
#   'jr'],
#  ['bts', '방탄소년단', 'dna', 'official', 'teaser'],
#  ['fall', 'boy', 'last', 'real', 'ones'],
#  ['trapped', 'snake', 'tank', 'pt', 'ft', 'boa', 'constrictor'],
#  ['alexa', 'guess', 'number'],
#  ['really',
#   'buy',
#   'shoes',
#   'ebay',
#   'yeezys',
#   'valentino',
#   'straight',
#   'copies'],
#  ['everytime', 'beat', 'drops', 'chainsmokers', 'ranz', 'niana'],
#  ['adelaine',
#   'morin',
#   'hello',
#   'yellow',
#   'bedroom',
#   'makeover',
#   'omg',
#   'coming',
#   'mr',
#   'kate'],
#  ['pennywise', 'glam', 'halloween', 'makeup', 'tutorial'],
#  ['nyfw', 'limo', 'rides', 'big', 'unboxing', 'carli', 'bybel'],
#  ['fall', 'essentials', 'need', 'beauty', 'lifestyle', 'casey', 'holmes'],
#  ['norm', 'macdonald', 'comic', 'genius'],
#  ['julien', 'baker', 'appointments', 'official', 'video'],
#  ['lethal', 'bizzle', 'teaches', 'dame', 'judi', 'dench', 'rap'],
#  ['blindfold', 'gymnastics', 'challenge'],
#  ['jiggly',
#   'cheese',
#   'cake',
#   'redo',
#   'reading',
#   'mean',
#   'inspiring',
#   'comments'],
#  ['behind',
#   'scenes',
#   'subaru',
#   'wrx',
#   'sti',
#   'type',
#   'ra',
#   'nbr',
#   'special',
#   'nurburgring'],
#  ['dua', 'lipa', 'x', 'gallant', 'room', 'episode'],
#  ['welcome', 'baby', 'taika'],
#  ['turned', 'space', 'seconds', 'without', 'spacesuit'],
#  ['official', 'us', 'find', 'voice', 'trailer', 'disney', 'pixar', 'coco'],
#  ['optical', 'illusions'],
#  ['close', 'look', 'victoria', 'beckham', 'make', 'products'],
#  ['strangest',
#   'sights',
#   'cassini',
#   'saw',
#   'postcards',
#   'saturn',
#   'npr',
#   'skunk',
#   'bear'],
#  ['kph',
#   'water',
#   'rocket',
#   'trike',
#   'ǀ',
#   'kph',
#   'second',
#   'g',
#   'ǀ',
#   'rider',
#   'françois',
#   'gissy'],
#  ['eat', 'much'],
#  ['lana', 'del', 'rey', 'white', 'mustang', 'official', 'video'],
#  ['x', 'ambassadors', 'ahead'],
#  ['bella',
#   'hadid',
#   'roughs',
#   'security',
#   'roughing',
#   'female',
#   'photog',
#   'tmz'],
#  ['impossible', 'big', 'mac', 'challenge', 'destroyed'],
#  ['gregg', 'sulkin', 'raw', 'word', 'play'],
#  ['jennifer',
#   'lawrence',
#   'new',
#   'horror',
#   'film',
#   'mother',
#   'assault',
#   'today'],
#  ['soy',
#   'pablo',
#   'extended',
#   'trailer',
#   'bad',
#   'lip',
#   'reading',
#   'narcos',
#   'netflix',
#   'original',
#   'series'],
#  ['toni', 'braxton', 'deadwood', 'audio'],
#  ['automatica', 'k', 'robots', 'vs', 'music', 'nigel', 'stanford'],
#  ['hell', 'yes'],
#  ['fast', 'furious', 'parody', 'goodbye', 'scene'],
#  ['get', 'ready', 'ft', 'old', 'friend'],
#  ['iphone', 'x', 'introducing', 'iphone', 'x', 'apple'],
#  ['year',
#   'old',
#   'bodybuilder',
#   'william',
#   'reed',
#   'sees',
#   'color',
#   'first',
#   'time'],
#  ['teyana', 'taylor', 'tells', 'boob', 'surgery', 'says', 'kanye', 'back'],
#  ['victoria', 'beckham', 'collection', 'hot'],
#  ['aly', 'aj', 'take'],
#  ['kelly', 'clarkson', 'talks', 'american', 'idol', 'dr', 'luke', 'interview'],
#  ['viral',
#   'video',
#   'uk',
#   'geese',
#   'bodyguards',
#   'help',
#   'hedgehog',
#   'cross',
#   'road'],
#  ['spiked', 'sea', 'urchin'],
#  ['car', 'hits', 'cyclist', 'east', 'flatbush'],
#  ['year', 'vlogging', 'logan', 'paul', 'changed', 'youtube', 'forever'],
#  ['adam',
#   'ruins',
#   'everything',
#   'messed',
#   'story',
#   'hawaii',
#   'became',
#   'state',
#   'trutv'],
#  ['apple', 'iphone', 'x', 'first', 'look'],
#  ['inside', 'world', 'smelliest', 'factory'],
#  ['weezer', 'beach', 'boys'],
#  ['nicki',
#   'minaj',
#   'surprises',
#   'nas',
#   'celebrating',
#   'rd',
#   'birthday',
#   'party',
#   'swizz',
#   'beatz'],
#  ['cream', 'cheese', 'stuffed', 'pumpkin', 'muffins', 'episode'],
#  ['riverdale', 'motive', 'trailer', 'cw'],
#  ['red', 'velvet', 'cupcakes', 'made', 'kevin', 'durant'],
#  ['lore', 'official', 'trailer', 'hd', 'amazon', 'video'],
#  ['learn', 'stack', 'dice', 'learn', 'quick'],
#  ['jacob', 'banks', 'unknown', 'audio'],
#  ['day', 'longest', 'flight', 'history'],
#  ['opposition', 'w', 'jordan', 'klepper', 'opposing', 'resistance', 'phoenix'],
#  ['hand', 'hand', 'benefit', 'hurricane', 'relief', 'mtv'],
#  ['dl', 'hughley', 'espn', 'jemele', 'hill', 'controversy'],
#  ['response'],
#  ['iphone', 'x', 'parody'],
#  ['alex', 'aiono', 'trinidad', 'cardona', 'feel', 'like', 'falling', 'audio'],
#  ['xx', 'hold', 'jamie', 'xx', 'remix'],
#  ['enough', 'milk', 'breastfeeding', 'journey', 'tips', 'momtember'],
#  ['craig', 'david', 'heartline', 'audio'],
#  ['hudson', 'moore', 'wanna', 'love', 'official', 'music', 'video'],
#  ['need', 'talk'],
#  ['bell', 'theorem', 'quantum', 'venn', 'diagram', 'paradox'],
#  ['r', 'hurts', 'good', 'audio'],
#  ['tori', 'kelly', 'luis', 'fonsi', 'hallelujah', 'hand', 'hand', 'benefit'],
#  ['grace', 'journey', 'digital', 'exclusive'],
#  ['angelica',
#   'hale',
#   'year',
#   'old',
#   'singer',
#   'blows',
#   'audience',
#   'away',
#   'america',
#   'got',
#   'talent'],
#  ['depeche', 'mode', 'cover'],
#  ['weight', 'update', 'weeks', 'post', 'surgery', 'pounds'],
#  ['fergie', 'already', 'know', 'ft', 'nicki', 'minaj'],
#  ['disaster', 'artist', 'official', 'trailer', 'hd'],
#  ['eat', 'melbourne'],
#  ['maggie', 'gyllenhaal', 'taylor', 'swift', 'scarf', 'wwhl'],
#  ['best', 'mic', 'sounds', 'week', 'sound', 'fx', 'nfl', 'films'],
#  ['internet', 'made', 'cry'],
#  ['emmalyn', 'self', 'care', 'official', 'music', 'video'],
#  ['iphone', 'x', 'iphone', 'hands'],
#  ['full', 'face', 'first', 'impressions', 'fenty', 'beauty', 'faced', 'ysl'],
#  ['king', 'krule', 'dum', 'surfer'],
#  ['couple', 'first', 'merch'],
#  ['james', 'tw', 'please', 'keep', 'loving'],
#  ['best', 'floyd', 'mayweather', 'interview', 'awkward', 'puppets'],
#  ['iphone', 'x', 'face', 'id', 'unlock', 'fail'],
#  ['mores',
#   'alaska',
#   'italian',
#   'meringue',
#   'plus',
#   'special',
#   'announcement',
#   'cupcake',
#   'jemma'],
#  ['boyfriend', 'buys', 'outfits'],
#  ['want', 'eat'],
#  ['film',
#   'theory',
#   'ariel',
#   'related',
#   'hercules',
#   'disney',
#   'connected',
#   'universe'],
#  ['million', 'subscribers', 'struggling', 'still', 'smiling'],
#  ['husker', 'du', 'sorry', 'somehow'],
#  ['honest', 'college', 'tour'],
#  ['iphone', 'x', 'vs', 'iphone', 'hands', 'difference'],
#  ['stone',
#   'sour',
#   'rose',
#   'red',
#   'violent',
#   'blue',
#   'song',
#   'dumb',
#   'official',
#   'video'],
#  ['honest', 'trailers', 'mummy'],
#  ['enter', 'shikari', 'rabble', 'rouser', 'official', 'promo', 'video'],
#  ['léon', 'believe', 'us', 'audio'],
#  ['kid', 'rock', 'tennessee', 'mountain', 'top', 'lyrics'],
#  ['mystery',
#   'van',
#   'helping',
#   'self',
#   'driving',
#   'cars',
#   'communicate',
#   'people',
#   'autonomy',
#   'ford'],
#  ['world', 'walker', 'trailer'],
#  ['crowder', 'prove', 'ft', 'kb'],
#  ['iphone', 'x', 'hands', 'live', 'apple', 'event'],
#  ['get', 'ellen', 'ellen', 'show', 'show'],
#  ['riverdale', 'scenes', 'madelaine', 'petsch'],
#  ['sarah',
#   'sanders',
#   'espn',
#   'jemele',
#   'hill',
#   'committed',
#   'fireable',
#   'offense'],
#  ['radiohead', 'lift'],
#  ['replay', 'day', 'hot', 'rod', 'drag', 'week', 'byron', 'dragway'],
#  ['nerf', 'bow', 'trick', 'shots', 'dude', 'perfect'],
#  ['grant', 'hart', 'e', 'p', 'version'],
#  ['juicy', 'chicken', 'breast', 'suck', 'cooking', 'episode'],
#  ['imagine', 'dragons', 'whatever', 'takes', 'version', 'lyric', 'vide'],
#  ['x', 'extreme', 'spicy', 'noodle', 'car', 'ride', 'cried', 'ranz', 'niana'],
#  ['cassini', 'burns', 'saturn', 'grand', 'finale'],
#  ['downsizing', 'official', 'trailer', 'paramount', 'pictures'],
#  ['superfruit', 'reacts', 'teens', 'react', 'superfruit'],
#  ['demi',
#   'lovato',
#   'performing',
#   'little',
#   'help',
#   'friends',
#   'hand',
#   'hand',
#   'september'],
#  ['everything', 'wrong', 'alien', 'covenant', 'minutes', 'less'],
#  ['getting', 'conversation', 'language', 'actually', 'speak', 'well'],
#  ['blind', 'people', 'describe', 'beauty'],
#  ['building',
#   'high',
#   'capacity',
#   'battery',
#   'bank',
#   'using',
#   'diy',
#   'tab',
#   'welder'],
#  ['actually', 'plane', 'future'],
#  ['lany', 'super', 'far', 'official', 'video'],
#  ['air', 'irma', 'catastrophic', 'wrath', 'undeniable'],
#  ['big',
#   'jb',
#   'weld',
#   'diamond',
#   'coring',
#   'bit',
#   'workshop',
#   'fabricobblin',
#   'fun'],
#  ['sorry', 'racial', 'slurs', 'finnish'],
#  ['vlogtember', 'nyc', 'running', 'around', 'heyclaire'],
#  ...]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Embedding, LSTM

# X_train 단어들을 토대로 정수 인덱스 설정
# 빈도수가 높은 것부터 4000개만 정수 인덱스로 변환하겠다

tokenizer = Tokenizer(2155)
tokenizer.fit_on_texts(X_train)

#위에서 설정된 정수 인덱스를 토대로 변환
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

print("# int_encoding done")
# Out:
# # int_encoding done

# %%
print(len(tokenizer.word_index))
# Out:
# 2230

# %%
max_length = 0
for data in X_train:
  if max_length < len(data):
    max_length = len(data)

print(max_length)
# Out:
# 19

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_len = 19
X_train = pad_sequences(X_train, maxlen = max_len)
X_test = pad_sequences(X_test, maxlen = max_len)

# %%
# model = Sequential()
# model.add(Embedding(2155, 10))
# model.add(LSTM(10))
# model.add(Dense(1, activation = 'relu'))

# %%
# model.compile(loss="cate_crossentropy", optimizer = 'adam', metrics=['acc'])
# model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10)

# %%
model = Sequential()
model.add(Embedding(5000, 32))
model.add(LSTM(32))
model.add(Dense(1, activation='relu'))

model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=30)
# Out:
# Epoch 1/30
# 60/60 [==============================] - 1s 9ms/step - loss: 0.2737 - mae: 0.4988 - val_loss: 0.2599 - val_mae: 0.5017
# Epoch 2/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.2477 - mae: 0.4925 - val_loss: 0.2550 - val_mae: 0.5004
# Epoch 3/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.2314 - mae: 0.4699 - val_loss: 0.2642 - val_mae: 0.4980
# Epoch 4/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.2194 - mae: 0.4409 - val_loss: 0.3309 - val_mae: 0.4973
# Epoch 5/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.2132 - mae: 0.4236 - val_loss: 0.2801 - val_mae: 0.4993
# Epoch 6/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.2090 - mae: 0.4115 - val_loss: 0.2753 - val_mae: 0.5011
# Epoch 7/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.2047 - mae: 0.4049 - val_loss: 0.2888 - val_mae: 0.5007
# Epoch 8/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.2019 - mae: 0.3970 - val_loss: 0.2834 - val_mae: 0.5021
# Epoch 9/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1995 - mae: 0.3941 - val_loss: 0.2865 - val_mae: 0.5044
# Epoch 10/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1988 - mae: 0.3952 - val_loss: 0.2952 - val_mae: 0.5049
# Epoch 11/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1972 - mae: 0.3909 - val_loss: 0.2914 - val_mae: 0.5043
# Epoch 12/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1964 - mae: 0.3877 - val_loss: 0.2979 - val_mae: 0.5045
# Epoch 13/30
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1951 - mae: 0.3856 - val_loss: 0.2948 - val_mae: 0.5056
# Epoch 14/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1948 - mae: 0.3860 - val_loss: 0.2955 - val_mae: 0.5056
# Epoch 15/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1932 - mae: 0.3815 - val_loss: 0.2924 - val_mae: 0.5054
# Epoch 16/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1923 - mae: 0.3810 - val_loss: 0.2951 - val_mae: 0.5057
# Epoch 17/30
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1920 - mae: 0.3801 - val_loss: 0.2974 - val_mae: 0.5053
# Epoch 18/30
# 60/60 [==============================] - 0s 7ms/step - loss: 0.1912 - mae: 0.3797 - val_loss: 0.3059 - val_mae: 0.5067
# Epoch 19/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1905 - mae: 0.3776 - val_loss: 0.3031 - val_mae: 0.5064
# Epoch 20/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1908 - mae: 0.3769 - val_loss: 0.2991 - val_mae: 0.5065
# Epoch 21/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1903 - mae: 0.3768 - val_loss: 0.2916 - val_mae: 0.5052
# Epoch 22/30
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1892 - mae: 0.3789 - val_loss: 0.3068 - val_mae: 0.5062
# Epoch 23/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1890 - mae: 0.3740 - val_loss: 0.3060 - val_mae: 0.5065
# Epoch 24/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1881 - mae: 0.3729 - val_loss: 0.2965 - val_mae: 0.5061
# Epoch 25/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1883 - mae: 0.3743 - val_loss: 0.3081 - val_mae: 0.5069
# Epoch 26/30
# 60/60 [==============================] - 0s 7ms/step - loss: 0.1887 - mae: 0.3742 - val_loss: 0.3036 - val_mae: 0.5067
# Epoch 27/30
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1879 - mae: 0.3707 - val_loss: 0.2962 - val_mae: 0.5069
# Epoch 28/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1869 - mae: 0.3742 - val_loss: 0.3139 - val_mae: 0.5087
# Epoch 29/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1871 - mae: 0.3693 - val_loss: 0.2968 - val_mae: 0.5064
# Epoch 30/30
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1863 - mae: 0.3732 - val_loss: 0.3198 - val_mae: 0.5104

# %%
sentence = input()
#토큰화
token_stc = sentence.split()
#정수 인코딩
encode_stc = tokenizer.texts_to_sequences([token_stc])
#패딩
pad_stc = pad_sequences(encode_stc, maxlen=50)

score = model.predict(pad_stc)
print(score)
