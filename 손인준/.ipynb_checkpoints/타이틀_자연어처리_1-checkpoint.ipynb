# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re
import time
import warnings
warnings.filterwarnings('ignore')
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline  
from scipy import stats

from collections import Counter
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words
import re
import nltk
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# # 영어 dataset에서 title만 추출해서 자연어처리를 위한 전처리를 하자

# %%
#데이터 불러오기
us_videos = pd.read_csv(r'C:\Users\injoo\광주 인공지능 사관학교\로테이션\자연어처리&추천시스템 김준태\미니프로젝트 데이터\USvideos.csv', error_bad_lines=False)
# Out:
# b'Skipping line 2401: expected 11 fields, saw 21\nSkipping line 2800: expected 11 fields, saw 21\nSkipping line 5297: expected 11 fields, saw 12\nSkipping line 5299: expected 11 fields, saw 12\nSkipping line 5300: expected 11 fields, saw 12\nSkipping line 5301: expected 11 fields, saw 12\n'

# %% [markdown]
# ### 이전과 마찬가지로 중복되는 동영상들은 제거해주자

# %%
# 우선 float64인 date의 datatype을 바꿔주자
us_videos['date'] = us_videos['date'].apply(lambda x: str(x).replace(".", "-"))
us_videos['date'] = us_videos['date'].apply(lambda x: '2017-'+str(x))
us_videos['date'] = pd.to_datetime(us_videos['date'], format='%Y-%d-%m')
result = us_videos.drop_duplicates('video_id', keep='last').values
duplicates_removed = pd.DataFrame(result, columns = us_videos.columns)

# %%
only_title = duplicates_removed['title']

# %%
title_data = only_title

# %% [markdown]
# ## Title만 가진 데이터를 추출했으니 전처리를 해주자

# %%
#단어 아니면 삭제
title_data = title_data.str.replace("[^\w]", " ")
#혹시나 공백이 있으면
title_data= title_data.replace('', np.nan)

#결측치 있으면 모두 제거
title_data = title_data.dropna(how='any')

# %%
titles_list = []
#숫자 제거가 덜 되었다. 하나하나 돌면서 숫자도 제거해주자. 단 단어랑 붙어 있는 숫자는 살려주자
for title in title_data:
    title = title.split(" ")
    word_without_number = []
    for word in title:
        output = re.sub(r'\d+', '', word)
        if output != '':
            word_without_number.append(output.lower())
    titles_list.append(word_without_number)

# %% [markdown]
# ### Stopwords 제거 (NLTK corpus stopwords 이용)

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

stop_words = set(stopwords.words('english')) 
cleaned_titles = []
words_list = []
for title in titles_list:
    tmp_list = []
    for word in title:
        if word not in stop_words:
            tmp_list.append(word)
            words_list.append(word)
    cleaned_titles.append(tmp_list)

# %%
for title in cleaned_titles:
    print(title)
# Out:
# ['gigi', 'hadid', 'loses', 'high', 'heel', 'fashion', 'week', 'walks', 'like', 'pro', 'tmz']
# ['hillary', 'clinton', 'really', 'thinks']
# ['gwyneth', 'paltrow', 'crashes', 'james', 'goop', 'magazine', 'rant']
# ['gold', 'diva', 'macarons', 'scran', 'line']
# ['iphone', 'x', 'hands']
# ['best', 'features', 'coming', 'iphones']
# ['sloane', 'stephens', 'jokes', 'million', 'check', 'inspires', 'keep', 'playing', 'espn']
# ['one', 'america', 'appeal', 'friends', 'texas']
# ['anvil', 'vs', 'watermelon', 'pyramid', 'crazy', 'drop', 'tests']
# ['welcome', 'jurassic', 'falls']
# ['bernie', 'sanders', 'tries', 'say', 'something', 'nice', 'trump']
# ['sam', 'smith', 'good', 'goodbyes', 'official', 'audio']
# ['update', 'problem', 'chemo', 'pills']
# ['kids', 'shows', 'honest', 'life']
# ['search', 'history', 'say']
# ['nerf', 'meets', 'call', 'duty', 'gun', 'game', 'first', 'person', 'k']
# ['g', 'eazy', 'limit', 'audio', 'ft', 'ap', 'rocky', 'cardi', 'b']
# ['rutgers', 'falls', 'eastern', 'michigan']
# ['florida', 'weather', 'cameras', 'hurricane', 'irma', 'cameras', 'across', 'florida']
# ['alias', 'grace', 'official', 'trailer', 'hd', 'netflix']
# ['dating', 'advice', 'ever', 'need']
# ['home', 'movie', 'review']
# ['fifth', 'harmony', 'deliver']
# ['janet', 'jackson', 'performs', 'dammn', 'baby', 'get', 'lonely', 'live', 'state', 'world', 'tour']
# ['jordan', 'peele', 'spike', 'lee', 'team', 'movie', 'black', 'cop', 'infiltrated', 'kkk']
# ['zayn', 'dusk', 'till', 'dawn', 'ft', 'sia']
# ['orlando', 'braces', 'hurricane', 'irma']
# ['nicholas', 'hamilton', 'chosen', 'jacobs', 'play', 'raw', 'whisper', 'challenge']
# ['green', 'day', 'dumb', 'die', 'official', 'lyric', 'video']
# ['hailee', 'steinfeld', 'alesso', 'ft', 'florida', 'georgia', 'line', 'watt', 'let', 'go', 'official', 'audio']
# ['kelly', 'clarkson', 'love', 'soft', 'official', 'video']
# ['harry', 'potter', 'theory', 'history', 'hagrid', 'wand']
# ['hurricanes', 'irma', 'jose', 'katia']
# ['thomas', 'rhett', 'sweetheart', 'static', 'video']
# ['suburbicon', 'trailer']
# ['live', 'footage', 'hurricane', 'irma', 'destroys', 'maho', 'beach', 'cam', 'st', 'maarten']
# ['avenged', 'sevenfold', 'tears', 'go']
# ['acting', 'real', 'childhood', 'stories', 'part']
# ['taylor', 'swift', 'presents', 'see', 'taylor']
# ['american', 'horror', 'story', 'cult', 'bee', 'hive']
# ['lecrae', 'hammer', 'time', 'dance', 'visual', 'ft', 'k', 'phew']
# ['small', 'hands', 'samsung', 'galaxy', 'note', 'review']
# ['online', 'shopping', 'haul', 'shopaholic']
# ['liza', 'koshy', 'dream', 'office', 'makeover', 'omg', 'coming', 'mr', 'kate']
# ['rhab', 'quintino', 'official', 'video']
# ['things', 'need', 'know', 'kittens', 'simon', 'cat']
# ['watch', 'live', 'satellite', 'images', 'hurricane', 'irma', 'evacuation', 'orders', 'place', 'florida', 'time']
# ['gaga', 'five', 'foot', 'two', 'press', 'conference', 'festival']
# ['colin', 'cloud', 'mind', 'reader', 'predicts', 'tweets', 'america', 'got', 'talent']
# ['fifth', 'harmony', 'like']
# ['apple', 'watch', 'series', 'hands', 'live', 'apple', 'event']
# ['chargers', 'vs', 'broncos', 'nfl', 'week', 'game', 'highlights']
# ['problem', 'phones']
# ['jimmy', 'kimmel', 'talks', 'kristen', 'bell', 'orlando', 'hurricane', 'irma']
# ['made', 'dad', 'cry', 'story', 'comeback', 'competition']
# ['hours', 'movies', 'whose', 'timelines', 'add']
# ['surveying', 'hurricane', 'irma', 'damage', 'southwest', 'florida']
# ['live', 'tracking', 'hurricane', 'irma']
# ['japan', 'ominous', 'dancing', 'cats', 'disaster', 'followed']
# ['rick', 'morty', 'character', 'studies', 'rick', 'rick']
# ['tracking', 'hurricane', 'irma']
# ['derealisation', 'depersonalisation']
# ['hurricane', 'irma', 'makes', 'landfall', 'florida', 'keys', 'powerful', 'category', 'today']
# ['testing', 'weird', 'puppy', 'toys', 'puppy', 'cute']
# ['fenty', 'beauty', 'rihanna', 'full', 'review']
# ['hour', 'test', 'cult', 'beauty', 'buys', 'full', 'face', 'first', 'impressions', 'beauty', 'mi']
# ['dried', 'beach', 'bahamas']
# ['hurricane', 'irma', 'category', 'could', 'engergize', 'category', 'msnbc']
# ['life', 'kylie', 'recap', 'season', 'ep', 'e']
# ['galaxy', 'note', 'things', 'first']
# ['irmagerd', 'hurricane', 'candy', 'hard', 'make', 'candy', 'rains']
# ['hurricane', 'irma', 'news', 'bloopers']
# ['hilarious', 'thrift', 'store', 'items']
# ['bbc', 'anchor', 'gets', 'lost', 'camera', 'news', 'blooper']
# ['hurricane', 'irma', 'roars', 'florida', 'keys', 'continues', 'coast']
# ['honda', 'civic', 'small', 'feature', 'never', 'noticed']
# ['knock', 'anthony', 'joshua', 'kubrat', 'pulev', 'roughs', 'offers', 'fight', 'kugan', 'cassius']
# ['served', 'like', 'girl', 'trailer']
# ['gave', 'celebrity', 'hair', 'transformation']
# ['hurricane', 'irma', 'emergency', 'fake', 'interpreter']
# ['check', 'description', 'southern', 'point', 'live', 'webcam']
# ['cal', 'football', 'hc', 'justin', 'wilcox', 'september']
# ['salted', 'egg', 'crab', 'street', 'food', 'tour', 'old', 'airport', 'road', 'hawker', 'center']
# ['nothing', 'thieves', 'sorry', 'stripped', 'back']
# ['us', 'open', 'sloane', 'stephens', 'takes', 'title']
# ['garlic', 'knot', 'chicken', 'alfredo', 'ring']
# ['days', 'timelapse', 'sea', 'k', 'thunderstorms', 'torrential', 'rain', 'busy', 'traffic']
# ['spoiler', 'talk']
# ['killer', 'whales', 'attack', 'minke', 'frozen', 'planet', 'bbc', 'earth']
# ['first', 'tuned', 'run', 'terry', 'mayhugh', 'quarter', 'scale', 'v', 'merlin']
# ['rainbow', 'connection', 'muppets', 'hollywood', 'bowl', 'september', 'hd']
# ['los', 'jugadores', 'de', 'sacachispas', 'entraron', 'vestidos', 'de', 'guerreros', 'vs', 'sarmiento', 'copa', 'argentina']
# ['rami', 'malek', 'como', 'freddie', 'mercury', 'en', 'live', 'aid']
# ['teardown', 'experiments', 'doppler', 'microwave', 'transceiver']
# ['svu', 'opener', 'dedication', 'wmv']
# ['fenty', 'beauty', 'rihanna', 'hit', 'miss', 'jeffree', 'star']
# ['final', 'steps', 'making', 'pyrimethamine', 'daraprim']
# ['stephen', 'king', 'difference']
# ['roasting', 'youtubers', 'nails', 'nail', 'diss']
# ['blake', 'shelton', 'name', 'dogs', 'official', 'music', 'video']
# ['dancing', 'movies', 'supercut', 'vol']
# ['dad', 'builds', 'palace', 'dogs']
# ['game', 'thrones', 'sings', 'look', 'made']
# ['hurricane', 'irma', 'warning', 'sign', 'language']
# ['smartphone', 'challenge']
# ['kmart']
# ['fenty', 'beauty', 'full', 'face', 'beat', 'impressions', 'review']
# ['save', 'seat', 'japan']
# ['cook', 'power', 'hurricane', 'irma']
# ['win', 'australia']
# ['rihanna', 'fenty', 'beauty', 'first', 'impressions', 'full', 'face', 'review', 'dark', 'skin', 'msdebdeb']
# ['steve', 'bannon', 'trump', 'access', 'hollywood', 'tape', 'litmus', 'test']
# ['genres', 'two', 'artists', 'one', 'song', 'voices', 'shape', 'ed', 'sheeran']
# ['kane', 'brown', 'found', 'audio']
# ['buick', 'skyhawk', 'commercial']
# ['nicholls', 'postgame', 'kevin', 'sumlin']
# ['calvin', 'harris', 'hard', 'love', 'official', 'video', 'ft', 'jessie', 'reyez']
# ['jimmy', 'kimmel', 'full', 'interview', 'sean', 'spicer']
# ['iphone', 'plus', 'vs', 'iphone', 'plus', 'worth', 'upgrading']
# ['iphone', 'x', 'iphone']
# ['mother', 'movie', 'review']
# ['jennifer', 'lawrence', 'challenges', 'jimmy', 'axe', 'throwing', 'contest']
# ['iphone', 'x', 'impressions', 'hands']
# ['real', 'reason', 'kill', 'mockingbird', 'became', 'famous']
# ['check', 'hud', 'ben', 'carson', 'hurricanes']
# ['need', 'talking', 'american', 'tail']
# ['action', 'bronson', 'sean', 'evans', 'sandwich', 'showdown', 'judged', 'mario', 'batali', 'sean', 'wild']
# ['galen', 'hooks', 'wait', 'galen', 'hooks', 'film']
# ['hurricane', 'jose', 'advisory']
# ['rudimental', 'sun', 'comes', 'feat', 'james', 'arthur', 'official', 'video']
# ['photograph', 'incredible', 'architecture']
# ['chocolate', 'chip', 'cookie', 'cupcakes', 'nerdy', 'nummies']
# ['harry', 'styles', 'chain', 'fleetwood', 'mac', 'cover', 'live', 'lounge']
# ['obsessed', 'netflix']
# ['willow', 'birthday']
# ['tommy', 'wiseau', 'james', 'franco', 'perfect', 'disaster', 'artist', 'los', 'angeles', 'times']
# ['real', 'clowns', 'creepier', 'pennywise']
# ['things', 'need', 'know', 'pennywise']
# ['blind', 'taste', 'test', 'grace', 'helbig']
# ['iphone', 'x', 'walkthrough', 'animoji', 'face', 'id', 'portrait', 'mode', 'lighting', 'effects']
# ['last', 'week', 'tonight', 'john', 'oliver', 'se', 'sep']
# ['big', 'announcement', 'popscicle']
# ['fall', 'makeup', 'tutorial', 'talk', 'tutorial', 'casey', 'holmes']
# ['fifty', 'shades', 'freed', 'teaser', 'hd']
# ['qb', 'turned', 'psychic', 'tony', 'romo', 'predicts', 'future']
# ['tying', 'shoe']
# ['kanye', 'west', 'graduation', 'changed', 'music', 'genius', 'news']
# ['seafood', 'vs', 'seafood', 'australia']
# ['interview', 'runaway', 'toddler']
# ['fail', 'new', 'estee', 'lauder', 'double', 'wear', 'nude', 'first', 'impression', 'review', 'demo', 'days', 'foundation']
# ['storm', 'chaser', 'battles', 'hurricane', 'irma', 'powerful', 'winds', 'nbc', 'news']
# ['jim', 'carrey', 'sounds', 'icons', 'nyfw', 'e', 'live', 'red', 'carpet']
# ['jim', 'carrey', 'bizarre', 'fashion', 'week', 'interview', 'daily', 'pop', 'e', 'news']
# ['happens', 'two', 'hurricanes', 'collide']
# ['hillary', 'clinton', 'speaks']
# ['kirstin', 'bad', 'weather', 'official', 'video']
# ['creativity', 'gets', 'noticed', 'feat', 'tango', 'squad', 'adidas']
# ['game', 'revealed', 'season', 'episode', 'goodbye', 'kiss']
# ['assume', 'sexuality', 'based', 'first', 'impression', 'tell', 'story']
# ['drone', 'captures', 'aftermath', 'hurricane', 'irma', 'naples', 'florida']
# ['iphone', 'hands', 'overlook', 'big', 'update']
# ['computers', 'compress', 'text', 'huffman', 'coding', 'huffman', 'trees']
# ['constitution', 'spartans']
# ['minelli', 'empty', 'spaces', 'official', 'video', 'ultra', 'music']
# ['larry', 'back', 'nothing', 'changed', 'curb', 'enthusiasm', 'season', 'trailer', 'hbo']
# ['casually', 'explained', 'ii', 'worst', 'could', 'happen']
# ['wolf', 'alice', 'beautifully', 'unconventional']
# ['hurricane', 'size', 'comparison']
# ['bought', 'entire', 'outfit', 'blindfolded']
# ['internet', 'trending', 'dance', 'challenge', 'megan', 'batoon', 'youtube', 'challenges', 'refinery']
# ['scores', 'biggest', 'horror', 'opening', 'ever', 'movie', 'talk']
# ['easy', 'magic', 'tricks', 'anyone']
# ['winch', 'bot', 'scanlime']
# ['essential', 'phone', 'drop', 'test', 'titanium', 'ceramic', 'vs', 'gravity']
# ['bts', 'singing', 'closer', 'chainsmokers']
# ['bioshock', 'made']
# ['parcour', 'part', 'road', 'olympics', 'andri', 'ragettli']
# ['moment', 'silence', 'national', 'memorial', 'museum']
# ['try', 'fall', 'haul', 'fashion', 'drugstore', 'makeup', 'ingrid', 'nilsen']
# ['wet', 'book', 'rescue']
# ['viral', 'instagram', 'makeup', 'trends', 'wavy', 'eyebrows', 'tested', 'alisha', 'marie']
# ['bill', 'skarsgård', 'demonic', 'smile', 'conan', 'tbs']
# ['stephen', 'smith', 'calls', 'espn', 'nbarank', 'garbage', 'carmelo', 'anthony', 'rating', 'first', 'take', 'espn']
# ['attacked', 'police', 'dog']
# ['houston', 'attorney', 'tony', 'buzbee', 'drops', 'tank', 'river', 'oaks', 'blvd']
# ['tyrese', 'slamsthe', 'rock', 'fast', 'furious', 'spinoff', 'sju']
# ['answering', 'questions', 'qandgay']
# ['damage', 'hurricane', 'irma', 'magic', 'kingdom', 'walt', 'disney', 'world']
# ['selena', 'gomez', 'hand', 'hand']
# ['doom', 'wolfenstein', 'switch', 'announcement', 'trailer']
# ['hurricane', 'irma', 'death', 'toll', 'rises', 'cuba']
# ['commuter', 'teaser', 'trailer', 'movieclips', 'trailers']
# ['queen', 'live', 'aid', 'part', 'high', 'quality']
# ['更なるフィット感を追求するねこ', 'maru', 'wishes', 'fitting', 'feeling']
# ['mystery', 'caboodle']
# ['usher', 'blake', 'shelton', 'stand', 'hand', 'hand', 'benefit', 'hurricane', 'relief', 'mtv']
# ['san', 'cisco', 'distance', 'official', 'music', 'video']
# ['wore', 'new', 'york', 'fashion', 'week']
# ['genesis', 'ibex', 'cassini', 'scishow', 'talk', 'show']
# ['lexus', 'lc', 'costs']
# ['jennifer', 'lawrence', 'tore', 'diaphragm', 'filming', 'mother']
# ['jumping', 'impossible', 'shapes']
# ['joe', 'arpaio', 'last', 'week', 'tonight', 'john', 'oliver', 'hbo']
# ['season', 'preview', 'white', 'people', 'renovating', 'houses']
# ['im', 'gonna', 'father', 'things', 'got', 'awkward']
# ['drowning', 'power', 'rooster', 'teeth', 'animated', 'adventures']
# ['apple', 'watch', 'series', 'hands']
# ['fenty', 'beauty', 'pro', 'filt', 'r', 'foundation', 'review', 'nyma', 'tang', 'thedarkestshade']
# ['bonnie', 'mckee', 'thorns']
# ['blueborne', 'android', 'take', 'demo']
# ['make', 'real', 'kingsman', 'umbrella', 'gun']
# ['make', 'lloyd', 'new', 'lego', 'ninjago', 'movie', 'cake', 'yolanda', 'gampp', 'cake']
# ['fenty', 'beauty', 'rihanna', 'review', 'wear', 'test']
# ['lemon', 'praises', 'chunky', 'cnn', 'reporter', 'facing', 'irma', 'wrath', 'nothing', 'wrong', 'little', 'curve']
# ['day', 'beach', 'mayor', 'steve', 'fulop']
# ['delicious', 'chocolate', 'cupcakes', 'minutes', 'scran', 'line']
# ['mondeo', 'driver', 'desperate', 'overtake', 'get', 'stuck', 'traffic']
# ['fuller', 'house', 'season', 'official', 'trailer', 'hd', 'netflix']
# ['full', 'canelo', 'alvarez', 'vs', 'gennady', 'golovkin', 'weigh', 'espn']
# ['fast', 'furious', 'parody', 'goodbye', 'scene']
# ['iphone', 'x', 'introducing', 'iphone', 'x', 'apple']
# ['inside', 'world', 'smelliest', 'factory']
# ['depeche', 'mode', 'cover']
# ['million', 'subscribers', 'struggling', 'still', 'smiling']
# ['mystery', 'van', 'helping', 'self', 'driving', 'cars', 'communicate', 'people', 'autonomy', 'ford']
# ['get', 'ellen', 'ellen', 'show', 'show']
# ['sarah', 'sanders', 'espn', 'jemele', 'hill', 'committed', 'fireable', 'offense']
# ['radiohead', 'lift']
# ['replay', 'day', 'hot', 'rod', 'drag', 'week', 'byron', 'dragway']
# ['nerf', 'bow', 'trick', 'shots', 'dude', 'perfect']
# ['grant', 'hart', 'e', 'p', 'version']
# ['juicy', 'chicken', 'breast', 'suck', 'cooking', 'episode']
# ['cassini', 'burns', 'saturn', 'grand', 'finale']
# ['downsizing', 'official', 'trailer', 'paramount', 'pictures']
# ['superfruit', 'reacts', 'teens', 'react', 'superfruit']
# ['demi', 'lovato', 'performing', 'little', 'help', 'friends', 'hand', 'hand', 'september']
# ['everything', 'wrong', 'alien', 'covenant', 'minutes', 'less']
# ['getting', 'conversation', 'language', 'actually', 'speak', 'well']
# ['blind', 'people', 'describe', 'beauty']
# ['building', 'high', 'capacity', 'battery', 'bank', 'using', 'diy', 'tab', 'welder']
# ['actually', 'plane', 'future']
# ['lany', 'super', 'far', 'official', 'video']
# ['air', 'irma', 'catastrophic', 'wrath', 'undeniable']
# ['big', 'jb', 'weld', 'diamond', 'coring', 'bit', 'workshop', 'fabricobblin', 'fun']
# ['sorry', 'racial', 'slurs', 'finnish']
# ['vlogtember', 'nyc', 'running', 'around', 'heyclaire']
# ['donald', 'glover', 'emmys', 'speech', 'wins', 'outstanding', 'actor', 'comedy']
# ['triplet', 'flow', 'took', 'rap']
# ['nasa', 'mission', 'control', 'live', 'cassini', 'finale', 'saturn']
# ['yo', 'gotti', 'ft', 'nicki', 'minaj', 'rake']
# ['insane', 'clown', 'posse', 'marching', 'washington', 'gang', 'time']
# ['bts', '방탄소년단', 'dna', 'official', 'teaser']
# ['trapped', 'snake', 'tank', 'pt', 'ft', 'boa', 'constrictor']
# ['red', 'velvet', 'cupcakes', 'made', 'kevin', 'durant']
# ['riverdale', 'motive', 'trailer', 'cw']
# ['aly', 'aj', 'take']
# ['best', 'mic', 'sounds', 'week', 'sound', 'fx', 'nfl', 'films']
# ['weight', 'update', 'weeks', 'post', 'surgery', 'pounds']
# ['xx', 'hold', 'jamie', 'xx', 'remix']
# ['internet', 'made', 'cry']
# ['eat', 'melbourne']
# ['tori', 'kelly', 'luis', 'fonsi', 'hallelujah', 'hand', 'hand', 'benefit']
# ['capsela', 'motorized', 'commercial']
# ['grace', 'journey', 'digital', 'exclusive']
# ['full', 'face', 'first', 'impressions', 'fenty', 'beauty', 'faced', 'ysl']
# ['couple', 'first', 'merch']
# ['fergie', 'already', 'know', 'ft', 'nicki', 'minaj']
# ['angelica', 'hale', 'year', 'old', 'singer', 'blows', 'audience', 'away', 'america', 'got', 'talent']
# ['maggie', 'gyllenhaal', 'taylor', 'swift', 'scarf', 'wwhl']
# ['iphone', 'x', 'face', 'id', 'unlock', 'fail']
# ['disaster', 'artist', 'official', 'trailer', 'hd']
# ['enough', 'milk', 'breastfeeding', 'journey', 'tips', 'momtember']
# ['king', 'krule', 'dum', 'surfer']
# ['emmalyn', 'self', 'care', 'official', 'music', 'video']
# ['iphone', 'x', 'iphone', 'hands']
# ['best', 'floyd', 'mayweather', 'interview', 'awkward', 'puppets']
# ['husker', 'du', 'sorry', 'somehow']
# ['mores', 'alaska', 'italian', 'meringue', 'plus', 'special', 'announcement', 'cupcake', 'jemma']
# ['riverdale', 'scenes', 'madelaine', 'petsch']
# ['stone', 'sour', 'rose', 'red', 'violent', 'blue', 'song', 'dumb', 'official', 'video']
# ['hand', 'hand', 'benefit', 'hurricane', 'relief', 'mtv']
# ['crowder', 'prove', 'ft', 'kb']
# ['film', 'theory', 'ariel', 'related', 'hercules', 'disney', 'connected', 'universe']
# ['boyfriend', 'buys', 'outfits']
# ['want', 'eat']
# ['james', 'tw', 'please', 'keep', 'loving']
# ['iphone', 'x', 'vs', 'iphone', 'hands', 'difference']
# ['honest', 'college', 'tour']
# ['kid', 'rock', 'tennessee', 'mountain', 'top', 'lyrics']
# ['enter', 'shikari', 'rabble', 'rouser', 'official', 'promo', 'video']
# ['iphone', 'x', 'hands', 'live', 'apple', 'event']
# ['honest', 'trailers', 'mummy']
# ['imagine', 'dragons', 'whatever', 'takes', 'version', 'lyric', 'vide']
# ['x', 'extreme', 'spicy', 'noodle', 'car', 'ride', 'cried', 'ranz', 'niana']
# ['world', 'walker', 'trailer']
# ['craig', 'david', 'heartline', 'audio']
# ['netflix', 'joke', 'emmys', 'netflix']
# ['treating', 'hurricanes', 'like', 'war', 'zones', 'hurts', 'survivors']
# ['cowboys', 'vs', 'broncos', 'nfl', 'week', 'game', 'highlights']
# ['nick', 'jonas', 'find']
# ['justin', 'theroux', 'weighs', 'argument', 'jennifer', 'aniston', 'best', 'friend']
# ['emmy', 'awards', 'post', 'show', 'tv', 'talk']
# ['let', 'explain', 'happened']
# ['huda', 'beauty', 'natasha', 'denona', 'colourpop', 'eyeshadow', 'palette', 'tested', 'beauty', 'mi', 'refinery']
# ['burning', 'device', 'filmed', 'tube', 'carriage', 'parsons', 'green', 'station']
# ['playing', 'magic', 'makeup', 'nikkietutorials']
# ['colbert', 'reveals', 'letterman', 'taught']
# ['money', 'world', 'official', 'trailer', 'hd']
# ['department']
# ['john', 'wick', 'able', 'hold', 'avengers', 'sju']
# ['dillon', 'francis', 'hurts', 'body', 'spicy', 'wings', 'hot', 'ones']
# ['close', 'look', 'victoria', 'beckham', 'make', 'products']
# ['dropgun', 'little', 'drop', 'official', 'music', 'video']
# ['dua', 'lipa', 'x', 'gallant', 'room', 'episode']
# ['hell', 'yes']
# ['jennifer', 'lawrence', 'new', 'horror', 'film', 'mother', 'assault', 'today']
# ['alexa', 'guess', 'number']
# ['strangest', 'sights', 'cassini', 'saw', 'postcards', 'saturn', 'npr', 'skunk', 'bear']
# ['x', 'ambassadors', 'ahead']
# ['eat', 'much']
# ['big', 'love', 'roman', 'grant', 'sings', 'big', 'rock', 'candy', 'mountain']
# ['supernatural', 'official', 'season', 'trailer', 'cw']
# ['automatica', 'k', 'robots', 'vs', 'music', 'nigel', 'stanford']
# ['car', 'hits', 'cyclist', 'east', 'flatbush']
# ['official', 'us', 'find', 'voice', 'trailer', 'disney', 'pixar', 'coco']
# ['blindfold', 'gymnastics', 'challenge']
# ['get', 'ready', 'ft', 'old', 'friend']
# ['impossible', 'big', 'mac', 'challenge', 'destroyed']
# ['lana', 'del', 'rey', 'white', 'mustang', 'official', 'video']
# ['sarah', 'huckabee', 'sanders', 'jemele', 'hill']
# ['kph', 'water', 'rocket', 'trike', 'ǀ', 'kph', 'second', 'g', 'ǀ', 'rider', 'françois', 'gissy']
# ['torched', 'read', 'harry', 'dean', 'stanton']
# ['optical', 'illusions']
# ['toni', 'braxton', 'deadwood', 'audio']
# ['cream', 'cheese', 'stuffed', 'pumpkin', 'muffins', 'episode']
# ['year', 'old', 'bodybuilder', 'william', 'reed', 'sees', 'color', 'first', 'time']
# ['victoria', 'beckham', 'collection', 'hot']
# ['adam', 'ruins', 'everything', 'messed', 'story', 'hawaii', 'became', 'state', 'trutv']
# ['quick', 'learners', 'high', 'achievers', 'study', 'mathematically', 'precocious', 'youth']
# ['teyana', 'taylor', 'tells', 'boob', 'surgery', 'says', 'kanye', 'back']
# ['galantis', 'rozes', 'girls', 'boys', 'official', 'music', 'video']
# ['soy', 'pablo', 'extended', 'trailer', 'bad', 'lip', 'reading', 'narcos', 'netflix', 'original', 'series']
# ['spiked', 'sea', 'urchin']
# ['learn', 'stack', 'dice', 'learn', 'quick']
# ['weezer', 'beach', 'boys']
# ['day', 'longest', 'flight', 'history']
# ['lore', 'official', 'trailer', 'hd', 'amazon', 'video']
# ['nicki', 'minaj', 'surprises', 'nas', 'celebrating', 'rd', 'birthday', 'party', 'swizz', 'beatz']
# ['léon', 'believe', 'us', 'audio']
# ['apple', 'iphone', 'x', 'first', 'look']
# ['alex', 'aiono', 'trinidad', 'cardona', 'feel', 'like', 'falling', 'audio']
# ['r', 'hurts', 'good', 'audio']
# ['year', 'vlogging', 'logan', 'paul', 'changed', 'youtube', 'forever']
# ['dl', 'hughley', 'espn', 'jemele', 'hill', 'controversy']
# ['hudson', 'moore', 'wanna', 'love', 'official', 'music', 'video']
# ['iphone', 'x', 'parody']
# ['bell', 'theorem', 'quantum', 'venn', 'diagram', 'paradox']
# ['response']
# ['opposition', 'w', 'jordan', 'klepper', 'opposing', 'resistance', 'phoenix']
# ['need', 'talk']
# ['dentist', 'creates', 'new', 'type', 'veneers']
# ['nick', 'jonas', 'find', 'live', 'peppermint', 'club']
# ['kelly', 'clarkson', 'talks', 'american', 'idol', 'dr', 'luke', 'interview']
# ['jacob', 'banks', 'unknown', 'audio']
# ['darci', 'lynne', 'kid', 'ventriloquist', 'sings', 'little', 'help', 'friends', 'america', 'got', 'talent']
# ['jimmy', 'kimmel', 'bill', 'cassidy', 'health', 'care', 'bill']
# ['best', 'friends', 'challenge', 'demi', 'lovato']
# ['either', 'cat', 'goes', 'hot', 'date']
# ['nick', 'peta', 'cha', 'cha', 'dancing', 'stars']
# ['gaga', 'five', 'foot', 'two', 'official', 'trailer', 'hd', 'netflix']
# ['five', 'senses']
# ['james', 'kiss', 'tell', 'time']
# ['donald', 'glover', 'wins', 'emmy', 'award', 'lead', 'actor']
# ['björk', 'gate']
# ['georgia', 'state', 'vs', 'penn', 'state', 'football']
# ['canelo', 'alvarez', 'vs', 'gennady', 'golovkin', 'fight', 'ruled', 'draw', 'sportscenter', 'espn']
# ['emmys', 'red', 'carpet', 'live', 'people', 'entertainment', 'weekly', 'peopletv', 'time']
# ['guy', 'disability', 'sees', 'antiques', 'roadshow', 'highest', 'appraisal', 'episode', 'realizes', 'item']
# ['nerf', 'war', 'worlds', 'largest', 'blanket', 'fort', 'feet']
# ['sperm', 'donor', 'meets', 'children', 'together']
# ['wendy', 'williams', 'responds', 'instagram', 'rant', 'dishes', 'scandalous', 'bikini', 'pics', 'peopletv']
# ['lowe', 'giving', 'workers', 'iron', 'man', 'suits', 'carry', 'lumber']
# ['live', 'stream', 'canelo', 'vs', 'golovkin', 'official', 'weigh', 'friday', 'sept', 'pm', 'et', 'pm', 'pt']
# ['reasons', 'buy', 'iphone', 'x']
# ['jennifer', 'lawrence', 'got', 'bar', 'fight', 'budapest']
# ['apple', 'watch', 'series', 'apple', 'music', 'roll', 'apple']
# ['miley', 'cyrus', 'see', 'live', 'lounge']
# ['words', 'chile', 'joanna', 'rants']
# ['vampy', 'fall', 'look', 'new', 'makeup', 'nicole', 'guerriero']
# ['nf', 'let', 'audio']
# ['tv', 'doctors', 'america', 'even', 'drama']
# ['butt', 'complaints', 'australia']
# ['mother', 'movie', 'review']
# ['new', 'burts', 'bees', 'goodness', 'glows', 'foundation', 'first', 'impression', 'demo', 'days', 'foundation']
# ['watermelon', 'freakshake', 'cupcakes', 'scran', 'line']
# ['people', 'awesome', 'girls', 'edition']
# ['jackie', 'chan', 'gets', 'fences']
# ['funny', 'ask']
# ['scam', 'shein', 'try', 'haul']
# ['feeling', 'superfruit']
# ['facing', 'anxiety']
# ['nasa', 'holds', 'news', 'conference', 'following', 'cassini', 'grand', 'finale']
# ['shape', 'water', 'red', 'band', 'trailer']
# ['everytime', 'beat', 'drops', 'chainsmokers', 'ranz', 'niana']
# ['cassini', 'last', 'looks', 'saturn']
# ['jay', 'z', 'pays', 'homage', 'hispanic', 'culture', 'lyrics', 'genius', 'news']
# ['harry', 'potter', 'theory', 'voldemort', 'full', 'tri', 'wizard', 'cup', 'plan']
# ['drawing', 'weird', 'australian', 'phrases', 'feat', 'draw', 'jazza', 'mate']
# ['niall', 'horan', 'much', 'ask', 'audio']
# ['grace', 'vanderwaal', 'beginning']
# ['lego', 'ultimate', 'collectors', 'series', 'millennium', 'falcon', 'review']
# ['carly', 'rae', 'jepsen', 'cut', 'feeling']
# ['back', 'school', 'outfit', 'ideas', 'grace', 'helbig']
# ['aaron', 'carter', 'hiv', 'test', 'results', 'revealed']
# ['chris', 'young', 'losing', 'sleep']
# ['ordered', 'first', 'free', 'things', 'wish']
# ['viral', 'video', 'uk', 'geese', 'bodyguards', 'help', 'hedgehog', 'cross', 'road']
# ['land', 'orbital', 'rocket', 'booster']
# ['boyfriend', 'buys', 'outfits']
# ['day', 'apple', 'new', 'iphone', 'x']
# ['miley', 'cyrus', 'talks', 'vmas', 'music', 'america', 'rainbowland']
# ['game', 'thrones', 'conquest', 'rebellion', 'animated', 'history', 'seven', 'kingdoms', 'clip']
# ['fall', 'boy', 'last', 'real', 'ones']
# ['road', 'live']
# ['machine', 'gun', 'kelly', 'let', 'go']
# ['fenty', 'beauty', 'hot', 'hmmm', 'jackie', 'aina']
# ['charles', 'bukowski', 'bluebird', 'read', 'harry', 'dean', 'stanton']
# ['life', 'hate', 'september', 'act', 'full', 'frontal', 'tbs']
# ['jiggly', 'cheese', 'cake', 'redo', 'reading', 'mean', 'inspiring', 'comments']
# ['pennywise', 'glam', 'halloween', 'makeup', 'tutorial']
# ['really', 'buy', 'shoes', 'ebay', 'yeezys', 'valentino', 'straight', 'copies']
# ['adelaine', 'morin', 'hello', 'yellow', 'bedroom', 'makeover', 'omg', 'coming', 'mr', 'kate']
# ['london', 'police', 'investigate', 'explosion', 'train']
# ['lethal', 'bizzle', 'teaches', 'dame', 'judi', 'dench', 'rap']
# ['norm', 'macdonald', 'comic', 'genius']
# ['king', 'infomercials', 'sell', 'anything']
# ['parsons', 'green', 'human', 'stampede', 'bbc', 'news']
# ['nyfw', 'limo', 'rides', 'big', 'unboxing', 'carli', 'bybel']
# ['thomas', 'rhett', 'bobby', 'bones', 'surprise', 'fans', 'life', 'changes']
# ['fall', 'essentials', 'need', 'beauty', 'lifestyle', 'casey', 'holmes']
# ['behind', 'scenes', 'subaru', 'wrx', 'sti', 'type', 'ra', 'nbr', 'special', 'nurburgring']
# ['hello', 'world', 'meet', 'baby', 'girl', 'alexis', 'olympia', 'ohanian', 'jr']
# ['bella', 'hadid', 'roughs', 'security', 'roughing', 'female', 'photog', 'tmz']
# ['gregg', 'sulkin', 'raw', 'word', 'play']
# ['julien', 'baker', 'appointments', 'official', 'video']
# ['turned', 'space', 'seconds', 'without', 'spacesuit']
# ['welcome', 'baby', 'taika']
# ['lip', 'sync', 'conversation', 'demi', 'lovato']
# ['hd', 'lindsey', 'stirling', 'mark', 'ballas', 'cha', 'cha', 'cha', 'dancing', 'stars', 'premiere']
# ['harrison', 'ford', 'ryan', 'gosling', 'acting', 'blade', 'running', 'pecs', 'blade', 'runner', 'wired']
# ['emmy', 'fashion', 'review', 'grace', 'helbig']
# ['portable', 'shaving', 'pods', 'let', 'shave', 'anywhere']
# ['facebook', 'pages', 'work']
# ['bf', 'gf', 'prank', 'wars', 'begun']
# ['animal', 'adventure', 'park', 'giraffe', 'cam']
# ['saquon', 'barkley', 'yard', 'touchdown', 'vs', 'georgia', 'state']
# ['crumb', 'trailer']
# ['kingsman', 'golden', 'circle', 'dog', 'hunt', 'clip', 'th', 'century', 'fox']
# ['das', 'acar', 'auf', 'der', 'iaa']
# ['conanisrael', 'sneak', 'peek', 'gal', 'gadot', 'conan', 'tbs']
# ['anvil', 'vs', 'giant', 'office', 'printer', 'drop', 'test']
# ['diy', 'fruit', 'flavored', 'cupcakes']
# ['injured', 'explosion', 'london', 'subway', 'train', 'parsons', 'green', 'underground', 'station', 'time']
# ['unfortunate', 'fortune']
# ['perfect', 'proposal', 'lele', 'pons', 'anwar', 'jibawi']
# ['jimmy', 'kimmel', 'fights', 'back', 'bill', 'cassidy', 'lindsey', 'graham', 'chris', 'christie']
# ['freedom', 'ish', 'speech', 'september', 'act', 'full', 'frontal', 'tbs']
# ['hillary', 'clinton', 'nobody', 'talking', 'contesting', 'election']
# ['marvel', 'punisher', 'official', 'trailer', 'hd', 'netflix']
# ['speak', 'ben', 'stiller', 'fred', 'armisen']
# ['dave', 'franco', 'kumail', 'nanjiani', 'fred', 'armisen', 'answer', 'web', 'searched', 'questions', 'wired']
# ['rachel', 'bryan', 'life', 'bachelorette']
# ['mexico', 'earthquake', 'absolutely', 'horrific', 'images', 'msnbc']
# ['american', 'gothic', 'became', 'icon']
# ['diving', 'sea', 'turtles']
# ['tried', 'step', 'korean', 'skincare', 'routine', 'month']
# ['honest', 'trailers', 'wonder', 'woman']
# ['lecrae', 'whatchu', 'mean', 'audio', 'ft', 'aha', 'gazelle']
# ['macklemore', 'feat', 'kesha', 'good', 'old', 'days']
# ['watch', 'live', 'donald', 'trump', 'gives', 'first', 'speech', 'un', 'general', 'assembly']
# ['kim', 'kardashian', 'west', 'answers', 'ellen', 'burning', 'questions']
# ['handcuffing', 'boyfriend', 'cameron', 'dallas', 'day']
# ['cities']
# ['everything', 'need', 'know', 'last', 'dab', 'hottest', 'sauce', 'hot', 'ones']
# ['wrong', 'movie', 'quotes', 'yiay']
# ['asi', 'se', 'vivió', 'el', 'sismo', 'de', 'en', 'méxico', 'cdmx']
# ['lions', 'vs', 'giants', 'nfl', 'week', 'game', 'highlights']
# ['make', 'fave', 'comfort', 'food', 'cake', 'giant', 'baked', 'potato', 'yolanda', 'gampp', 'cake']
# ['adriana', 'lima', 'gets', 'ready', 'night', 'beauty', 'secrets', 'vogue']
# ['major', 'earthquake', 'hits', 'south', 'mexico', 'city']
# ['hd', 'frankie', 'muniz', 'witney', 'carson', 'foxtrot', 'dancing', 'stars', 'premiere']
# ['ate', 'like', 'kourtney', 'kardashian', 'week']
# ['lipstick', 'changes', 'way', 'talk', 'ft', 'manny', 'mua']
# ['bts', '방탄소년단', 'dna', 'official', 'mv']
# ['st', 'day', 'chemotherapy', 'ucsf']
# ['popular', 'names', 'around', 'world']
# ['apartment', 'vs', 'apartment']
# ['official', 'call', 'duty', 'wwii', 'story', 'trailer']
# ['thor', 'ragnarok', 'trailer', 'nerdist', 'presents']
# ['safiya', 'nygaard', 'smoothie', 'challenge', 'lucie', 'fink', 'youtube', 'challenges', 'refinery']
# ['world', 'destroyer', 'animated', 'movie', 'trailer', 'hd']
# ['childhood', 'stories']
# ['akutaq', 'eskimo', 'ice', 'cream', 'recipe', 'test', 'crisco', 'berries']
# ['blind', 'people', 'describe', 'racism']
# ['avicii', 'lonely', 'together', 'ft', 'rita', 'ora']
# ['weirdest', 'facebook', 'marketplace', 'items', 'game']
# ['preview', 'get', 'board', 'brand', 'new', 'season', 'season', 'last', 'man', 'earth']
# ['eggs', 'baked', 'hash', 'browns', 'gordon', 'ramsay']
# ['game', 'revealed', 'season', 'episode', 'warrior', 'women']
# ['animal', 'survive', 'everyone', 'dies']
# ['rotary', 'jails', 'accidental', 'amputations']
# ['age', 'giant', 'insects']
# ['organizer', 'gives', 'sink', 'space']
# ['bob', 'shoop', 'addresses', 'vols', 'final', 'play', 'florida']
# ['ultimate', 'waterproof', 'drugstore', 'makeup', 'test']
# ['year', 'surprise', 'reaction', 'tyler', 'oakley']
# ['message', 'uc', 'berkeley', 'milo', 'berkeley', 'patriots']
# ['playing', 'golf', 'nintendo', 'switch']
# ['billie', 'eilish', 'watch']
# ['revolt', 'official', 'trailer']
# ['racks', 'kevin', 'durant', 'shooting', 'contest', 'chris', 'mullin']
# ['kevin', 'durant', 'went', 'little', 'far', 'twitter']
# ['zapad', 'russian', 'helicopter', 'kamov', 'ka', 'alligator', 'fail', 'air', 'surface', 'missiles']
# ['full', 'face', 'makeup', 'using', 'hardware', 'tools']
# ['track', 'testing', 'continued']
# ['small', 'doses', 'robbery']
# ['magnum', 'pis', 'booted', 'comerica', 'park']
# ['gr', 'born', 'motorsports篇']
# ['krewella', 'yellow', 'claw', 'new', 'world', 'ft', 'taylor', 'bennett', 'audio']
# ['juggalos', 'march', 'washington']
# ['biggest', 'winners', 'losers', 'emmys', 'sju']
# ['golf', 'club', 'breaks', 'half', 'world', 'long', 'drive', 'championships']
# ['missed', 'emmy', 'awards', 'highlights']
# ['quindar', 'sound']
# ['way', 'get', 'power', 'change', 'forever']
# ['kitchen', 'gadgets', 'put', 'test', 'part']
# ['sterling', 'k', 'brown', 'emmys', 'full', 'backstage', 'speech']
# ['november', 'criminals', 'trailer', 'digital', 'theaters']
# ['diy', 'kinda', 'big', 'oreo', 'cookie']
# ['rock', 'iron']
# ['penn', 'state', 'coach', 'james', 'franklin', 'ices', 'kicker', 'trying', 'break', 'shutout']
# ['lucasfilm', 'listen', 'episode', 'director', 'petition', 'movie', 'talk']
# ['go', 'look', 'using', 'jaclyn', 'hill', 'palette', 'jaclyn', 'hill']
# ['strange', 'spheres', 'higher', 'dimensions', 'numberphile']
# ['dog', 'reunites', 'best', 'friend', 'dodo']
# ['see', 'star', 'studded', 'reaction', 'sean', 'spicer', 'emmys', 'appearance']
# ['keyboard', 'actual', 'keys']
# ['break', 'change', 'opinion', 'gaby', 'allison']
# ['microsoft', 'devcast']
# ['wtf', 'happened', 'emmys', 'etc', 'live']
# ['rio', 'ferdinand', 'defender', 'contender']
# ['top', 'things', 'know', 'hidden', 'secret', 'uses']
# ['bbq', 'grass', 'stroke', 'bubbles', 'hottub', 'car', 'final', 'touches']
# ['love', 'first', 'swipe']
# ['humble', 'parody', 'love', 'song', 'edition']
# ['try', 'guys', 'get', 'makeovers', 'high', 'school', 'girls']
# ['bizarre', 'lava', 'like', 'landslide', 'tears', 'hillside', 'national', 'geographic']
# ['making', 'kylie', 'jenner', 'clothes', 'cheap']
# ['butch', 'jones', 'press', 'conference']
# ['diy', 'queen', 'laurdiy', 'official', 'music', 'video']
# ['emmy', 'fashion', 'roundup', 'sofia', 'vergara', 'jessica', 'biel', 'emmys', 'access', 'hollywood']
# ['bad', 'breath', 'tester', 'wacky', 'ebay', 'products']
# ['emmys', 'red', 'carpet', 'live', 'people', 'entertainment', 'weekly', 'peopletv']
# ['grwm', 'slay', 'grocery', 'store', 'catch']
# ['rick', 'morty', 'rick', 'changed']
# ['clay', 'travis', 'stuns', 'cnn', 'host', 'says', 'believes', 'two', 'things', 'first', 'amendment', 'boobs']
# ['fenty', 'beauty', 'rihanna', 'desi', 'perkins']
# ['need', 'talk']
# ['mac', 'mini', 'exist']
# ['el', 'ridículo', 'penal', 'de', 'teo', 'gutiérrez', 'junior', 'tigres']
# ['faced', 'peaches', 'cream', 'grwm', 'first', 'impressions', 'soothingsista']
# ['match', 'highlights', 'watford', 'v', 'man', 'city']
# ['gin', 'wong', 'faia']
# ['david', 'lynch', 'commencement', 'address', 'mum', 'graduation']
# ['emmys', 'us', 'star', 'sterling', 'k', 'brown', 'says', 'crazy', 'people', 'think', 'sexy']
# ['jake', 'paulers', 'song', 'official', 'music', 'video']
# ['goran', 'dragic', 'luka', 'doncic', 'winning', 'eurobasket', 'gold', 'medal']
# ['pure', 'uncut', 'holo', 'drugz', 'nails']
# ['shakira', 'perro', 'fiel', 'official', 'video', 'ft', 'nicky', 'jam']
# ['sterling', 'k', 'brown', 'rehearse', 'wife', 'e', 'live', 'red', 'carpet']
# ['insane', 'full', 'house', 'theory', 'might', 'true']
# ['cast', 'really', 'look']
# ['marvel', 'punisher', 'surprise', 'netflix', 'promo']
# ['dave', 'franco', 'weed', 'cookie', 'induced', 'panic', 'attack', 'surprise', 'party']
# ['macklemore', 'feat', 'otieno', 'terry', 'levitate']
# ['senator', 'jeff', 'flake', 'health', 'bill', 'responding', 'donors', 'morning', 'joe', 'msnbc']
# ['happened', 'mad', 'cow', 'disease']
# ['super', 'glowy', 'skin', 'makeup', 'foundation', 'ingrid', 'nilsen']
# ['one', 'light', 'official', 'video', 'linkin', 'park']
# ['confession', 'always', 'sweaty', 'hyperhidrosis', 'tips', 'jackie', 'aina']
# ['games', 'cutscenes', 'full', 'voice', 'acting']
# ['fight', 'giants', 'lions', 'fan', 'threw', 'another', 'fan']
# ['host', 'stephen', 'colbert', 'kicks', 'th', 'primetime', 'emmy', 'awards', 'rollicking', 'number']
# ['mexico', 'killed', 'earthquake']
# ['на', 'учениях', 'запад', 'на', 'полигоне', 'в', 'ленобласти', 'боевой', 'вертолет', 'попал', 'ракетами', 'по', 'зрителям']
# ['sam', 'smith', 'good', 'goodbyes', 'official', 'video']
# ['things', 'probably', 'know', 'princess', 'bride']
# ['nickelback', 'rain', 'lyric', 'video']
# ['nick', 'jonas', 'find']
# ['see', 'official', 'trailer', 'theaters', 'october']
# ['nikki', 'artem', 'tango', 'dancing', 'stars']
# ['back', 'uni', 'settling', 'dorm', 'shopping', 'thrifting', 'etc']
# ['terremoto', 'en', 'méxico', 'impactante', 'edificio', 'se', 'desploma']
# ['morrissey', 'spent', 'day', 'bed', 'official', 'lyric', 'video']
# ['atl', 'movie', 'theater', 'preview']
# ['helmer', 'zone']
# ['every', 'high', 'school', 'clique', 'ever']
# ['bad', 'parents']
# ['hurricane', 'maria', 'slams', 'puerto', 'rico', 'latest', 'projections']
# ['leonard', 'cohen', 'leaving', 'table']
# ['xov', 'xwm', 'ເຂ', 'ອນນ', 'າອ', 'າວ', 'nam', 'ao', 'dam', 'tawg', 'txaus', 'ntshai', 'tiag', 'tiag', 'li', 'nyob', 'xeev', 'khuam', 'laos']
# ['rooster', 'teeth', 'animated', 'adventures', 'macaroni', 'makeout']
# ['two', 'minutes', 'mitch', 'henck', 'bicyclists', 'finally', 'lose', 'one']
# ['emmys', 'stephen', 'colbert', 'monologue', 'featuring', 'sean', 'spicer']
# ['fan', 'requested', 'steampunk', 'cake', 'man', 'cake', 'season', 'premiere', 'joshua', 'john', 'russell']
# ['gonna', 'git', 'sucka', 'trailer']
# ['murder', 'orient', 'express', 'official', 'trailer', 'hd', 'th', 'century', 'fox']
# ['twin', 'swap', 'prank', 'boyfriend', 'merrell', 'twins']
# ['clockwork', 'orange', 'glamorous', 'psychopath']
# ['marvel', 'phase', 'movies', 'want', 'see', 'w', 'max', 'landis', 'movie', 'fights']
# ['team', 'audition', 'tessa', 'brooks', 'nick', 'crompton']
# ['watch', 'first', 'lady', 'melania', 'trump', 'discusses', 'children', 'issues', 'un']
# ['tomb', 'raider', 'trailer', 'review']
# ['q', 'grey', 'meme', 'edition']
# ['earthquake', 'kills', 'dozens', 'central', 'mexico']
# ['special', 'report', 'deadly', 'earthquake', 'hits', 'central', 'mexico', 'nbc', 'news']
# ['rihanna', 'fenty', 'beauty', 'review', 'first', 'impressions']
# ['sia', 'rainbow', 'little', 'pony', 'movie', 'official', 'soundtrack', 'official', 'video']
# ['björk', 'gate']
# ['flight', 'log', 'elevations']
# ['japan', 'vs', 'usa', 'different', 'fast', 'food', 'menus']
# ['puppy', 'first', 'swim']
# ['quake', 'rocks', 'mexico', 'city', 'anniversary', 'earthquake']
# ['giving', 'birth', 'mountain', 'top']
# ['internet', 'crash', 'course', 'computer', 'science']
# ['preserving', 'migration', 'giants', 'guyana', 'arapaima']
# ['merrell', 'twins', 'live']
# ['binomios', 'caninos', 'entre', 'el', 'valor', 'el', 'heroísmo']
# ['sick', 'cyanide', 'happiness', 'minis']
# ['powerful', 'hurricane', 'maria', 'follows', 'deadly', 'storms', 'harvey', 'irma']
# ['iphone', 'vs', 'plus', 'unboxing', 'comparison']
# ['everything', 'obsessed', 'gigi']
# ['adam', 'savage', 'explores', 'science', 'fiction', 'spacesuits', 'fbfx']
# ['вот', 'она', 'настоящая', 'магия']
# ['kuwtk', 'keep', 'kardashian', 'back', 'start', 'e']
# ['cain', 'goes', 'kyrie', 'irving', 'interview', 'responses', 'first', 'take', 'espn']
# ['chain', 'snaps', 'smashes', 'windshield']
# ['ultra', 'boost', 'get', 'less', 'comfortable']
# ['zedd', 'liam', 'payne', 'get', 'low', 'street', 'video']
# ['cardi', 'b', 'bodak', 'yellow', 'feat', 'kodak', 'black', 'remix']
# ['uplifted', 'alex', 'ea', 'sports', 'fifa']
# ['fergie', 'save', 'til', 'morning']
# ['jumanji', 'welcome', 'jungle', 'official', 'trailer']
# ['hidden', 'nes', 'golf', 'game', 'nintendo', 'switch', 'tribute', 'satoru', 'iwata']
# ['everyday', 'makeup', 'routine', 'fleur', 'de', 'force']
# ['first', 'footage', 'wild', 'sand', 'cat', 'kittens']
# ['wonder', 'woman', 'makeup', 'tutorial', 'different', 'ways']
# ['magnitude', 'earthquake', 'rattles', 'mexico', 'city', 'puebla']
# ['buildings', 'sway', 'people', 'panic', 'magnitude', 'earthquake', 'strikes', 'mexico']
# ['princess', 'elizabeth', 'baby', 'clothes', 'appear', 'auction']
# ['diaper', 'bag', 'momtember']
# ['powerful', 'earthquake', 'strikes', 'mexico', 'los', 'angeles', 'times']
# ['tiësto', 'john', 'christian', 'scream', 'official', 'video']
# ['ravens', 'jaguars', 'players', 'kneel', 'national', 'anthem']
# ['g', 'highest', 'note', 'ever', 'hit', 'world', 'georgia', 'brown']
# ['fix', 'life', 'yiay']
# ['wwe', 'yearbook']
# ['grace', 'cast', 'performs', 'theme', 'song', 'lyrics']
# ['round', 'jimmy', 'kimmel', 'health', 'care', 'battle']
# ['jim', 'parsons', 'opens', 'marriage', 'hurry']
# ['invest', 'money', 'questions', 'financial', 'diet']
# ['fergie', 'like']
# ['first', 'look', 'ellen', 'scores', 'deleted', 'scenes', 'taylor', 'swift', 'look', 'made']
# ['donald', 'trump', 'hits', 'john', 'mccain', 'kaepernick', 'north', 'korea', 'wild', 'rally', 'th', 'hour', 'msnbc']
# ['rams', 'vs', 'ers', 'nfl', 'week', 'game', 'highlights']
# ['massive', 'equifax', 'data', 'breach', 'happened']
# ['joji', 'sets', 'face', 'fire', 'eating', 'spicy', 'wings', 'hot', 'ones']
# ['rise', 'fall', 'american', 'fallout', 'shelter']
# ['kygo', 'town', 'ft', 'sasha', 'sloan']
# ['disney', 'villain', 'lipsticks', 'first', 'impression', 'friday']
# ['iphone', 'durability', 'test', 'bend', 'test', 'glass', 'scratch', 'video']
# ['rrrrrrrrrrrrr']
# ['drone', 'carries', 'child', 'terrifying']
# ['grandma', 'short']
# ['simulation']
# ['maggie', 'rogers', 'split', 'stones']
# ['best', 'tv', 'theme', 'song', 'ever', 'heard', 'extinct', 'peter', 'hollens', 'taylor', 'davis', 'devinsupertramp']
# ['would', 'happen', 'never', 'stopped', 'eating']
# ['darci', 'lynne', 'terry', 'fator', 'deliver', 'unbelievable', 'performance', 'america', 'got', 'talent']
# ['epic', 'scam', 'created', 'iconic', 'rock', 'band', 'cracked', 'responds', 'zombies', 'english', 'rock']
# ['spa', 'car', 'drivable', 'hot', 'tub']
# ['barn', 'door', 'scooter', 'wheel', 'first', 'test']
# ['whale', 'swallowed', 'alive']
# ['kids']
# ['tardis', 'first', 'working', 'video']
# ['watsky', 'yes', 'britannia', 'x', 'infinity']
# ['niall', 'horan', 'much', 'ask', 'official']
# ['top', 'things', 'differently']
# ['maine', 'feel']
# ['charles', 'bradley', 'black', 'velvet', 'tribute', 'james', 'brown', 'live']
# ['future', 'could', 'mean', 'delivery', 'straight', 'fridge']
# ['self', 'sabotage']
# ['mumbai', 'rains', 'special', 'water', 'ride', 'mumbai']
# ['mount', 'rushmore', 'weirdest', 'monument']
# ['cake', 'kitchen', 'tour', 'blindfold', 'challenge', 'yolanda', 'gampp', 'cake']
# ['blimping']
# ['chicken', 'fajita', 'soup', 'recipe', 'episode']
# ['questions', 'tracee', 'ellis', 'ross', 'vogue']
# ['jumanji', 'welcome', 'jungle', 'official', 'trailer']
# ['look', 'made', 'taylor', 'mountain']
# ['rob', 'parker', 'weighs', 'charles', 'barkley', 'comments', 'kevin', 'durant', 'court', 'drama', 'herd']
# ['anatomy', 'scene', 'battle', 'sexes']
# ['internationally', 'standard', 'cup', 'tea']
# ['hot', 'damn', 'official', 'lyric', 'video']
# ['dating', 'bisexual']
# ['alvaro', 'morata', 'scores', 'third', 'goal', 'chelsea']
# ['child', 'gets', 'hit', 'todd', 'frazier', 'foul', 'ball', 'line', 'drive', 'yankee', 'stadium', 'yankees', 'v', 'twins']
# ['taking', 'everything', 'literally', 'anwar', 'jibawi']
# ['bini', 'slam', 'dunking', 'basketball', 'bunny', 'meet', 'record', 'breakers']
# ['samsung', 'galaxy', 'note', 'review', 'android']
# ['chemotherapy', 'hit', 'hard', 'first', 'cycle']
# ['dej', 'loaf', 'changes', 'audio']
# ['martin', 'scorsese', 'teaches', 'filmmaking', 'official', 'trailer']
# ['diy', 'bagel', 'bite', 'normal', 'vs', 'giant']
# ['theresa', 'may', 'brexit', 'speech', 'florence', 'watch', 'live']
# ['kb', 'hometeam', 'ft', 'lecrae']
# ['katherine', 'johnson', 'interview', 'sept']
# ['bicycle', 'line', 'guy', 'st', 'attempt']
# ['importance', 'vulnerability']
# ['tomb', 'raider', 'official', 'trailer']
# ['dj', 'snake', 'different', 'way', 'audio', 'ft', 'lauv']
# ['hollyn', 'hola', 'official', 'audio', 'video']
# ['amazing', 'fall', 'autumn', 'themed', 'cupcakes', 'minutes', 'scran', 'line']
# ['trip', 'movie']
# ['good', 'goodbyes', 'sam', 'smith', 'alicia', 'moffet', 'khs', 'cover']
# ['years', 'keeping', 'kardashians', 'kris', 'jenner', 'kim', 'k', 'look', 'back', 'megyn', 'kelly', 'today']
# ['launched', 'brand', 'petite', 'cosmetics']
# ['makeup', 'using', 'fingers', 'challenge']
# ['first', 'makeup', 'tutorial', 'fall', 'vampy', 'glam', 'manny', 'mua']
# ['facts', 'libraries', 'mental_floss', 'list', 'show', 'ep']
# ['flight', 'year', 'trains', 'bridges', 'rapids', 'mountains', 'sunset', 'gapping', 'perching', 'powerlooping']
# ['star', 'wars', 'ruining', 'mystery', 'sju']
# ['r', 'hurts', 'good', 'official', 'video']
# ['gold', 'iphone', 'plus', 'unboxing', 'first', 'impressions']
# ['taylor', 'swift', 'limp', 'bizkit', 'song']
# ['lazy', 'day', 'makeup', 'routine']
# ['peter', 'rabbit', 'trailer']
# ['getting', 'know', 'victoria', 'beckham']
# ['scariest', 'ghost', 'experience']
# ['girlfriend', 'gay', 'friend']
# ['yelle', 'romeo', 'lyric', 'video']
# ['massive', 'earthquake', 'rocks', 'mexico', 'city']
# ['fall', 'makeup', 'tutorial', 'daisy', 'marquez']
# ['like', 'bruno', 'mars', 'rat', 'pack', 'style', 'cover', 'ft', 'lavance', 'colley', 'lee', 'howard']
# ['steel', 'balls', 'grinding', 'balls', 'set', 'technology', 'center', 'countries', 'around', 'world']
# ['wonderstruck', 'official', 'trailer', 'hd', 'amazon', 'studios']
# ['father', 'son', 'moment', 'passed', 'florida', 'bar', 'exam']
# ['unsafe', 'bicycling', 'hands', 'handle', 'bar']
# ['anne', 'marie', 'heavy', 'official', 'audio']
# ['eli', 'lieb', 'kissing', 'tattoos', 'lyric', 'video']
# ['apple', 'watch', 'series', 'lte', 'review']
# ['cook', 'movie', 'official', 'trailer']
# ['ivanka', 'trump', 'talks', 'dr', 'oz', 'voice', 'moderation']
# ['exploring', 'memes', 'boyfriend']
# ['bear', 'russian', 'traffic']
# ['athena', 'laser', 'weapon', 'system', 'defeats', 'unmanned', 'aerial', 'systems']
# ['mad', 'libs', 'fail', 'camila', 'mendes', 'madelaine', 'petsch']
# ['try', 'kendall', 'jenner', 'makeup', 'looks', 'kuwtk', 'anniversary', 'beauty', 'evolution', 'refinery']
# ['things', 'tell', 'grace', 'helbig']
# ['kungs', 'mess', 'official', 'video', 'ft', 'olly', 'murs', 'coely']
# ['everything', 'wrong', 'lego', 'batman', 'movie']
# ['trump', 'nfl', 'comments', 'everything', 'race']
# ['trump', 'attacks', 'protesting', 'athletes', 'closer', 'look']
# ['frankie', 'witney', 'cha', 'cha', 'dancing', 'stars']
# ['camila', 'cabello', 'havana']
# ['lebron', 'james', 'stands', 'calling', 'president', 'trump', 'bum']
# ['put', 'kkw', 'fenty', 'beauty', 'makeup', 'hour', 'test', 'beauty', 'mi', 'refinery']
# ['full', 'cavaliers', 'isaiah', 'thomas', 'press', 'conference', 'nba', 'media', 'day', 'espn']
# ['urban', 'decay', 'velvetizer', 'hell', 'stuff', 'jackie', 'aina']
# ['disney', 'rides', 'get', 'movie', 'w', 'max', 'landis', 'millennial', 'falcon']
# ['men', 'vs', 'women', 'different']
# ['husky', 'dog', 'adopts', 'stray', 'cat', 'saving', 'life', 'dodo', 'comeback', 'kids']
# ['bmw', 'x', 'mission', 'mars', 'virtual', 'testdrive']
# ['multiple', 'incidents', 'vandal', 'receives', 'karmic', 'retribution']
# ['woman', 'brandishing', 'handgun', 'machete', 'threatens', 'people', 'kardashian', 'boutique']
# ['official', 'trailer', 'hd', 'netflix']
# ['bite', 'big', 'creepy', 'spider']
# ['testing', 'expensive', 'af', 'liquid', 'lipsticks', 'jeffree', 'star']
# ['cellos', 'love', 'story', 'official', 'video']
# ['make', 'hater', 'wears', 'fenty', 'day']
# ['worst', 'nap', 'ever', 'lele', 'pons']
# ['iphone', 'iphone', 'plus', 'unboxing', 'first', 'impressions']
# ['apple', 'needs', 'samsung']
# ['jason', 'derulo', 'lucky', 'part', 'official', 'music', 'video']
# ['gardening', 'cody', 'week', 'huge', 'potato', 'harvest']
# ['original', 'prusa', 'mk', 'release']
# ['worth', 'makeup', 'applying', 'high', 'end', 'makeup']
# ['fenty', 'beauty', 'rihanna', 'honest', 'review', 'casey', 'holmes']
# ['rihanna', 'en', 'madrid', 'en', 'fentybeauty']
# ['asking', 'alexandria', 'fire', 'official', 'music', 'video']
# ['gwen', 'stefani', 'make', 'feel', 'like', 'christmas', 'audio', 'ft', 'blake', 'shelton']
# ['getting', 'ready', 'fall']
# ['noah', 'cyrus', 'ft', 'xxxtentacion']
# ['isle', 'dogs', 'official', 'trailer', 'fox', 'searchlight']
# ['official', 'w', 'miel']
# ['lecrae', 'facts', 'audio']
# ['film', 'theory', 'much', 'soul', 'worth', 'fullmetal', 'alchemist', 'brotherhood']
# ['depeche', 'mode', 'heroes', 'highline', 'sessions', 'version']
# ['ryan', 'seacrest', 'mariah', 'carey', 'disastrous', 'nye', 'performance', 'wwhl']
# ['types', 'guys', 'bff', 'dates', 'ft', 'alex', 'wassabi', 'laurdiy']
# ['jackie', 'chan', 'olivia', 'munn', 'answer', 'martial', 'arts', 'questions', 'twitter', 'tech', 'support', 'wired']
# ['macklemore', 'feat', 'kesha', 'good', 'old', 'days', 'official', 'music', 'video']
# ['unga', 'general', 'debate', 'september', 'ireland', 'dpr', 'korea']
# ['back', 'school', 'makeup', 'tutorial', 'easy', 'steps']
# ['dangerous', 'games']
# ['found', 'worst', 'book']
# ['cristiano', 'ronaldo', 'reacts', 'football', 'videos']
# ['hurry', 'superfruit']
# ['burning', 'man', 'film']
# ['true', 'love', 'songify', 'princess', 'bride']
# ['tomb', 'raider', 'future', 'video', 'game', 'movies', 'trailer', 'talk']
# ['walk', 'moon', 'one', 'foot', 'official', 'video']
# ['elders', 'react', 'rupaul', 'drag', 'race']
# ['tamar', 'braxton', 'blind']
# ['matte', 'nail', 'art', 'designs', 'fall']
# ['vegan', 'krispie', 'treats', 'cook', 'megan', 'batoon']
# ['conan', 'invites', 'gal', 'gadot', 'apartment', 'conan', 'tbs']
# ['danielle', 'bradbery', 'hello', 'summer', 'instant', 'grat', 'video']
# ['foo', 'fighters', 'carpool', 'karaoke']
# ['jeremy', 'camp', 'storm']
# ['carlos', 'vives', 'pescaíto', 'official', 'video']
# ['reality', 'real', 'simulation', 'argument']
# ['week', 'learned', 'blacksmith', 'alec', 'steele']
# ['world', 'greatest', 'drag', 'race']
# ['homemade', 'power', 'feeder']
# ['giving', 'dolls', 'tiny', 'makeovers', 'feat', 'shane', 'dawson']
# ['karrueche', 'tran']
# ['uber', 'loses', 'london', 'operating', 'licence', 'bbc', 'news']
# ['things', 'know', 'cat', 'play', 'simon', 'cat', 'logic']
# ...
# ['future', 'medical', 'technology']
# ['teensystep', 'high', 'speed', 'stepper', 'library']
# ['hired', 'cia', 'spy', 'find', 'secret', 'photo']
# ['spider', 'man', 'dominoes']
# ['bruno', 'mars', 'way', 'one', 'voice', 'somos', 'live', 'performance']
# ['thrust', 'ssc', 'still', 'car', 'travel', 'faster', 'speed', 'sound']
# ['whats', 'inside', 'life', 'saving', 'watch']
# ['roy', 'hibbert', 'watch', 'nba', 'previewpalooza', 'ringer']
# ['activist', 'tamika', 'mallory', 'kicked', 'flight', 'seating', 'dispute']
# ['mixing', 'eyeshadows', 'together']
# ['sean', 'hughes', 'comedian']
# ['asmr', 'triggers', 'chris', 'brittany']
# ['wabash', 'kicker', 'takes', 'blocked', 'field', 'goal', 'td']
# ['wear', 'halloween', 'makeup', 'every', 'day', 'beauty', 'mi', 'refinery']
# ['evacuations', 'northern', 'california', 'wildfires', 'kill']
# ['fidget', 'spinner', 'spinning', 'space']
# ['bicycle', 'law', 'breaker']
# ['windowsdevday', 'fluent', 'design']
# ['deep', 'chinese', 'street', 'food', 'tour', 'sichuan', 'china', 'best', 'brain', 'rabbit', 'spicy', 'adventure']
# ['joe', 'jonas', 'sophie', 'turner', 'engaged', 'see', 'ring']
# ['genius', 'leonardo', 'da', 'vinci']
# ['alec', 'benjamin', 'gabriel', 'music', 'video']
# ['piccadilly', 'lights', 'future']
# ['sticker', 'factory', 'stoned', 'mode']
# ['blake', 'lively', 'daughter', 'eats', 'raw', 'meat', 'like', 'white', 'walker']
# ['playing', 'boston', 'celtics', 'jaylen', 'brown', 'must', 'watch']
# ['ayesha', 'curry', 'sending', 'pics', 'feet', 'steph', 'curry']
# ['riding', 'bmx', 'construction', 'site']
# ['u', 'russia', 'building', 'deep', 'space', 'gateway', 'need', 'know']
# ['abby', 'loves', 'proclaimers', 'gonna', 'miles']
# ['new', 'mutants', 'official', 'trailer', 'hd', 'th', 'century', 'fox']
# ['jonathan', 'taylor', 'rips', 'yd', 'td', 'vs', 'purdue']
# ['pomegranates']
# ['alesso', 'anitta', 'official', 'music', 'video']
# ['get', 'bullied', 'lele', 'pons']
# ['harvey', 'weinstein', 'donald', 'trump', 'systemic', 'sexism', 'closer', 'look']
# ['nicole', 'kidman', 'gets', 'flustered', 'talking', 'alexander', 'skarsgård', 'graham', 'norton', 'show']
# ['filling', 'jon', 'batiste']
# ['gram', 'material', 'worth', 'billion', 'dollars']
# ['ironman', 'world', 'championship']
# ['bebe', 'rexha', 'meant', 'feat', 'florida', 'georgia', 'line', 'lyric', 'video']
# ['make', 'pcb', 'lcd', 'mask']
# ['try', 'playing', 'grand', 'theft', 'auto', 'without', 'breaking', 'laws']
# ['legends', 'shield', 'eliminated', 'list']
# ['gordon', 'hayward', 'addresses', 'boston', 'celtics', 'home', 'crowd', 'october']
# ['holo', 'inside', 'holographic', 'scar', 'makeup', 'ft', 'glam', 'gore']
# ['fifth', 'harmony', 'spin', 'trl', 'wheel', 'dance', 'step', 'weekdays', 'pm', 'trl']
# ['pumpkin', 'spice', 'everything']
# ['haters', 'back', 'pants', 'cookies', 'nerdy', 'nummies']
# ['ramen', 'vs', 'ramen', 'japan']
# ['sue', 'perkins', 'delivers', 'superb', 'rant', 'harvey', 'weinstein', 'last', 'leg']
# ['daniel', 'brühl', 'luke', 'evans', 'dakota', 'fanning', 'alienist', 'official', 'trailer', 'tnt']
# ['monster', 'mash', 'pop', 'punk', 'halloween', 'cover', 'jonathan', 'young']
# ['demi', 'lovato', 'plays', 'puppies', 'answering', 'fan', 'questions']
# ['danielle', 'bradbery', 'sway']
# ['apple', 'park', 'october', 'drone', 'tour', 'k']
# ['black', 'panther', 'new', 'trailer', 'finds', 'chadwick', 'boseman', 'taking', 'throne', 'movie', 'talk']
# ['cook', 'perfect', 'rice', 'every', 'time']
# ['mike', 'leach', 'practice', 'oct']
# ['rock', 'cooking', 'tomahawk', 'steak', 'twice', 'baked', 'potato']
# ['easy', 'halloween', 'diys']
# ['space', 'travel', 'possible']
# ['cat', 'vs', 'dog', 'best', 'support', 'class']
# ['rabbit', 'hole', 'learning']
# ['airframe', 'f', 'raptor']
# ['hurricane', 'ophelia', 'thousands', 'lose', 'power', 'storm', 'hits', 'ireland', 'bbc', 'news']
# ['atlas', 'orion', 'like', 'siblings']
# ['rick', 'morty', 'szechuan', 'sauce', 'vs', 'homemade']
# ['cyclopia', 'rare', 'birth', 'defect', 'could', 'help', 'cure', 'cancer']
# ['tiësto', 'ft', 'aloe', 'blacc', 'stargate', 'carry', 'home', 'official', 'video']
# ['uses', 'less', 'gas', 'coasting', 'engine', 'braking']
# ['morning', 'routine', 'fall']
# ['adrian', 'peterson', 'sky', 'limit', 'cardinals', 'vs', 'buccaneers', 'week', 'oct']
# ['pregnancy', 'heartbreak', 'shawn', 'johnson', 'andrew', 'east']
# ['first', 'time', 'flying', 'lele', 'pons']
# ['battlegrounds', 'movie', 'official', 'fake', 'trailer']
# ['ned', 'tries', 'famous', 'soccer', 'trick', 'shots', 'try', 'vlog']
# ['seth', 'rollins', 'dean', 'ambrose', 'react', 'shocking', 'changes', 'tlc', 'main', 'event', 'exclusive', 'oct']
# ['diy', 'ouija', 'nail', 'art', 'clickbait', 'actual', 'nail', 'art', 'emergency']
# ['history', 'jacksfilms', 'feat', 'jacksfilms', 'brief', 'history']
# ['diy', 'halloween', 'pin', 'splosion', 'pizza', 'skulls', 'finger', 'candles', 'bears', 'oh']
# ['candy', 'corn', 'themed', 'pizza', 'w', 'dad']
# ['taylor', 'swift', 'gorgeous', 'lyric', 'video']
# ['college', 'kids', 'react', 'marina', 'diamonds']
# ['age', 'end', 'aging', 'forever']
# ['die']
# ['waste', 'amazon']
# ['rick', 'morty', 'cartoon', 'food', 'taste', 'test']
# ['movie', 'spoilers', 'anwar', 'jibawi']
# ['exotic', 'animals', 'ancient', 'rome']
# ['three', 'bizarre', 'cases', 'alien', 'abductions']
# ['ultra', 'rare', 'velvet', 'worm']
# ['stephen', 'smith', 'outraged', 'lavar', 'ball', 'comments', 'lonzo', 'debut', 'sportscenter', 'espn']
# ['hillary', 'clinton', 'really', 'tried', 'avoid', 'going', 'inauguration', 'graham', 'norton', 'show']
# ['harry', 'styles', 'scares', 'niall', 'horan']
# ['pink', 'addresses', 'christina', 'aguilera', 'beef', 'plead', 'fifth', 'wwhl']
# ['chiefs', 'vs', 'raiders', 'nfl', 'week', 'game', 'highlights']
# ['marshmello', 'silence', 'ft', 'khalid', 'official', 'music', 'video']
# ['official', 'video', 'away', 'manger', 'pentatonix']
# ['thor', 'ragnarok', 'director', 'responds', 'ign', 'comments']
# ['tonya', 'official', 'teaser', 'theaters', 'winter']
# ['academy', 'anecdotes', 'school', 'stories']
# ['lonzo', 'ball', 'completes', 'near', 'triple', 'double', 'lakers', 'win', 'points', 'rebounds', 'assists']
# ['dog', 'vs', 'dog']
# ['kitchen', 'gadgets', 'put', 'test', 'part']
# ['diy', 'taylor', 'swift', 'lwymmd', 'costume', 'grace', 'helbig']
# ['ai', 'need', 'help', 'humans']
# ['jemele', 'hill', 'deserved', 'suspension', 'mad', 'espn', 'tmz', 'sports']
# ['brand', 'new', 'show']
# ['pokemon', 'fan', 'jumps', 'fence', 'white', 'house']
# ['girlfriend', 'picks', 'outfits']
# ['homemade', 'nintendo', 'switch', 'nintimdo', 'rp']
# ['guy', 'sebastian', 'polishes', 'musical', 'disaster']
# ['sauces', 'basics', 'babish']
# ['body', 'amazing', 'pt']
# ['halloween', 'costumes', 'equal']
# ['dressed', 'like']
# ['danisa', 'denmark', 'open', 'badminton', 'sf', 'ws', 'tai', 'tzu', 'ying', 'vs', 'ratchanok', 'intanon']
# ['rita', 'ora', 'anywhere', 'official', 'video']
# ['pokémon', 'go', 'spooky', 'pokémon', 'sableye', 'banette', 'others', 'arrive', 'pokémon', 'go']
# ['tim', 'mcgraw', 'faith', 'hill', 'rest', 'life', 'music', 'video', 'behind', 'scenes', 'tim', 'mcgraw']
# ['explode', 'pumpkin', 'actually']
# ['charlie', 'puth', 'long', 'official', 'video']
# ['harry', 'potter', 'theory', 'sorcerer', 'stone', 'made', 'ft', 'seamus', 'gorman']
# ['ufc', 'fight', 'night', 'gdansk', 'official', 'weigh']
# ['dogs', 'try', 'halloween', 'costumes']
# ['detroit', 'pistons', 'trending', 'eminem', 'surprises', 'lca', 'crowd']
# ['kids', 'try', 'years', 'chicken', 'bon', 'appétit']
# ['pretending', 'klay', 'thompson']
# ['outlander', 'sam', 'heughan', 'caitriona', 'balfe', 'read', 'fan', 'fiction', 'harper', 'bazaar']
# ['katy', 'perry', 'gets', 'stuck', 'air', 'concert', 'nashville']
# ['liam', 'payne', 'bedroom', 'floor', 'lyric', 'video']
# ['marvel', 'punisher', 'official', 'trailer', 'hd', 'netflix']
# ['zach', 'williams', 'fear', 'liar', 'official', 'lyric', 'video']
# ['blue', 'planet', 'ii', 'trailer', 'bbc', 'earth']
# ['martin', 'garrix', 'matisse', 'sadko', 'forever', 'official', 'music', 'video']
# ['kuwtk', 'kourtney', 'khloe', 'kardashian', 'prank', 'sleeping', 'kendall', 'jenner', 'e']
# ['mario', 'got', 'mustache', 'name']
# ['hired', 'taylor', 'swift', 'impersonator', 'day']
# ['pixel', 'durability', 'test', 'scratch', 'bend', 'tested']
# ['kygo', 'kids', 'love', 'audio', 'ft', 'night', 'game']
# ['rachel', 'platten', 'collide', 'audio']
# ['dump', 'cyanide', 'happiness', 'shorts']
# ['chris', 'young', 'blacked', 'audio']
# ['strong', 'official', 'trailer']
# ['halloween', 'look', 'disney', 'villain', 'ursula']
# ['bobi', 'andonov', 'apartment', 'official', 'video']
# ['days', 'diy', 'halloween', 'costumes', 'try', 'living', 'lucie', 'refinery']
# ['eternity', 'calvin', 'klein']
# ['needtobreathe', 'walking', 'water', 'official', 'video']
# ['artie', 'lange', 'raw', 'uncensored', 'eating', 'spicy', 'wings', 'hot', 'ones']
# ['jason', 'aldean', 'keith', 'urban', 'cover', 'back', 'cmt', 'artists', 'year']
# ['hayley', 'kiyoko', 'feelings', 'official', 'video']
# ['confronting', 'first', 'love']
# ['love', 'daddy', 'trailer']
# ['keyshia', 'cole', 'performs', 'incapable']
# ['unmasking', 'california', 'new', 'white', 'supremacists']
# ['baez', 'belts', 'two', 'homers', 'cubs', 'force', 'game']
# ['cnco', 'mamita', 'audio']
# ['star', 'wars', 'last', 'jedi', 'new', 'york', 'comic', 'con', 'experience']
# ['vamps', 'maggie', 'lindemann', 'personal']
# ['jeff', 'bezos', 'smashes', 'bottle', 'champagne', 'perched', 'top', 'giant', 'wind', 'mill']
# ['kelly', 'clarkson', 'meaning', 'life', 'official', 'audio']
# ['talk', 'destiny', 'child', 'michelle', 'williams', 'candid', 'depression', 'suicidal']
# ['white', 'house', 'press', 'briefing', 'chief', 'staff', 'john', 'kelly', 'military', 'deals', 'soldiers', 'death']
# ['capital', 'kings', 'rip', 'feat', 'aaron', 'cole', 'official', 'music', 'video']
# ['loud', 'official', 'music', 'video']
# ['nintendo', 'switch', 'video', 'capture']
# ['venom', 'f', 'unveiling', 'event', 'november', 'pacific']
# ['real', 'reason', 'taxes', 'suck']
# ['cardi', 'b', 'performs', 'bodak', 'yellow']
# ['chewy', 'salted', 'chocolate', 'caramels', 'cupcake', 'jemma']
# ['voice', 'th', 'coach', 'digital', 'exclusive']
# ['jess', 'hilarious', 'exposes', 'hazel', 'e', 'rose', 'burgundy', 'full', 'video']
# ['chi', 'season', 'teaser', 'trailer', 'lena', 'waithe', 'common', 'showtime', 'series']
# ['top', 'clara', 'moments']
# ['rep', 'frederica', 'wilson', 'recounts', 'trump', 'call', 'widow', 'fallen', 'soldier', 'view']
# ['david', 'fincher', 'hijacks', 'eyes']
# ['stranger', 'things', 'gaten', 'matarazzo', 'recaps', 'season', 'minutes', 'teen', 'vogue']
# ['josie', 'pussycats', 'ft', 'cheryl', 'blossom', 'milkshake', 'cover', 'riverdale']
# ['saving', 'iguana', 'four', 'miles', 'offshore']
# ['facts', 'european', 'royalty', 'mental_floss', 'list', 'show', 'ep']
# ['f', 'ing', 'raw', 'kitchen', 'nightmares']
# ['lavar', 'ball', 'answers', 'basketball', 'questions', 'twitter', 'tech', 'support', 'wired']
# ['last', 'minute', 'diy', 'halloween', 'costumes']
# ['mama', 'best', 'female', 'male', 'group', 'nominees']
# ['walmart', 'vs', 'amazon', 'successful', 'company', 'comparison']
# ['curtain', 'falls', 'announcement']
# ['tesla', 'model', 'driving', 'impression', 'ocdetailing']
# ['world', 'first', 'aerial', 'video', 'north', 'korea']
# ['pregnancy', 'terminology', 'dan', 'phil', 'motherhood']
# ['demi', 'lovato', 'simply', 'complicated', 'official', 'documentary']
# ['artist', 'makes', 'amazing', 'fashion', 'illustrations']
# ['giant', 'robot', 'duel']
# ['well', 'boyfriend', 'know', 'riverdale', 'madelaine', 'petsch']
# ['king', 'gizzard', 'lizard', 'wizard', 'crumbling', 'castle']
# ['bitch', 'official', 'movie', 'trailer']
# ['google', 'pixel', 'xl', 'reassembly', 'teardown', 'reverse']
# ['dreams', 'hannah', 'stocking']
# ['kj', 'apa', 'responds', 'riverdale', 'absurd', 'fan', 'theories', 'elle']
# ['dejounte', 'murray', 'full', 'highlights', 'vs', 'timberwolves', 'pts', 'fgm']
# ['burger', 'king', 'bullying', 'jr']
# ['dimitri', 'vegas', 'like', 'mike', 'vs', 'david', 'guetta', 'feat', 'kiiara', 'complicated', 'rhab', 'remix']
# ['mgmt', 'little', 'dark', 'age']
# ['look', 'made', 'looks']
# ['look', 'tiny', 'baby', 'hank']
# ['roussel', 'schenn', 'engage', 'hilarious', 'punchless', 'fight']
# ['celebrating', 'selena', 'quintanilla']
# ['gerard', 'butler', 'ended', 'hospital', 'injecting', 'bee', 'venom', 'lorraine']
# ['daina', 'performing', 'youtubeblack', 'fanfest', 'washington', 'c']
# ['bon', 'iver', 'circle', 'one', 'one']
# ['ashley', 'tisdale', 'wedding', 'tutorial', 'patrickstarrr']
# ['time', 'history', 'time']
# ['want', 'full', 'length']
# ['brett', 'eldredge', 'long', 'way', 'official', 'music', 'video']
# ['fifth', 'harmony', 'perform', 'say', 'love', 'weekdays', 'pm', 'trl']
# ['divided', 'island', 'haiti', 'dr', 'became', 'two', 'worlds']
# ['pinhead', 'halloween', 'costume', 'makeup', 'tutorial', 'w', 'rawbeautykristi']
# ['google', 'pixel', 'unboxing', 'best', 'android', 'features']
# ['full', 'story', 'hywind', 'scotland', 'world', 'first', 'floating', 'wind', 'farm']
# ['adam', 'savage', 'set', 'tour', 'blade', 'runner', 'universe']
# ['niall', 'horan', 'much', 'ask', 'behind', 'scenes']
# ['louis', 'tomlinson', 'like', 'lyric', 'video']
# ['lebron', 'james', 'postgame', 'interview', 'celtics', 'vs', 'cavaliers', 'oct', 'nba', 'season']
# ['morrissey', 'spent', 'day', 'bed', 'official', 'video']
# ['shining', 'twins', 'talk', 'kubrick', 'nicholson', 'remakes']
# ['songs', 'daughter', 'africa', 'toto']
# ['exclusive', 'htc', 'u', 'plus', 'leaked', 'degree', 'renders']
# ['sweet', 'jax', 'tribute', 'cat']
# ['miranda', 'sings', 'listick', 'cupcakes', 'hatersbackoff', 'scran', 'line']
# ['pistons', 'live', 'postgame', 'stan', 'van', 'gundy']
# ['iihs', 'launches', 'new', 'passenger', 'side', 'crash', 'test', 'iihs', 'news']
# ['make', 'gross', 'tacular', 'surprise', 'inside', 'halloween', 'roulette', 'cake', 'yolanda', 'gampp', 'cake']
# ['pawn', 'stars', 'original', 'superman', 'costume', 'season', 'history']
# ['drivers', 'fight', 'crash', 'anderson', 'indiana', 'race']
# ['free', 'predetermined']
# ['parachute', 'fails']
# ['fall', 'makeup', 'tutorial', 'ft', 'patrickstarrr', 'ashley', 'tisdale']
# ['live', 'q', 'birdie', 'brie', 'winston', 'brie', 'confirms', 'wwe', 'return', 'baby']
# ['california', 'musical', 'road', 'sounds', 'terrible']
# ['bought', 'luxury', 'mystery', 'box', 'ebay', 'omg']
# ['cat', 'realised', 'neutered', 'wait', 'n', 'nnewsflare']
# ['boogie', 'wit', 'da', 'hoodie', 'goes', 'sneaker', 'shopping', 'complex']
# ['crane', 'removal', 'timelapse']
# ['logan', 'paul', 'outta', 'hair', 'official', 'music', 'video']
# ['latinos', 'react', 'selena', 'google', 'doodle']
# ['bailey', 'bryan', 'good', 'official', 'cover']
# ['draymond', 'green', 'know', 'serious', 'rockets', 'take', 'defense']
# ['excited', 'dogs', 'car', 'stop', 'howling', 'park', 'dodo']
# ['equifax', 'last', 'week', 'tonight', 'john', 'oliver', 'hbo']
# ['john', 'oliver', 'harvey', 'weinstein']
# ['storm', 'ophelia', 'makes', 'landfall', 'ireland']
# ['jordan', 'lindsay', 'foxtrot', 'dancing', 'stars']
# ['jonathan', 'groff', 'got', 'lead', 'netflix', 'mindhunter']
# ['video', 'games', 'turning', 'movies']
# ['blake', 'lively', 'talks', 'harvey', 'weinstein', 'gma']
# ['john', 'mccain', 'liberty', 'medal', 'speech']
# ['things', 'tell', 'younger', 'self', 'life', 'lessons', 'ingrid', 'nilsen']
# ['vintage', 'shopping', 'first', 'time', 'mess', 'lol']
# ['baby', 'hears', 'first', 'time', 'almost', 'moved', 'tears']
# ['katy', 'perry', 'making', 'swish', 'swish', 'music', 'video', 'ft', 'nicki', 'minaj']
# ['brad', 'paisley', 'heaven', 'south']
# ['monument', 'valley', 'available', 'android', 'ios', 'november', 'th']
# ['kellywise', 'snl']
# ['chris', 'hemsworth', 'mark', 'ruffalo', 'australian', 'interview', 'secret', 'plot', 'twist', 'revealed']
# ['bannon', 'vs', 'mcconnell', 'fight', 'means', 'trump', 'gop']
# ['pixel', 'classic', 'unboxing']
# ['pumpkin', 'spice', 'oreo', 'taste', 'test']
# ['massive', 'sinkholes', 'form']
# ['trump', 'slams', 'clinton', 'defending', 'nfl', 'anthem', 'protests']
# ['lp', 'lost', 'night', 'mckittrick', 'hotel']
# ['tré', 'melvin', 'youtubeblack', 'fanfest', 'washington', 'c']
# ['first', 'cosmic', 'event', 'seen', 'gravitational', 'waves', 'light']

# %% [markdown]
# ### 2364개의 제목들에 대하여 간단한 전처리를 했다. 제목 길이의 분포를 보자

# %%
# 문장 길이 체크
import matplotlib.pyplot as plt

len_titles = []
for title in cleaned_titles:
    len_titles.append(len(title))

plt.hist(len_titles, label='en', alpha=0.7)
plt.legend()
plt.show()

# %%
ser = pd.Series(cleaned_titles)

# %%
ser.to_csv(r'./\cleaned_titles.csv')

# %%
tokenizer = Tokenizer(3000)
tokenizer.fit_on_texts(words_list)
data = tokenizer.texts_to_sequences(cleaned_titles)

# %%
print(len(data))
# Out:
# 2364

# %%
embedded_titles = pd.Series(data)

# %%
embedded_titles.to_csv(r'./\embeded_titles.csv')
