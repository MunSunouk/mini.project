# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Embedding, LSTM
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

import pandas as pd

# %%
embedded_titles = pd.read_csv(r'C:\Users\injoo\광주 인공지능 사관학교\로테이션\자연어처리&추천시스템 김준태\미니프로젝트\Dataset\embeded_titles.csv', error_bad_lines=False)

# %%
embedded_titles = embedded_titles.drop(columns = ['Unnamed: 0'], axis=1)

# %%
embedded_titles
# Out:
#                                                       0
# 0     [1266, 611, 1267, 168, 232, 17, 1268, 29, 467,...
# 1                                        [612, 468, 92]
# 2                                 [1269, 1270, 73, 613]
# 3                                  [614, 1271, 233, 93]
# 4                                         [13, 27, 130]
# ...                                                 ...
# 2359                                             [1086]
# 2360                      [14, 1069, 468, 38, 443, 590]
# 2361                                   [648, 165, 2061]
# 2362                             [2152, 2153, 323, 279]
# 2363                                [6, 193, 1830, 351]
#
# [2364 rows x 1 columns]

# %%
titles = embedded_titles['0']

# %%
titles = list(titles)

# %%
titles
# Out:
# ['[1266, 611, 1267, 168, 232, 17, 1268, 29, 467, 359]',
#  '[612, 468, 92]',
#  '[1269, 1270, 73, 613]',
#  '[614, 1271, 233, 93]',
#  '[13, 27, 130]',
#  '[54, 615, 282]',
#  '[1272, 1273, 1274, 847, 848, 616, 360, 66]',
#  '[74, 151, 169, 1275]',
#  '[1276, 4, 1277, 283, 469, 1278]',
#  '[470, 849]',
#  '[361, 617, 284, 850, 14]',
#  '[111, 94, 75, 285, 1, 8]',
#  '[234, 851, 1279]',
#  '[190, 1280, 286, 47]',
#  '[152, 284]',
#  '[852, 853, 235, 1281, 236, 18, 6, 618, 82]',
#  '[362, 1282, 8, 5, 471, 363]',
#  '[849, 1283]',
#  '[131, 1284, 1285, 20, 48, 1285, 131]',
#  '[83, 1, 3, 15, 63]',
#  '[472, 1286, 76, 84]',
#  '[237, 22, 33]',
#  '[238, 364, 1287]',
#  '[1288, 619, 67, 35, 620, 9, 170, 23, 77]',
#  '[854, 855, 621, 22, 100]',
#  '[622, 623, 624, 473, 5, 474]',
#  '[1289, 20, 48]',
#  '[239, 132, 42]',
#  '[191, 43, 1290, 856, 1, 44, 2]',
#  '[1291, 1292, 857, 5, 131, 365, 93, 1293, 171, 133, 1, 8]',
#  '[101, 625, 36, 1, 2]',
#  '[102, 366, 134, 152]',
#  '[626, 48, 1294]',
#  '[627, 1295, 1296, 2]',
#  '[3]',
#  '[9, 1297, 20, 48, 1298, 628, 475, 287]',
#  '[858, 133]',
#  '[859, 85, 629, 860, 78]',
#  '[86, 240, 861, 172, 86]',
#  '[95, 630, 135, 1299, 862]',
#  '[631, 45, 192, 5, 82]',
#  '[632, 130, 633, 288, 476, 33]',
#  '[289, 477]',
#  '[863, 1300, 864, 1301, 865, 634, 282, 635, 367]',
#  '[1302, 1, 2]',
#  '[37, 84, 79, 636, 637, 112]',
#  '[68, 9, 1303, 20, 48, 866, 131, 45]',
#  '[1304, 638, 867, 173, 136, 103, 1305]',
#  '[1306, 241, 1307, 639, 151, 137, 640]',
#  '[238, 364, 29]',
#  '[64, 68, 153, 130, 9, 64, 193]',
#  '[1308, 4, 868, 38, 17, 18, 49]',
#  '[851, 1309]',
#  '[154, 242, 138, 869, 1289, 20, 48]',
#  '[55, 290, 641, 135, 1310]',
#  '[870, 368, 1311]',
#  '[20, 48, 1312, 871, 131]',
#  '[9, 872, 20, 48]',
#  '[478, 87, 873, 642]',
#  '[113, 243, 113, 113]',
#  '[872, 20, 48]',
#  '[]',
#  '[20, 48, 291, 874, 131, 875, 292, 876, 244]',
#  '[369, 643, 479, 479, 877]',
#  '[69, 21, 155, 16, 33]',
#  '[370, 19, 1299, 21, 644, 16, 96, 6, 156, 21, 293]',
#  '[628]',
#  '[20, 48, 876, 645, 876, 294]',
#  '[47, 371, 878, 25, 174, 114]',
#  '[288, 476, 37, 6]',
#  '[20, 295, 296, 39, 295, 1313]',
#  '[20, 48, 30, 1314]',
#  '[646, 1315, 297, 647]',
#  '[194, 157, 648, 879, 30]',
#  '[20, 48, 131, 875, 1316, 1317]',
#  '[632, 195, 1318]',
#  '[880, 372, 881, 1319, 88]',
#  '[29, 298, 3]',
#  '[1320, 373, 882]',
#  '[20, 48, 1321, 480]',
#  '[848, 9]',
#  '[299, 374, 104]',
#  '[1322, 1323, 375, 97, 77, 158, 1324, 300, 883]',
#  '[481, 482, 70]',
#  '[80, 649, 1272, 1273, 376, 1325]',
#  '[196, 884]',
#  '[301, 1326, 885, 82, 1327, 886]',
#  '[1328, 56]',
#  '[650, 887, 651, 194, 197]',
#  '[6, 888, 652, 1329, 245]',
#  '[483, 302, 889, 104, 15]',
#  '[484, 303, 303, 4, 1330]',
#  '[1331, 1332, 485, 9, 890]',
#  '[1333, 1334, 653]',
#  '[]',
#  '[69, 21, 155, 486, 1335, 50]',
#  '[377, 1336, 175]',
#  '[115, 378, 891]',
#  '[892, 654, 487]',
#  '[304, 655, 246, 305, 1, 10, 2]',
#  '[87, 368, 893, 656]',
#  '[290, 1337, 305]',
#  '[18, 488, 306, 31, 55]',
#  '[20, 48, 1338, 1339, 894]',
#  '[895, 42]',
#  '[]',
#  '[69, 21, 16, 96, 1340, 156, 33]',
#  '[1341, 896, 478]',
#  '[379, 247, 20, 48]',
#  '[657, 658]',
#  '[155, 69, 21, 6, 156, 16, 96, 33, 489, 1342]',
#  '[490, 1343, 14, 897, 302, 1344, 19]',
#  '[173, 659, 74, 116, 1345, 898, 1346]',
#  '[899, 139, 491, 8]',
#  '[1347, 900]',
#  '[901, 492]',
#  '[1348, 296, 36, 1, 2, 5, 660]',
#  '[154, 242, 16, 40, 117, 661]',
#  '[13, 198, 4, 13, 198, 307, 1349]',
#  '[13, 27, 13]',
#  '[380, 22, 33]',
#  '[493, 662, 663, 154, 902]',
#  '[13, 27, 156, 130]',
#  '[85, 1350, 903, 308, 664]',
#  '[848, 665, 904, 626]',
#  '[84, 381, 95, 1351]',
#  '[117, 248, 666, 117, 249]',
#  '[1352, 1353, 1354, 1352, 1353, 159]',
#  '[20, 1294]',
#  '[32, 73, 1, 2]',
#  '[494]',
#  '[309, 905, 176, 382, 383]',
#  '[102, 906, 1355, 495, 105, 9, 496]',
#  '[1356, 63]',
#  '[907]',
#  '[1357, 73, 908, 106, 642, 667, 484, 909, 910]',
#  '[85, 310]',
#  '[37, 84, 79, 310]',
#  '[384, 250, 19, 83, 251]',
#  '[13, 27, 96, 1358, 668, 1359]',
#  '[34, 17, 252, 46, 199, 911]',
#  '[118, 497]',
#  '[57, 7, 24, 56, 24, 498, 669]',
#  '[1360, 107, 15]',
#  '[670, 912, 1307, 160]',
#  '[]',
#  '[1361, 1362, 1363, 499, 10, 671, 30]',
#  '[1364, 4, 1364, 658]',
#  '[40, 913]',
#  '[500, 12, 914, 915, 6, 311, 33, 501, 301, 200]',
#  '[312, 20, 48, 292, 672, 30]',
#  '[502, 916, 385, 1365, 114, 9, 201, 673]',
#  '[502, 916, 674, 232, 17, 40, 1366, 1367, 114, 30]',
#  '[917, 173, 626, 1368]',
#  '[612, 468, 918]',
#  '[313, 1284, 1, 2]',
#  '[157, 1318, 32, 1369]',
#  '[18, 503, 25, 71, 919, 920]',
#  '[6, 311, 314, 135]',
#  '[504, 20, 48, 131]',
#  '[13, 130, 118, 234]',
#  '[1370, 1370]',
#  '[]',
#  '[1, 2, 505, 10]',
#  '[70, 481, 499, 25, 3, 177]',
#  '[1371, 675, 676, 386, 645, 387]',
#  '[677]',
#  '[20, 678]',
#  '[921, 1372, 1373, 922]',
#  '[506, 1374, 192, 42, 923, 1375, 161, 663, 89]',
#  '[507, 924, 630, 1376, 76, 22, 56]',
#  '[178, 679]',
#  '[]',
#  '[1377, 925, 469, 19, 4, 1378]',
#  '[926, 508, 1379]',
#  '[55]',
#  '[78, 300]',
#  '[388, 680, 253]',
#  '[65, 57, 477, 232, 389, 7, 315, 316]',
#  '[681]',
#  '[927, 390, 7, 1380, 509, 928, 682]',
#  '[510, 1381, 1382, 254, 179]',
#  '[115, 94, 391, 66, 929, 372, 6, 140, 66]',
#  '[1383, 392, 119]',
#  '[912, 930, 931, 932]',
#  '[108, 317, 1384, 511]',
#  '[683, 81]',
#  '[1312, 20, 48, 679, 202, 23]',
#  '[933, 120, 120]',
#  '[934, 512, 497, 3]',
#  '[20, 48, 935, 1385]',
#  '[1386, 107, 3, 513]',
#  '[514, 9, 890, 78, 168]',
#  '[936]',
#  '[684]',
#  '[1387, 304, 655, 120, 120, 937, 20, 938, 1388]',
#  '[685, 1, 10, 2]',
#  '[1389, 12, 686, 232, 17]',
#  '[393, 56, 28]',
#  '[1390]',
#  '[493, 662, 380]',
#  '[687]',
#  '[318, 34, 17, 252, 46, 199, 177]',
#  '[25, 688, 72, 53]',
#  '[1391, 939, 515, 37, 137, 689]',
#  '[247, 1392, 1393, 516, 1394]',
#  '[64, 68, 153, 130]',
#  '[69, 21, 467, 940, 200, 33, 941, 690, 1395]',
#  '[]',
#  '[691, 140, 501]',
#  '[39, 85, 1396, 236]',
#  '[39, 12, 517, 22, 51, 394, 395, 51]',
#  '[69, 21, 155, 33, 915, 19]',
#  '[1397, 518, 1398, 48, 1399, 481, 255, 109]',
#  '[43, 628, 1400, 490]',
#  '[309, 176, 396, 233, 93]',
#  '[35, 942, 886]',
#  '[90, 25, 1, 3, 15, 63]',
#  '[16, 943, 1401, 4, 1402, 944, 945, 66]',
#  '[317, 1384, 519, 919, 946]',
#  '[13, 27, 520, 13, 27, 64]',
#  '[319, 23, 1403]',
#  '[1404, 668, 105]',
#  '[847, 521]',
#  '[684, 1405, 203, 692, 1406, 53, 320]',
#  '[35, 397, 397, 28, 28]',
#  '[522, 361, 66, 693, 141, 1407]',
#  '[1408]',
#  '[43, 58, 947, 17]',
#  '[852, 694, 523, 1409, 106]',
#  '[1410, 1411, 114, 204, 695]',
#  '[196, 948, 524, 71]',
#  '[393, 696, 949, 697]',
#  '[1, 3, 950, 951]',
#  '[398, 525, 952, 256, 398]',
#  '[142, 143, 1412, 109, 121, 169, 120, 120, 104]',
#  '[59, 255, 953, 396, 698]',
#  '[699, 1413, 894, 526, 1414, 1415]',
#  '[384, 53, 1416, 21]',
#  '[321, 168, 322, 52]',
#  '[526, 527, 160]',
#  '[205, 1417, 1, 2]',
#  '[700, 48, 1399]',
#  '[118, 1418, 1419]',
#  '[482, 1420]',
#  '[528, 954, 701]',
#  '[110, 1421, 144, 257, 1422, 1423, 1424]',
#  '[955, 956]',
#  '[1425, 1426, 957, 9, 393, 697, 696]',
#  '[958, 1427, 5, 702, 703]',
#  '[959, 1428, 323, 45]',
#  '[926, 1429, 960, 1, 107]',
#  '[961, 931, 399, 5]',
#  '[201, 962, 176, 55, 492, 704]',
#  '[180, 1430, 3, 1431]',
#  '[140]',
#  '[54, 385, 17, 400, 38, 1432]',
#  '[1433, 234, 529, 963]',
#  '[964, 705, 965, 964, 206]',
#  '[506, 55, 641]',
#  '[258]',
#  '[101, 1434, 1435, 120, 120, 937]',
#  '[900]',
#  '[83, 1436, 706, 207]',
#  '[16, 96, 6, 156, 69, 21, 1437]',
#  '[1438, 6]',
#  '[401, 79, 5, 702, 703]',
#  '[162, 158, 530, 151, 137, 640]',
#  '[966, 86, 240, 208]',
#  '[13, 27, 96, 1358, 500]',
#  '[642, 667, 1, 3, 15]',
#  '[1439, 1436, 402, 967]',
#  '[378]',
#  '[203, 707, 1, 10, 2]',
#  '[13, 27, 13, 130]',
#  '[54, 1440, 40, 689]',
#  '[482]',
#  '[1441, 198, 403, 497, 968, 969]',
#  '[180, 324, 325, 326]',
#  '[1442, 1443, 259, 201, 531, 116, 1290, 1, 2]',
#  '[120, 120, 937, 20, 938, 1388]',
#  '[5, 970]',
#  '[159, 134, 1444, 202, 1445, 708]',
#  '[327, 644, 532]',
#  '[709, 258]',
#  '[73, 616, 1446]',
#  '[13, 27, 4, 13, 130, 891]',
#  '[286, 710, 77]',
#  '[971, 108, 1447, 404, 60, 711]',
#  '[1448, 1, 1449, 2]',
#  '[13, 27, 130, 9, 64, 193]',
#  '[286, 513]',
#  '[1450, 972, 973, 376, 695, 44]',
#  '[27, 712, 209, 181, 533, 974, 975]',
#  '[23, 713, 3]',
#  '[328, 8]',
#  '[63, 144, 63]',
#  '[1451, 626, 29, 534, 535, 1452]',
#  '[976, 4, 868, 38, 17, 18, 49]',
#  '[210, 536, 405]',
#  '[374, 1453, 1454, 493, 54, 329]',
#  '[330, 406, 529, 28, 331, 56]',
#  '[171, 407]',
#  '[977, 21, 1455, 1456, 509, 21, 293, 89]',
#  '[537, 714, 191, 1457]',
#  '[360, 679, 7, 1458]',
#  '[538, 332, 1459]',
#  '[1460, 23, 1, 3, 15]',
#  '[]',
#  '[46, 705, 511]',
#  '[535, 408, 209, 260, 58, 211]',
#  '[1461, 31, 978, 979, 39, 1462]',
#  '[109, 469, 1, 10, 2]',
#  '[27, 980, 71]',
#  '[1463, 1464]',
#  '[493, 662, 12, 630, 159, 380, 244]',
#  '[1465, 981]',
#  '[393, 1466, 696, 1467, 261]',
#  '[27]',
#  '[258, 262]',
#  '[118, 36, 715, 1410, 306, 118, 108, 295, 404]',
#  '[1468, 1, 25, 3, 1431]',
#  '[82, 4, 10]',
#  '[181, 539, 716]',
#  '[1, 80, 405, 212, 3, 202, 1469]',
#  '[1470, 982, 42]',
#  '[35, 213, 5, 158, 329]',
#  '[687, 118, 495, 42]',
#  '[1471, 72, 1, 2]',
#  '[522, 1472, 361, 693, 141]',
#  '[1473, 409, 983, 1474, 1473, 1475, 362, 1474, 1476]',
#  '[410, 102, 717, 1477]',
#  '[]',
#  '[1478, 718, 8]',
#  '[984, 985, 122, 71]',
#  '[162, 158, 1479, 1480, 986, 6, 45]',
#  '[978, 979, 719, 58]',
#  '[263, 720, 59, 135, 308, 170, 987]',
#  '[988, 168]',
#  '[86, 721, 963, 333, 1361, 70]',
#  '[1481, 264, 1482, 1, 10, 2]',
#  '[3, 313, 722, 723, 63, 411, 153]',
#  '[885]',
#  '[412, 412, 988]',
#  '[1483, 628, 1482]',
#  '[43, 1484, 214, 152]',
#  '[1, 3, 15, 215, 2]',
#  '[702, 703, 1485, 1486, 1487, 1488, 907, 265]',
#  '[989, 80, 8]',
#  '[64, 13, 27, 6, 31]',
#  '[724, 1489, 1490, 1491, 413, 29, 1492, 8]',
#  '[940, 535, 75, 8]',
#  '[162, 725, 540, 499, 161, 541]',
#  '[66, 693, 141]',
#  '[1493, 1494, 36, 1, 10, 2]',
#  '[13, 27, 519]',
#  '[869]',
#  '[990]',
#  '[61, 854]',
#  '[84, 56]',
#  '[12, 1495]',
#  '[210, 536, 405, 9, 1496]',
#  '[101, 625, 138, 95, 726, 334, 40]',
#  '[991, 727, 8]',
#  '[1497, 1498, 971, 306, 109, 121, 169, 151, 137, 640]',
#  '[154, 242, 510, 1499, 414, 707, 510]',
#  '[54, 169, 42, 142, 143]',
#  '[112, 216, 58, 728]',
#  '[210, 335, 335, 87, 91]',
#  '[1304, 638, 867, 173, 1, 3, 15, 63]',
#  '[638, 1500]',
#  '[73, 920, 314, 45]',
#  '[110, 1421, 1422, 330, 415, 1424]',
#  '[1501, 992]',
#  '[365, 170, 4, 993, 170, 299]',
#  '[943, 1401, 4, 1402, 944, 88, 1502, 994, 66]',
#  '[144, 201, 673, 9, 53, 995, 729, 996, 45]',
#  '[730, 1480, 1503, 71]',
#  '[852, 534, 731, 997, 1504]',
#  '[853, 998, 732]',
#  '[542, 543, 390, 613, 999, 996]',
#  '[1505, 1000, 1001, 98, 1506]',
#  '[9, 733, 943, 4, 944, 1, 945, 544, 1002, 545, 1507, 545, 399]',
#  '[1508, 546, 13, 27]',
#  '[493, 662, 137, 734, 88]',
#  '[64, 68, 153, 64, 10, 1003, 64]',
#  '[217, 145, 172, 9, 496]',
#  '[]',
#  '[1004, 57, 31, 12, 7, 1509]',
#  '[1510, 171, 8]',
#  '[331, 151, 1511, 1512]',
#  '[658]',
#  '[380, 22, 33]',
#  '[12, 200, 6, 311, 501, 301, 200]',
#  '[1277, 176, 233, 93]',
#  '[53, 1005, 264, 735]',
#  '[266, 1513, 157]',
#  '[1006, 547]',
#  '[1007, 65, 477]',
#  '[936, 398]',
#  '[1398]',
#  '[1425, 1514, 30, 103, 1515, 393, 949, 697]',
#  '[1345, 409, 201, 1516, 3]',
#  '[1340, 930, 1379, 974, 975]',
#  '[393, 34, 736, 696]',
#  '[1517, 711, 671, 30]',
#  '[102, 366, 134, 16, 1518, 548, 1519]',
#  '[643, 1520, 32, 1502]',
#  '[737, 738, 262, 547, 8]',
#  '[83, 1521, 1522]',
#  '[517, 739, 153, 1523, 1008, 33]',
#  '[1524, 1525, 1009, 936]',
#  '[70, 336, 1373, 1526, 83, 251]',
#  '[1010, 19, 1527, 503]',
#  '[123, 416, 1528]',
#  '[6, 417, 37]',
#  '[927, 2, 121, 300]',
#  '[983]',
#  '[327, 644, 532]',
#  '[43, 64, 12, 13, 27]',
#  '[217, 145, 138, 10, 151]',
#  '[18, 488, 516, 152, 1011]',
#  '[57, 337, 34, 85, 211]',
#  '[300, 9]',
#  '[236, 101, 171, 133]',
#  '[69, 21, 58, 266, 418]',
#  '[1012, 1529, 410, 102, 717, 1477]',
#  '[47, 1530, 104, 549, 16, 740, 179]',
#  '[985, 51, 723, 218, 267]',
#  '[310, 419, 11, 7, 24]',
#  '[92, 546, 741, 742]',
#  '[743, 744, 1013, 865, 634, 282, 635, 367]',
#  '[1014, 392, 1531, 1532]',
#  '[1533, 956]',
#  '[1534, 1535, 745, 671]',
#  '[378]',
#  '[714, 191, 1015, 194, 30]',
#  '[1365, 1536, 118, 338]',
#  '[627, 1295, 1537, 550, 551, 47, 746]',
#  '[57, 84, 21, 1538, 498, 669]',
#  '[268, 324, 1495, 403]',
#  '[743, 23, 420, 67, 298, 1016]',
#  '[1017, 611, 1319, 1018, 359]',
#  '[1019, 132, 747, 239]',
#  '[1, 2]',
#  '[670, 219, 552]',
#  '[470, 67]',
#  '[722, 1539, 1413, 142, 143]',
#  '[15, 421, 1020, 553, 335, 335, 335, 87, 91, 554]',
#  '[422, 320, 124, 423, 859, 220, 954, 220, 221, 182]',
#  '[330, 232, 33, 83, 251]',
#  '[1540, 171, 1541]',
#  '[1542, 748]',
#  '[555, 146]',
#  '[749, 424, 222, 1543, 475]',
#  '[1544, 750, 1545, 1021, 4, 365, 170]',
#  '[3]',
#  '[1396, 1022, 1023, 119, 1546, 1011, 125, 751, 183]',
#  '[1547]',
#  '[1024, 1025, 269, 270, 254, 179]',
#  '[1276, 4, 223, 1301, 469, 19]',
#  '[52, 176]',
#  '[1548, 1531, 1014, 1532, 714, 191, 1457, 45]',
#  '[1549]',
#  '[106, 339, 340, 425, 426]',
#  '[154, 242, 1550, 70, 510, 1499, 421, 341, 123]',
#  '[752, 1026, 257, 104, 549, 16, 740, 179]',
#  '[612, 468, 1551, 381]',
#  '[342, 1027, 1, 3, 15, 63]',
#  '[1414, 665, 1552, 1553]',
#  '[427, 908, 1028, 1029, 1552, 1553, 1554, 81, 182]',
#  '[556, 557, 47]',
#  '[163, 164, 1303, 294]',
#  '[95, 308]',
#  '[885, 1030]',
#  '[428, 1555, 1556, 1557, 343, 1558]',
#  '[286, 513, 429, 184]',
#  '[631, 218, 8, 5]',
#  '[1031, 32, 1559, 75, 158, 301]',
#  '[68, 9, 110, 14, 344, 6, 257, 1032, 1033]',
#  '[558, 185, 1362, 559, 397, 537, 81]',
#  '[327, 1034, 43]',
#  '[]',
#  '[59, 84, 79, 34, 1560, 1561, 345, 58, 211]',
#  '[255, 22, 560]',
#  '[911, 753, 303, 485, 1562]',
#  '[1563, 4, 754, 38, 17, 18, 49]',
#  '[39, 97, 51, 223, 755, 756, 394, 395, 51]',
#  '[157, 213, 165, 21, 1035, 271]',
#  '[164, 539, 1036, 163, 346]',
#  '[15, 1037, 1038, 904, 1564, 87, 91, 554]',
#  '[1039, 29, 1565, 185, 17]',
#  '[1566, 746, 224, 56, 5, 1567, 1568]',
#  '[926, 1429, 960, 1, 1569]',
#  '[287, 43, 1040]',
#  '[1570, 1571, 701, 23]',
#  '[757, 4, 757]',
#  '[1, 235, 1281, 1572, 135, 3]',
#  '[561, 758, 3, 1041, 861]',
#  '[42, 1042, 161, 663, 89]',
#  '[23, 516, 22, 3, 15]',
#  '[629, 860]',
#  '[984, 347, 19]',
#  '[384, 53, 1416, 1573]',
#  '[1574, 620, 732, 5, 1575, 1576]',
#  '[1043, 1542, 1577, 647, 18]',
#  '[688, 35, 1044, 272, 12, 25, 25, 34, 98, 197]',
#  '[755, 1045, 1578]',
#  '[18, 503, 25, 71, 186]',
#  '[749, 759, 1046, 1047]',
#  '[1579]',
#  '[430, 223]',
#  '[344, 219]',
#  '[1580, 431, 377, 239, 131]',
#  '[739, 389, 7, 19]',
#  '[162, 550, 562, 1581, 1582]',
#  '[760, 1583, 1584, 1583, 1048]',
#  '[360, 1049, 563, 512]',
#  '[68]',
#  '[1, 3]',
#  '[492, 704, 62, 902, 123]',
#  '[492, 704, 1585, 109, 1417, 564]',
#  '[1586, 500, 700]',
#  '[16, 96, 7, 322, 1587]',
#  '[1588, 369]',
#  '[632]',
#  '[222]',
#  '[1050]',
#  '[744, 12, 23, 5, 86, 8]',
#  '[1589, 323]',
#  '[924, 144, 511]',
#  '[1049, 1496, 1051, 1590, 23, 565, 566, 761]',
#  '[762, 330, 406, 49]',
#  '[400]',
#  '[224, 35, 247, 1052, 541]',
#  '[225, 567, 226, 19, 78]',
#  '[763, 82, 139, 144, 16, 257]',
#  '[432, 1591, 3, 706, 764]',
#  '[52, 1592, 118, 1053, 905]',
#  '[108, 1001]',
#  '[993, 170, 1054, 73, 1593, 348, 1055]',
#  '[71, 765, 22, 56]',
#  '[133, 31, 322, 766, 141, 1456, 766, 141]',
#  '[767, 1056]',
#  '[119, 54, 329, 273]',
#  '[172, 50, 562, 117, 661, 144]',
#  '[1594, 875]',
#  '[1055, 1052, 1595, 1596]',
#  '[1597]',
#  '[1598, 407, 144, 1599, 9]',
#  '[]',
#  '[60, 37, 79, 568, 349, 1600]',
#  '[1057, 181, 377]',
#  '[36, 6]',
#  '[1601, 519, 36, 116, 735]',
#  '[65, 569, 35, 1602, 168, 336, 264]',
#  '[674, 1603, 29, 858, 253]',
#  '[175, 371, 350, 1058, 1059]',
#  '[136, 103]',
#  '[52, 514, 1604, 1, 10, 2]',
#  '[330, 232, 1605, 1060, 1606, 144, 897, 302]',
#  '[313, 741, 1462]',
#  '[144, 201, 673, 9, 53, 995, 729, 996]',
#  '[768, 1607, 297]',
#  '[113, 243, 113, 499]',
#  '[1061, 1608, 518, 433, 333, 173, 37, 6]',
#  '[69, 21, 155, 1062, 769]',
#  '[84, 56]',
#  '[495, 570, 1063]',
#  '[753, 303]',
#  '[1437, 984, 768, 6, 156]',
#  '[1064, 49, 1065, 245, 98, 346]',
#  '[]',
#  '[328, 1363]',
#  '[144, 80, 50, 763, 82, 139, 333, 283, 53, 1609]',
#  '[1610, 116, 1, 10, 2]',
#  '[1611, 1612, 614, 1613]',
#  '[1614, 654]',
#  '[1, 2, 5, 1615]',
#  '[763, 82, 139, 1616, 114, 9, 201, 673]',
#  '[959, 16, 90, 134, 1066]',
#  '[434, 92, 31]',
#  '[342, 1027, 550, 63, 1449]',
#  '[427, 908, 905, 1617, 650, 550, 265]',
#  '[1031, 32, 652]',
#  '[1618, 770, 414, 510, 227, 318, 294]',
#  '[407, 435]',
#  '[205, 1342, 7, 200, 315, 316]',
#  '[74, 351, 1, 2, 1619, 222]',
#  '[1620, 402, 266, 418]',
#  '[436, 16, 212, 859]',
#  '[88, 754, 1563, 99, 1621, 99]',
#  '[433, 115, 538, 125, 330, 406, 981]',
#  '[163, 1622, 164]',
#  '[1623, 1623]',
#  '[111, 94, 75, 285, 1, 2]',
#  '[37, 79, 771, 1624]',
#  '[1327, 44, 2]',
#  '[210, 536, 405]',
#  '[172, 1, 3, 764, 147]',
#  '[1625, 1626, 1369, 87, 91]',
#  '[70, 289, 1599]',
#  '[485, 1562, 911]',
#  '[1627, 772, 43, 1067, 1, 44, 2]',
#  '[22, 1628, 688]',
#  '[1629]',
#  '[126, 168, 336, 76]',
#  '[313, 1068]',
#  '[20, 773, 1069, 274, 275, 1630]',
#  '[1631]',
#  '[1632, 1633, 1633]',
#  '[1392, 1393, 516, 1394]',
#  '[173, 396, 1634, 1070, 74]',
#  '[144, 115, 538, 1635, 437, 117, 661]',
#  '[99, 51, 98, 51, 25, 554, 881, 46, 228]',
#  '[939, 3]',
#  '[1636, 1, 3, 15, 125, 751, 183]',
#  '[555, 327, 1637, 438]',
#  '[1638]',
#  '[342, 368, 709, 172, 61, 1639, 1640, 22, 1550]',
#  '[621, 1641, 210]',
#  '[68, 6, 14, 1071, 998, 1642, 1032]',
#  '[1072, 1073, 3, 33]',
#  '[571, 1074, 735]',
#  '[164, 1643, 163]',
#  '[403, 1075, 164, 539, 1643, 163, 672, 30]',
#  '[155, 69, 21, 33, 6, 156]',
#  '[474, 483, 109, 774, 22, 1, 1, 2]',
#  '[1501, 992]',
#  '[214]',
#  '[478, 4, 439, 317, 97]',
#  '[479, 6]',
#  '[1644, 163, 346, 1076, 164]',
#  '[1000, 1645, 404, 60]',
#  '[506, 440, 1646, 1647, 572]',
#  '[754]',
#  '[1637, 438, 9]',
#  '[753, 753]',
#  '[1648, 775, 573]',
#  '[292, 20, 773, 1075, 127, 48]',
#  '[13, 4, 198, 338, 678]',
#  '[59, 1356, 1266]',
#  '[263, 776, 572, 1649]',
#  '[]',
#  '[441, 616, 185, 70, 574, 114]',
#  '[216, 40, 6, 140, 66]',
#  '[1355, 1650]',
#  '[505, 35, 698]',
#  '[1077, 1651, 35, 375, 2]',
#  '[471, 363, 1652, 744, 32, 100, 206]',
#  '[724, 575]',
#  '[401, 1341, 227]',
#  '[1653, 470, 1078, 1, 3]',
#  '[568, 1049, 18, 563, 512, 442]',
#  '[7, 343, 1654, 303, 1079]',
#  '[6, 1297, 249, 112, 636]',
#  '[429, 184, 7, 24, 439, 777]',
#  '[1655, 164, 163, 346]',
#  '[1656, 53, 1617, 1655, 164, 1657, 163]',
#  '[771, 1658, 67, 1058]',
#  '[967]',
#  '[292, 164, 1657, 163, 484, 909, 910]',
#  '[1659, 46, 1660, 1, 2]',
#  '[778, 1080, 253, 443]',
#  '[362, 1503, 476, 76, 486, 23, 365, 139]',
#  '[1661, 47, 560]',
#  '[779]',
#  '[83, 434, 619, 780, 116, 711]',
#  '[1081, 154, 242, 414, 707, 1082]',
#  '[502, 714, 781, 576, 1083]',
#  '[1460, 81]',
#  '[401, 29]',
#  '[6, 31, 397, 507, 324, 86, 240, 31, 55]',
#  '[110, 14, 539, 46, 1084, 1085, 782, 783, 249, 125, 370, 294]',
#  '[4, 1662, 38, 17, 18, 49]',
#  '[1086, 1087, 1663, 407]',
#  '[1088, 96, 229, 352, 209, 260, 58, 211]',
#  '[784, 57, 95]',
#  '[1089, 1664, 5, 1665]',
#  '[202, 1666, 1667, 6, 311, 544]',
#  '[13, 1668, 19, 1669, 19, 1090, 1670, 2]',
#  '[]',
#  '[504, 1091]',
#  '[276]',
#  '[1671]',
#  '[966, 1672, 1673]',
#  '[54, 331, 780, 116, 76, 1674, 577, 1675, 86]',
#  '[444, 387, 195, 1676, 352]',
#  '[1497, 1498, 652, 1287, 578, 151, 137, 640]',
#  '[1092, 1007, 579, 108, 1516, 543, 1677, 108]',
#  '[181, 58, 1093]',
#  '[1094, 1095, 6, 19]',
#  '[1678]',
#  '[190]',
#  '[6, 1096, 2]',
#  '[1464, 27]',
#  '[737, 738, 262, 547, 1]',
#  '[60, 37]',
#  '[413]',
#  '[1012, 100, 962, 442, 73, 139, 9]',
#  '[160, 645, 218, 742]',
#  '[203]',
#  '[1679, 1313, 403, 409, 533, 1679]',
#  '[1043, 1680]',
#  '[51, 225, 77, 1470, 42, 394, 395, 51]',
#  '[]',
#  '[196, 347, 71]',
#  '[81, 1681, 1682, 785, 271]',
#  '[1653, 470, 1078, 1, 3]',
#  '[31, 55, 86, 404]',
#  '[1453, 1012, 750, 267, 492, 704, 1512]',
#  '[946, 1082]',
#  '[548]',
#  '[58, 1, 44, 2]',
#  '[472]',
#  '[507, 786, 1683]',
#  '[1091, 157, 486, 1684, 445, 93, 566, 1685, 1686, 245, 438]',
#  '[1097, 59, 425, 426]',
#  '[1687, 420, 787]',
#  '[633, 288, 476, 33, 691]',
#  '[1040, 486, 296, 6]',
#  '[746, 8]',
#  '[580, 1533, 1, 3]',
#  '[52, 1688, 4, 223]',
#  '[1689, 788, 257, 68, 9]',
#  '[970, 5, 631]',
#  '[1098, 40, 1002]',
#  '[1690, 93, 730, 287, 1099]',
#  '[]',
#  '[1072, 1073, 1, 3]',
#  '[961, 439, 224, 8, 5, 1691]',
#  '[1, 8, 2]',
#  '[1100, 57, 789, 1692, 176, 396, 233, 93]',
#  '[1693, 22]',
#  '[75, 285, 111, 94, 1694, 105]',
#  '[446, 1695, 1696, 1101, 350, 558, 82, 31, 70, 581, 101, 244]',
#  '[272, 1697]',
#  '[7, 322, 42]',
#  '[6, 7, 24, 57, 1004, 419, 1567, 1568]',
#  '[1102, 582, 28, 174]',
#  '[214, 162, 1698]',
#  '[50, 146, 684, 511]',
#  '[940, 535, 75, 1, 2]',
#  '[614, 13, 198, 338, 6, 156]',
#  '[86, 240, 116]',
#  '[43, 7, 343]',
#  '[577, 1103, 3]',
#  '[699, 79, 978, 979]',
#  '[1699, 448]',
#  '[277, 1700, 329]',
#  '[1104, 44, 2]',
#  '[1086, 164, 1644, 163, 346]',
#  '[57, 7, 24, 1701]',
#  '[29, 1105, 583, 1702, 791, 105, 5, 855, 1106]',
#  '[1703, 1703, 1107, 1108, 883, 701, 23]',
#  '[1, 3, 15, 215, 1704]',
#  '[515, 1109, 388, 131, 734]',
#  '[130, 734]',
#  '[682, 1705, 1, 8]',
#  '[1706, 44, 2]',
#  '[64, 68, 153, 33]',
#  '[379, 22, 1, 3]',
#  '[14, 138, 726, 212]',
#  '[327]',
#  '[261, 1586, 886]',
#  '[1110, 1707]',
#  '[435, 500, 1111, 325, 326]',
#  '[65, 1708, 350, 7, 736, 441, 1076, 21, 584, 89]',
#  '[37, 314, 83, 251]',
#  '[1709, 1, 2, 5]',
#  '[59, 255, 517, 1710, 22]',
#  '[14, 38, 267, 59, 792]',
#  '[14, 1112, 1711, 508, 31]',
#  '[1037, 1038, 335, 335, 87, 91]',
#  '[1111, 1712, 1713]',
#  '[585, 73, 1714, 353, 14]',
#  '[226, 69, 21, 7, 370, 19, 21, 293, 89]',
#  '[16, 1113, 627, 136, 103, 354, 449, 43, 66]',
#  '[1715, 1463, 1114, 266, 418]',
#  '[202, 1536, 35, 22, 61, 1639, 1640, 1008]',
#  '[586, 4, 186, 439]',
#  '[1716, 119, 1717, 112, 1115, 47, 273, 1310, 190]',
#  '[1718, 27, 1426, 583, 1719]',
#  '[]',
#  '[184, 53, 185]',
#  '[1, 3, 15, 63]',
#  '[1688, 118, 1720, 355]',
#  '[369, 1721, 1722, 1667, 1335, 50]',
#  '[36, 135, 1, 2]',
#  '[39, 1723, 69, 43]',
#  '[386, 76, 339, 340]',
#  '[13, 13, 198, 338, 6, 156]',
#  '[64, 793, 633]',
#  '[1724, 78, 1, 10, 2]',
#  '[17, 1725, 756]',
#  '[411, 1116]',
#  '[307, 7, 168, 794, 7]',
#  '[69, 21, 155, 286, 33, 498, 669]',
#  '[155, 485, 485]',
#  '[1726, 229, 1, 10, 2]',
#  '[1727, 1728, 39, 413, 29, 1729, 8, 5, 304, 655]',
#  '[699, 213, 57]',
#  '[1117, 145, 5]',
#  '[305, 1, 3, 183]',
#  '[1, 61]',
#  '[631, 1102, 8]',
#  '[159, 134, 262, 307]',
#  '[1404, 668, 1730, 1118, 695]',
#  '[124, 1731, 1732, 578, 208]',
#  '[569, 1733, 5, 724, 1604]',
#  '[266, 1513, 1554, 81, 564, 587, 588, 182]',
#  '[1031, 32, 1559, 75, 158, 301, 1, 10, 2]',
#  '[1033, 104, 795, 783]',
#  '[70, 336, 7, 24, 178, 1336]',
#  '[450, 436]',
#  '[491, 386, 681]',
#  '[525, 299, 1119]',
#  '[1083, 398]',
#  '[537, 98, 159]',
#  '[1066, 36, 1734, 771, 1624]',
#  '[1072, 1073, 160, 2, 18, 368, 3, 56]',
#  '[796, 1120, 74, 867, 1, 2]',
#  '[256, 947, 792]',
#  '[1121, 718, 384]',
#  '[487, 278, 1735, 57]',
#  '[1122, 379, 923, 1375]',
#  '[254, 269, 270, 757, 254, 179]',
#  '[1123, 1736, 743, 2]',
#  '[1737, 1124]',
#  '[797, 798, 312]',
#  '[1, 2]',
#  '[1125, 85, 1671, 1454]',
#  '[17, 451, 1126]',
#  '[23, 1127, 947, 792]',
#  '[799, 247]',
#  '[1000, 589, 1602, 32]',
#  '[]',
#  '[1267, 1014, 194, 30]',
#  '[37, 79, 112, 239, 637, 112]',
#  '[416, 99, 1738, 1684, 445, 1685, 1686]',
#  '[1739, 274, 275]',
#  '[1665, 1740, 87, 91]',
#  '[60, 132, 800, 779, 60, 104]',
#  '[401, 1741, 666, 374, 1742, 238, 208]',
#  '[847, 1128, 317, 506]',
#  '[200, 55, 1114, 55, 89]',
#  '[1129, 1130, 138, 1743, 1131, 1744, 1067]',
#  '[1580, 38, 590, 16, 518, 40]',
#  '[1019, 1745, 801]',
#  '[929, 372, 574, 66]',
#  '[408, 241, 241, 408]',
#  '[258, 1323, 29, 467, 97, 1746]',
#  '[591, 1099, 1055, 23, 787]',
#  '[728, 165, 7, 882, 24]',
#  '[641, 1, 116]',
#  '[491, 648, 13, 932]',
#  '[18, 488]',
#  '[802, 279, 228, 1298, 1747]',
#  '[551, 537, 38, 25, 449]',
#  '[726, 1131, 183, 169]',
#  '[283, 99, 507, 786, 245]',
#  '[1711, 551, 1748, 14, 1085, 267]',
#  '[1337, 1749, 1750, 90]',
#  '[52, 638, 283, 1132, 1751]',
#  '[1752, 1133, 59, 592, 65, 452]',
#  '[1753]',
#  '[593, 781, 229, 1447, 1754]',
#  '[52, 11, 148, 928, 682]',
#  '[861, 428, 37, 439, 17]',
#  '[1019, 1745, 1069, 14, 72]',
#  '[64, 222, 803, 104, 1698, 77, 82]',
#  '[1090, 490, 1755, 1628]',
#  '[165, 565, 1324]',
#  '[60, 450, 506, 663]',
#  '[767, 1756, 297, 647, 804]',
#  '[387]',
#  '[12, 1053, 1757, 250, 19, 42, 98, 4, 161]',
#  '[546, 13, 546, 13]',
#  '[1, 3, 5, 1134, 1758, 1077, 177]',
#  '[1135, 1021]',
#  '[805, 1136, 768, 594, 594, 1759]',
#  '[1045, 1137, 37, 806, 111, 980, 225, 807, 893]',
#  '[348, 741, 11, 148]',
#  '[435, 1, 2]',
#  '[1760, 1138, 390]',
#  '[66, 710, 356, 993, 170, 1054, 1714]',
#  '[1108]',
#  '[13, 4, 633, 288, 409, 19]',
#  '[537, 778, 1761]',
#  '[616, 721, 126, 100, 95, 793]',
#  '[23, 450, 352]',
#  '[31, 29, 1380]',
#  '[162, 158, 1139, 1762, 552]',
#  '[290, 595, 192, 265]',
#  '[495, 1763, 1661, 941, 690, 1395]',
#  '[1716, 6]',
#  '[371, 350, 1140, 359, 30]',
#  '[1140, 1764]',
#  '[1441, 440, 28]',
#  '[574, 1765, 1141]',
#  '[207, 1121, 718, 1766, 1529, 573, 34, 1142, 76]',
#  '[169, 99]',
#  '[1710, 4, 310, 16, 3, 99, 55, 15]',
#  '[805, 35, 31, 681]',
#  '[622, 623, 624, 473, 5, 474, 1143, 1005, 1767]',
#  '[355, 96]',
#  '[898, 1346, 106, 1, 44, 2]',
#  '[1768, 347, 39, 1768, 589]',
#  '[1769, 483, 1770, 1771, 382, 383]',
#  '[1123, 79, 1, 10, 2]',
#  '[126, 202, 72, 887, 1772, 135, 1144, 1773]',
#  '[1774, 1132]',
#  '[13, 64, 68, 153, 1775]',
#  '[1145, 1776, 49, 596, 88, 165]',
#  '[331, 1305, 1146, 1777, 451, 1146, 28]',
#  '[25, 1, 6, 31, 432, 279]',
#  '[942, 1778, 1779]',
#  '[110, 14, 38, 229, 1080, 1780, 1781, 34, 747, 294]',
#  '[310]',
#  '[692, 1147, 186, 1148, 1149, 1782]',
#  '[246, 116, 42, 808, 1783]',
#  '[851]',
#  '[427]',
#  '[494, 1784]',
#  '[1060, 344, 115]',
#  '[1605, 1060, 332, 318, 972, 1785]',
#  '[1408, 1786, 1787, 531, 651, 676]',
#  '[410, 218, 639]',
#  '[515, 1, 3]',
#  '[1150, 65]',
#  '[1788, 1789, 1790, 1791, 234, 282]',
#  '[585, 73, 16, 136, 103, 1113, 449, 43, 354, 25]',
#  '[1101, 350, 344, 101, 124, 234, 371, 350, 1151, 1792]',
#  '[]',
#  '[83, 228, 1793, 721, 581, 101, 28, 581, 101, 244]',
#  '[34, 17, 252, 46, 199, 177]',
#  '[1152, 1794]',
#  '[38, 1795, 1796, 1761]',
#  '[446, 161, 85, 56, 571]',
#  '[436, 1309, 135]',
#  '[904, 1153, 1376, 809, 566, 4, 1034, 976, 4, 1154, 38, 1797, 49]',
#  '[67, 71, 1798, 1779]',
#  '[527, 896, 4, 527, 896]',
#  '[1148, 1149, 186, 692]',
#  '[221, 935, 1799, 1, 3, 15, 125, 751, 183]',
#  '[96, 36, 1800, 315, 316]',
#  '[1801]',
#  '[81, 559]',
#  '[23, 54, 1458]',
#  '[]',
#  '[1148, 1149, 171, 186, 566]',
#  '[983, 1141, 453, 92, 748]',
#  '[158, 521, 1802]',
#  '[50, 1803, 1804, 1325]',
#  '[1155, 1316, 1486, 656]',
#  '[369, 12, 7, 977, 21, 69, 200]',
#  '[162, 158, 298, 306, 116, 76, 654]',
#  '[789, 477, 1805]',
#  '[35, 213, 80, 406]',
#  '[172, 205, 810, 1156, 1806, 126, 43]',
#  '[1122, 1157, 75]',
#  '[1807, 597, 752, 10, 2, 1808]',
#  '[13, 27, 1809, 1810]',
#  '[13]',
#  '[57, 7, 343]',
#  '[1699, 1811, 90, 308, 1158]',
#  '[212]',
#  '[1756, 64, 68, 92]',
#  '[1812, 409, 187, 811]',
#  '[52, 1159, 812, 1813, 373, 4, 524]',
#  '[520, 1386, 1814, 149]',
#  '[912, 38, 590, 1080, 1160, 1815, 137, 1383]',
#  '[119, 1816]',
#  '[348, 239, 18, 337]',
#  '[68, 9, 522, 361, 1514, 72, 90, 30, 1161]',
#  '[542, 391, 253, 443, 1007, 1128, 133, 903]',
#  '[1162, 535, 1, 2]',
#  '[388, 290]',
#  '[55, 1817]',
#  '[]',
#  '[1046, 1039, 1818]',
#  '[259, 136, 103]',
#  '[389, 57, 7, 24, 766, 141]',
#  '[1819, 1817, 1622, 1820, 1821]',
#  '[675, 636]',
#  '[188, 433, 124, 423, 1822]',
#  '[52, 1813, 1150]',
#  '[12, 185, 1821, 12, 185, 28]',
#  '[1823]',
#  '[142, 143, 641, 67, 8]',
#  '[1153, 1824]',
#  '[191, 351, 9, 496]',
#  '[12, 1825]',
#  '[471, 363, 1766, 226, 894, 1338]',
#  '[14, 1826, 1163, 79]',
#  '[560]',
#  '[768, 1827, 373, 266, 418]',
#  '[1537, 391, 9, 1002]',
#  '[50, 146]',
#  '[1110, 379, 756]',
#  ...]
